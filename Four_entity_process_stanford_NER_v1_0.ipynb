# %% [markdown]
# ## Using Stanford NER from Dan's stan.py work, on Hansard four entity process

# %%
# Stanford imports
from nltk.tag.stanford import StanfordNERTagger
from nltk.tokenize.stanford import StanfordTokenizer
# Other imports
import os
import nltk
from collections import defaultdict
# NLTK imports
from nltk import pos_tag
from nltk.chunk import conlltags2tree
from nltk.tree import Tree

import tkinter

import pandas as pd
import numpy as np

from collections import Counter
import operator

# %%
### Define paths ###

#Set core path for Stanford NLP packages
main_path = os.path.join("C:\\Users\\rothw\\Documents\\Python Scripts\\Python NLP\\StanfordNLP\\",
                         "stanford-corenlp-full-2016-10-31\\")
# Set paths where the Standford NLP .jar files are located
pathlist = [os.path.join(main_path,"stanford-corenlp-3.7.0"),
            os.path.join(main_path,"ner\\stanford-ner.jar"),
            os.path.join(main_path,"postagger\\stanford-postagger.jar")]
###            os.path.join(main_path,"parser\\stanford-parser.jar"),
###            os.path.join(main_path,"parser\\stanford-parser-3.6.0-models.jar"),
# Set path to Stanford models
mpath = [os.path.join(main_path,"postagger\\models"),
         os.path.join(main_path,"ner\\classifiers")]
# Set path to java.exe
javapath = "C:\\Program Files\\Java\\jre1.8.0_121\\bin\\java.exe"

# Add paths to the CLASSPATH environmental variable (as instructed by NLTK)
os.environ['CLASSPATH'] = os.pathsep.join(pathlist)
os.environ['STANFORD_MODELS'] = os.pathsep.join(mpath)
os.environ['JAVAHOME'] = javapath

# %%
### Define functions ###

# Define function to take in a sentence and return it NER tagged
def get_tagged_sent(sample):
    # Tokenize sentence with stanford NLP
    tkn_sent = StanfordTokenizer().tokenize(sample)
    print("\nTokenized sentence:\n", tkn_sent)
    # Named entity tagging with stanford NLP
    tag_sent = StanfordNERTagger(
                'english.muc.7class.distsim.crf.ser.gz').tag(tkn_sent)
    print("\nNamed Entity tagged sentence:\n", tag_sent)
    # Return NER tagged sentence
    return tag_sent

# Define function to tag NER sentence with BIO tags
def stanfordNE2BIO(tagged_sent):
    bio_tagged_sent = []
    prev_tag = "O"
    for token, tag in tagged_sent:
        if tag == "O": #O
            bio_tagged_sent.append((token, tag))
            prev_tag = tag
            continue
        if tag != "O" and prev_tag == "O": # Begin NE
            bio_tagged_sent.append((token, "B-"+tag))
            prev_tag = tag
        elif prev_tag != "O" and prev_tag == tag: # Inside NE
            bio_tagged_sent.append((token, "I-"+tag))
            prev_tag = tag
        elif prev_tag != "O" and prev_tag != tag: # Adjacent NE
            bio_tagged_sent.append((token, "B-"+tag))
            prev_tag = tag
    print("\nBIO chunked setence:\n", bio_tagged_sent)
    # Return BIO tagged sentence
    return bio_tagged_sent

# Define function to create tree from BIO tagged sentence
def stanfordNE2tree(ne_tagged_sent):
    bio_tagged_sent = stanfordNE2BIO(ne_tagged_sent)
    sent_tokens, sent_ne_tags = zip(*bio_tagged_sent)
    sent_pos_tags = [pos for token, pos in pos_tag(sent_tokens)]

    sent_conlltags = [(token, pos, ne) for token, pos, ne
                     in zip(sent_tokens, sent_pos_tags, sent_ne_tags)]
    ne_tree = conlltags2tree(sent_conlltags)
    print("\nPOS tagged tree:\n", ne_tree)
    # Return sentence in NLTK tree format
    return ne_tree

# Define function to get entities from NLTK tree
def get_ents(ne_tree):
    ne_in_sent = []
    for subtree in ne_tree:
        if type(subtree) == Tree: # If subtree is a noun chunk, i.e. NE != "O"
            ne_label = subtree.label()
            ne_string = " ".join([token for token, pos in subtree.leaves()])
            ne_in_sent.append((ne_string, ne_label))
    # Return list of entity tuples
    return ne_in_sent

# Define function to turn text into NLTK trees (one tree per sentence)
def text_to_trees(sample):
    # Tokenize sentence with NLTK
    sentences = nltk.sent_tokenize(sample)
    tagged_sentences = [get_tagged_sent(sent) for sent in sentences]
    trees = [stanfordNE2tree(sent) for sent in tagged_sentences]
    # Return list of NLTK trees
    return trees

# Define function to extract entities from NLTK trees
def ents_from_trees(trees):
    ents = [get_ents(tree) for tree in trees]
    ent_list = [item for sublist in ents for item in sublist] # Flatten list
    dedupe_ent_list = set(ent_list)
    # Return list of entities
    return dedupe_ent_list

# Re-creation of nltk tree2semi_rel to look inside lists of lists
def tree2rel_list(trees):
    semi_rels = []
    semi_rel = [[], None]

    for item in trees:
        for tree in item:
            if not isinstance(tree, Tree):
                semi_rel[0].append(tree)
            else:
                semi_rel[1] = tree
                semi_rels.append(semi_rel)
                semi_rel = [[], None]
    return semi_rels

# Re-creation of nltk semi_rel2reldic to remove NER tags
def rel2reldict(pairs, window=5, trace=False):
    result = []

    while len(pairs) > 2:
        reldict = defaultdict(str)
        reldict['lcon'] = " ".join(token for token, pos in pairs[0][0][-window:])
        reldict['subjclass'] = pairs[0][1].label()
        reldict['subjtext'] = " ".join(token for token, pos in pairs[0][1].leaves())
        reldict['filler'] = " ".join(token for token, pos in pairs[1][0])
        reldict['objclass'] = pairs[1][1].label()
        reldict['objtext'] = " ".join(token for token, pos in pairs[1][1].leaves())
        reldict['rcon'] = " ".join(token for token, pos in pairs[2][0][:window])
        if trace:
            print("(%s(%s, %s)" % (reldict['untagged_filler'], reldict['subjclass'], reldict['objclass']))
        result.append(reldict)
        pairs = pairs[1:]
    return result

# %% [markdown]
# ## Hansard Four Entity sample data

# %%
# Set up input parameters

file_in = 'c:\\Users\\rothw\\Documents\\Python Scripts\\Python NLP\\Motor Neurone Disease-Gordon Aikman 2017-02-20.txt'
file_out_suffix = 'motor_neurone'
date = '20/02/2017'

# Read in file
sample = open(file_in, 'r', encoding='utf8').read()

# %%
sample_tagged = get_tagged_sent(sample)
# Out:
# Tokenized sentence:
#  ['Motor', 'Neurone', 'Disease/Gordon', 'Aikman', 'Motion', 'made', ',', 'and', 'Question', 'proposed', ',', 'That', 'this', 'House', 'do', 'now', 'adjourn', '.', '--', '-LRB-', 'Chris', 'Heaton-Harris', '.', '-RRB-', '19:18:00', 'Ian', 'Murray', '-LRB-', 'Edinburgh', 'South', '-RRB-', '-LRB-', 'Lab', '-RRB-', 'I', 'am', 'very', 'grateful', 'to', 'the', 'good', 'offices', 'of', 'Mr', 'Speaker', 'and', 'you', ',', 'Madam', 'Deputy', 'Speaker', ',', 'for', 'granting', 'time', 'for', 'this', 'Adjournment', 'debate', '.', 'I', 'want', 'to', 'talk', 'about', 'the', 'dreadful', 'disease', 'that', 'is', 'motor', 'neurone', 'disease', 'and', 'to', 'pay', 'tribute', 'to', 'the', 'life', 'of', 'Gordon', 'Aikman', '.', 'I', 'wish', 'we', 'were', 'not', 'having', 'this', 'debate', ',', 'because', 'that', 'would', 'mean', 'Gordon', 'Aikman', 'was', 'still', 'with', 'us', '.', 'He', 'sadly', 'passed', 'away', 'on', '2', 'February', ',', 'aged', 'just', '31', '.', 'I', 'want', 'to', 'do', 'three', 'things', 'this', 'evening', ':', 'first', ',', 'pay', 'tribute', 'in', 'this', 'House', 'to', 'Gordon', 'Aikman', 'and', 'what', 'he', 'achieved', 'both', 'in', 'his', 'life', 'and', 'in', 'his', 'death', ';', 'secondly', ',', 'give', 'more', 'exposure', 'to', 'what', 'MND', 'is', 'and', 'how', 'the', 'disease', 'affects', 'those', 'stricken', 'by', 'it', ';', 'and', ',', 'thirdly', ',', 'discuss', 'what', 'we', 'can', 'all', 'do', 'and', 'what', 'the', 'Government', 'can', 'do', 'to', 'help', 'find', 'a', 'cure', '.', 'Alberto', 'Costa', '-LRB-', 'South', 'Leicestershire', '-RRB-', '-LRB-', 'Con', '-RRB-', 'I', 'congratulate', 'the', 'hon.', 'Gentleman', 'on', 'bringing', 'this', 'much', 'needed', 'debate', 'to', 'the', 'Floor', 'of', 'the', 'House', '.', 'Will', 'he', 'join', 'me', 'in', 'paying', 'tribute', 'to', 'local', 'MND', 'associations', 'across', 'the', 'United', 'Kingdom', 'for', 'the', 'invaluable', 'support', 'they', 'provide', '?', 'I', 'know', 'of', 'the', 'excellent', 'work', 'of', 'my', 'local', 'Leicestershire', 'and', 'Rutland', 'association', ',', 'having', 'heard', 'at', 'first', 'hand', 'from', 'a', 'constituent', 'and', 'friend', 'of', 'mine', ',', 'Ruth', 'Morrison', ',', 'about', 'her', 'tragic', 'personal', 'experience', '.', 'The', 'support', 'that', 'is', 'available', 'is', 'of', 'immense', 'value', 'and', 'I', 'hope', 'the', 'hon.', 'Gentleman', 'will', 'join', 'me', 'in', 'paying', 'tribute', 'to', 'the', 'work', 'of', 'those', 'associations', '.', 'Ian', 'Murray', 'I', 'am', 'delighted', 'that', 'the', 'hon.', 'Gentleman', 'was', 'able', 'to', 'intervene', 'to', 'emphasise', 'the', 'good', 'work', 'that', 'MND', 'associations', ',', 'including', 'MND', 'Scotland', ',', 'do', 'across', 'the', 'country', '.', 'I', 'pay', 'tribute', 'to', 'him', 'for', 'highlighting', 'that', 'good', 'work', 'in', 'the', 'House', 'and', 'I', 'ask', 'him', 'to', 'pass', 'on', 'our', 'best', 'wishes', 'to', 'his', 'constituents', 'who', 'are', 'stricken', 'by', 'this', 'dreadful', 'disease', '.', 'Gordon', 'Aikman', 'was', 'only', '29', 'when', 'he', 'was', 'diagnosed', 'with', 'MND', '.', 'He', 'was', 'given', '14', 'months', 'to', 'live', 'but', ',', 'as', 'was', 'usual', 'with', 'Gordon', ',', 'his', 'dedication', 'and', 'determination', 'made', 'sure', 'he', 'doubled', 'that', 'to', '28', '.', 'Gordon', 'died', 'leaving', 'behind', 'a', 'loving', 'husband', ',', 'Joe', ',', 'who', 'is', 'with', 'us', 'this', 'evening', ',', 'a', 'doting', 'mother', ',', 'Nancy', ',', 'and', 'a', 'devoted', 'sister', ',', 'Lorraine', '.', 'He', 'has', 'become', 'a', 'twinkling', 'star', 'in', 'the', 'sky', 'for', 'his', 'young', 'niece', 'Ailidh', 'and', 'young', 'nephew', 'Murray', ',', 'who', 'would', 'describe', 'Gordon', 'as', '``', 'Uncle', 'Gordon', 'with', 'wheels', "''", 'when', 'he', 'was', 'in', 'his', 'wheelchair', '.', 'He', 'leaves', 'behind', 'friends', 'whose', 'lives', 'will', 'forever', 'have', 'a', 'Gordon', 'Aikman-shaped', 'hole',  ...
#
# Named Entity tagged sentence:
#  [('Motor', 'O'), ('Neurone', 'ORGANIZATION'), ('DiseaseGordon', 'ORGANIZATION'), ('Aikman', 'ORGANIZATION'), ('Motion', 'ORGANIZATION'), ('made', 'O'), (',', 'O'), ('and', 'O'), ('Question', 'O'), ('proposed', 'O'), (',', 'O'), ('That', 'O'), ('this', 'O'), ('House', 'ORGANIZATION'), ('do', 'O'), ('now', 'O'), ('adjourn', 'O'), ('.', 'O'), ('--', 'O'), ('-LRB-', 'O'), ('Chris', 'PERSON'), ('Heaton-Harris', 'PERSON'), ('.', 'O'), ('-RRB-', 'O'), ('19:18:00', 'O'), ('Ian', 'PERSON'), ('Murray', 'PERSON'), ('-LRB-', 'O'), ('Edinburgh', 'ORGANIZATION'), ('South', 'ORGANIZATION'), ('-RRB-', 'O'), ('-LRB-', 'O'), ('Lab', 'O'), ('-RRB-', 'O'), ('I', 'O'), ('am', 'O'), ('very', 'O'), ('grateful', 'O'), ('to', 'O'), ('the', 'O'), ('good', 'O'), ('offices', 'O'), ('of', 'O'), ('Mr', 'O'), ('Speaker', 'O'), ('and', 'O'), ('you', 'O'), (',', 'O'), ('Madam', 'O'), ('Deputy', 'O'), ('Speaker', 'O'), (',', 'O'), ('for', 'O'), ('granting', 'O'), ('time', 'O'), ('for', 'O'), ('this', 'O'), ('Adjournment', 'O'), ('debate', 'O'), ('.', 'O'), ('I', 'O'), ('want', 'O'), ('to', 'O'), ('talk', 'O'), ('about', 'O'), ('the', 'O'), ('dreadful', 'O'), ('disease', 'O'), ('that', 'O'), ('is', 'O'), ('motor', 'O'), ('neurone', 'O'), ('disease', 'O'), ('and', 'O'), ('to', 'O'), ('pay', 'O'), ('tribute', 'O'), ('to', 'O'), ('the', 'O'), ('life', 'O'), ('of', 'O'), ('Gordon', 'PERSON'), ('Aikman', 'PERSON'), ('.', 'O'), ('I', 'O'), ('wish', 'O'), ('we', 'O'), ('were', 'O'), ('not', 'O'), ('having', 'O'), ('this', 'O'), ('debate', 'O'), (',', 'O'), ('because', 'O'), ('that', 'O'), ('would', 'O'), ('mean', 'O'), ('Gordon', 'PERSON'), ('Aikman', 'PERSON'), ('was', 'O'), ('still', 'O'), ('with', 'O'), ('us', 'O'), ('.', 'O'), ('He', 'O'), ('sadly', 'O'), ('passed', 'O'), ('away', 'O'), ('on', 'O'), ('2', 'O'), ('February', 'DATE'), (',', 'O'), ('aged', 'O'), ('just', 'O'), ('31', 'O'), ('.', 'O'), ('I', 'O'), ('want', 'O'), ('to', 'O'), ('do', 'O'), ('three', 'O'), ('things', 'O'), ('this', 'O'), ('evening', 'O'), (':', 'O'), ('first', 'O'), (',', 'O'), ('pay', 'O'), ('tribute', 'O'), ('in', 'O'), ('this', 'O'), ('House', 'ORGANIZATION'), ('to', 'O'), ('Gordon', 'PERSON'), ('Aikman', 'PERSON'), ('and', 'O'), ('what', 'O'), ('he', 'O'), ('achieved', 'O'), ('both', 'O'), ('in', 'O'), ('his', 'O'), ('life', 'O'), ('and', 'O'), ('in', 'O'), ('his', 'O'), ('death', 'O'), (';', 'O'), ('secondly', 'O'), (',', 'O'), ('give', 'O'), ('more', 'O'), ('exposure', 'O'), ('to', 'O'), ('what', 'O'), ('MND', 'ORGANIZATION'), ('is', 'O'), ('and', 'O'), ('how', 'O'), ('the', 'O'), ('disease', 'O'), ('affects', 'O'), ('those', 'O'), ('stricken', 'O'), ('by', 'O'), ('it', 'O'), (';', 'O'), ('and', 'O'), (',', 'O'), ('thirdly', 'O'), (',', 'O'), ('discuss', 'O'), ('what', 'O'), ('we', 'O'), ('can', 'O'), ('all', 'O'), ('do', 'O'), ('and', 'O'), ('what', 'O'), ('the', 'O'), ('Government', 'O'), ('can', 'O'), ('do', 'O'), ('to', 'O'), ('help', 'O'), ('find', 'O'), ('a', 'O'), ('cure', 'O'), ('.', 'O'), ('Alberto', 'O'), ('Costa', 'O'), ('-LRB-', 'O'), ('South', 'LOCATION'), ('Leicestershire', 'LOCATION'), ('-RRB-', 'O'), ('-LRB-', 'O'), ('Con', 'O'), ('-RRB-', 'O'), ('I', 'O'), ('congratulate', 'O'), ('the', 'O'), ('hon.', 'O'), ('Gentleman', 'O'), ('on', 'O'), ('bringing', 'O'), ('this', 'O'), ('much', 'O'), ('needed', 'O'), ('debate', 'O'), ('to', 'O'), ('the', 'O'), ('Floor', 'O'), ('of', 'O'), ('the', 'O'), ('House', 'ORGANIZATION'), ('.', 'O'), ('Will', 'O'), ('he', 'O'), ('join', 'O'), ('me', 'O'), ('in', 'O'), ('paying', 'O'), ('tribute', 'O'), ('to', 'O'), ('local', 'O'), ('MND', 'ORGANIZATION'), ('associations', 'O'), ('across', 'O'), ('the', 'O'), ('United', 'LOCATION'), ('Kingdom', 'LOCATION'), ('for', 'O'), ('the', 'O'), ('invaluable', 'O'), ('support', 'O'), ('they', 'O'), ('provide', 'O'), ('?', 'O'), ('I', 'O'), ('know', 'O'), ('of', 'O'), ('the', 'O'), ('excellent', 'O'), ('work', 'O'), ('of', 'O'), ('my', 'O'), ('local', 'O'), ('Leicestershire', 'O'), ('and', 'O'), ('R ...

# %%
sample_bio = stanfordNE2BIO(sample_tagged)
# Out:
# BIO chunked setence:
#  [('Motor', 'O'), ('Neurone', 'B-ORGANIZATION'), ('DiseaseGordon', 'I-ORGANIZATION'), ('Aikman', 'I-ORGANIZATION'), ('Motion', 'I-ORGANIZATION'), ('made', 'O'), (',', 'O'), ('and', 'O'), ('Question', 'O'), ('proposed', 'O'), (',', 'O'), ('That', 'O'), ('this', 'O'), ('House', 'B-ORGANIZATION'), ('do', 'O'), ('now', 'O'), ('adjourn', 'O'), ('.', 'O'), ('--', 'O'), ('-LRB-', 'O'), ('Chris', 'B-PERSON'), ('Heaton-Harris', 'I-PERSON'), ('.', 'O'), ('-RRB-', 'O'), ('19:18:00', 'O'), ('Ian', 'B-PERSON'), ('Murray', 'I-PERSON'), ('-LRB-', 'O'), ('Edinburgh', 'B-ORGANIZATION'), ('South', 'I-ORGANIZATION'), ('-RRB-', 'O'), ('-LRB-', 'O'), ('Lab', 'O'), ('-RRB-', 'O'), ('I', 'O'), ('am', 'O'), ('very', 'O'), ('grateful', 'O'), ('to', 'O'), ('the', 'O'), ('good', 'O'), ('offices', 'O'), ('of', 'O'), ('Mr', 'O'), ('Speaker', 'O'), ('and', 'O'), ('you', 'O'), (',', 'O'), ('Madam', 'O'), ('Deputy', 'O'), ('Speaker', 'O'), (',', 'O'), ('for', 'O'), ('granting', 'O'), ('time', 'O'), ('for', 'O'), ('this', 'O'), ('Adjournment', 'O'), ('debate', 'O'), ('.', 'O'), ('I', 'O'), ('want', 'O'), ('to', 'O'), ('talk', 'O'), ('about', 'O'), ('the', 'O'), ('dreadful', 'O'), ('disease', 'O'), ('that', 'O'), ('is', 'O'), ('motor', 'O'), ('neurone', 'O'), ('disease', 'O'), ('and', 'O'), ('to', 'O'), ('pay', 'O'), ('tribute', 'O'), ('to', 'O'), ('the', 'O'), ('life', 'O'), ('of', 'O'), ('Gordon', 'B-PERSON'), ('Aikman', 'I-PERSON'), ('.', 'O'), ('I', 'O'), ('wish', 'O'), ('we', 'O'), ('were', 'O'), ('not', 'O'), ('having', 'O'), ('this', 'O'), ('debate', 'O'), (',', 'O'), ('because', 'O'), ('that', 'O'), ('would', 'O'), ('mean', 'O'), ('Gordon', 'B-PERSON'), ('Aikman', 'I-PERSON'), ('was', 'O'), ('still', 'O'), ('with', 'O'), ('us', 'O'), ('.', 'O'), ('He', 'O'), ('sadly', 'O'), ('passed', 'O'), ('away', 'O'), ('on', 'O'), ('2', 'O'), ('February', 'B-DATE'), (',', 'O'), ('aged', 'O'), ('just', 'O'), ('31', 'O'), ('.', 'O'), ('I', 'O'), ('want', 'O'), ('to', 'O'), ('do', 'O'), ('three', 'O'), ('things', 'O'), ('this', 'O'), ('evening', 'O'), (':', 'O'), ('first', 'O'), (',', 'O'), ('pay', 'O'), ('tribute', 'O'), ('in', 'O'), ('this', 'O'), ('House', 'B-ORGANIZATION'), ('to', 'O'), ('Gordon', 'B-PERSON'), ('Aikman', 'I-PERSON'), ('and', 'O'), ('what', 'O'), ('he', 'O'), ('achieved', 'O'), ('both', 'O'), ('in', 'O'), ('his', 'O'), ('life', 'O'), ('and', 'O'), ('in', 'O'), ('his', 'O'), ('death', 'O'), (';', 'O'), ('secondly', 'O'), (',', 'O'), ('give', 'O'), ('more', 'O'), ('exposure', 'O'), ('to', 'O'), ('what', 'O'), ('MND', 'B-ORGANIZATION'), ('is', 'O'), ('and', 'O'), ('how', 'O'), ('the', 'O'), ('disease', 'O'), ('affects', 'O'), ('those', 'O'), ('stricken', 'O'), ('by', 'O'), ('it', 'O'), (';', 'O'), ('and', 'O'), (',', 'O'), ('thirdly', 'O'), (',', 'O'), ('discuss', 'O'), ('what', 'O'), ('we', 'O'), ('can', 'O'), ('all', 'O'), ('do', 'O'), ('and', 'O'), ('what', 'O'), ('the', 'O'), ('Government', 'O'), ('can', 'O'), ('do', 'O'), ('to', 'O'), ('help', 'O'), ('find', 'O'), ('a', 'O'), ('cure', 'O'), ('.', 'O'), ('Alberto', 'O'), ('Costa', 'O'), ('-LRB-', 'O'), ('South', 'B-LOCATION'), ('Leicestershire', 'I-LOCATION'), ('-RRB-', 'O'), ('-LRB-', 'O'), ('Con', 'O'), ('-RRB-', 'O'), ('I', 'O'), ('congratulate', 'O'), ('the', 'O'), ('hon.', 'O'), ('Gentleman', 'O'), ('on', 'O'), ('bringing', 'O'), ('this', 'O'), ('much', 'O'), ('needed', 'O'), ('debate', 'O'), ('to', 'O'), ('the', 'O'), ('Floor', 'O'), ('of', 'O'), ('the', 'O'), ('House', 'B-ORGANIZATION'), ('.', 'O'), ('Will', 'O'), ('he', 'O'), ('join', 'O'), ('me', 'O'), ('in', 'O'), ('paying', 'O'), ('tribute', 'O'), ('to', 'O'), ('local', 'O'), ('MND', 'B-ORGANIZATION'), ('associations', 'O'), ('across', 'O'), ('the', 'O'), ('United', 'B-LOCATION'), ('Kingdom', 'I-LOCATION'), ('for', 'O'), ('the', 'O'), ('invaluable', 'O'), ('support', 'O'), ('they', 'O'), ('provide', 'O'), ('?', 'O'), ('I', 'O'), ('know', 'O'), ('of', 'O'), ('the', 'O'), ('excellent', 'O'), ('work', 'O'), ('of', 'O'), ('my', 'O'), ('loca ...

# %%
sample_tree = stanfordNE2tree(sample_tagged)
# Out:
# BIO chunked setence:
#  [('Motor', 'O'), ('Neurone', 'B-ORGANIZATION'), ('DiseaseGordon', 'I-ORGANIZATION'), ('Aikman', 'I-ORGANIZATION'), ('Motion', 'I-ORGANIZATION'), ('made', 'O'), (',', 'O'), ('and', 'O'), ('Question', 'O'), ('proposed', 'O'), (',', 'O'), ('That', 'O'), ('this', 'O'), ('House', 'B-ORGANIZATION'), ('do', 'O'), ('now', 'O'), ('adjourn', 'O'), ('.', 'O'), ('--', 'O'), ('-LRB-', 'O'), ('Chris', 'B-PERSON'), ('Heaton-Harris', 'I-PERSON'), ('.', 'O'), ('-RRB-', 'O'), ('19:18:00', 'O'), ('Ian', 'B-PERSON'), ('Murray', 'I-PERSON'), ('-LRB-', 'O'), ('Edinburgh', 'B-ORGANIZATION'), ('South', 'I-ORGANIZATION'), ('-RRB-', 'O'), ('-LRB-', 'O'), ('Lab', 'O'), ('-RRB-', 'O'), ('I', 'O'), ('am', 'O'), ('very', 'O'), ('grateful', 'O'), ('to', 'O'), ('the', 'O'), ('good', 'O'), ('offices', 'O'), ('of', 'O'), ('Mr', 'O'), ('Speaker', 'O'), ('and', 'O'), ('you', 'O'), (',', 'O'), ('Madam', 'O'), ('Deputy', 'O'), ('Speaker', 'O'), (',', 'O'), ('for', 'O'), ('granting', 'O'), ('time', 'O'), ('for', 'O'), ('this', 'O'), ('Adjournment', 'O'), ('debate', 'O'), ('.', 'O'), ('I', 'O'), ('want', 'O'), ('to', 'O'), ('talk', 'O'), ('about', 'O'), ('the', 'O'), ('dreadful', 'O'), ('disease', 'O'), ('that', 'O'), ('is', 'O'), ('motor', 'O'), ('neurone', 'O'), ('disease', 'O'), ('and', 'O'), ('to', 'O'), ('pay', 'O'), ('tribute', 'O'), ('to', 'O'), ('the', 'O'), ('life', 'O'), ('of', 'O'), ('Gordon', 'B-PERSON'), ('Aikman', 'I-PERSON'), ('.', 'O'), ('I', 'O'), ('wish', 'O'), ('we', 'O'), ('were', 'O'), ('not', 'O'), ('having', 'O'), ('this', 'O'), ('debate', 'O'), (',', 'O'), ('because', 'O'), ('that', 'O'), ('would', 'O'), ('mean', 'O'), ('Gordon', 'B-PERSON'), ('Aikman', 'I-PERSON'), ('was', 'O'), ('still', 'O'), ('with', 'O'), ('us', 'O'), ('.', 'O'), ('He', 'O'), ('sadly', 'O'), ('passed', 'O'), ('away', 'O'), ('on', 'O'), ('2', 'O'), ('February', 'B-DATE'), (',', 'O'), ('aged', 'O'), ('just', 'O'), ('31', 'O'), ('.', 'O'), ('I', 'O'), ('want', 'O'), ('to', 'O'), ('do', 'O'), ('three', 'O'), ('things', 'O'), ('this', 'O'), ('evening', 'O'), (':', 'O'), ('first', 'O'), (',', 'O'), ('pay', 'O'), ('tribute', 'O'), ('in', 'O'), ('this', 'O'), ('House', 'B-ORGANIZATION'), ('to', 'O'), ('Gordon', 'B-PERSON'), ('Aikman', 'I-PERSON'), ('and', 'O'), ('what', 'O'), ('he', 'O'), ('achieved', 'O'), ('both', 'O'), ('in', 'O'), ('his', 'O'), ('life', 'O'), ('and', 'O'), ('in', 'O'), ('his', 'O'), ('death', 'O'), (';', 'O'), ('secondly', 'O'), (',', 'O'), ('give', 'O'), ('more', 'O'), ('exposure', 'O'), ('to', 'O'), ('what', 'O'), ('MND', 'B-ORGANIZATION'), ('is', 'O'), ('and', 'O'), ('how', 'O'), ('the', 'O'), ('disease', 'O'), ('affects', 'O'), ('those', 'O'), ('stricken', 'O'), ('by', 'O'), ('it', 'O'), (';', 'O'), ('and', 'O'), (',', 'O'), ('thirdly', 'O'), (',', 'O'), ('discuss', 'O'), ('what', 'O'), ('we', 'O'), ('can', 'O'), ('all', 'O'), ('do', 'O'), ('and', 'O'), ('what', 'O'), ('the', 'O'), ('Government', 'O'), ('can', 'O'), ('do', 'O'), ('to', 'O'), ('help', 'O'), ('find', 'O'), ('a', 'O'), ('cure', 'O'), ('.', 'O'), ('Alberto', 'O'), ('Costa', 'O'), ('-LRB-', 'O'), ('South', 'B-LOCATION'), ('Leicestershire', 'I-LOCATION'), ('-RRB-', 'O'), ('-LRB-', 'O'), ('Con', 'O'), ('-RRB-', 'O'), ('I', 'O'), ('congratulate', 'O'), ('the', 'O'), ('hon.', 'O'), ('Gentleman', 'O'), ('on', 'O'), ('bringing', 'O'), ('this', 'O'), ('much', 'O'), ('needed', 'O'), ('debate', 'O'), ('to', 'O'), ('the', 'O'), ('Floor', 'O'), ('of', 'O'), ('the', 'O'), ('House', 'B-ORGANIZATION'), ('.', 'O'), ('Will', 'O'), ('he', 'O'), ('join', 'O'), ('me', 'O'), ('in', 'O'), ('paying', 'O'), ('tribute', 'O'), ('to', 'O'), ('local', 'O'), ('MND', 'B-ORGANIZATION'), ('associations', 'O'), ('across', 'O'), ('the', 'O'), ('United', 'B-LOCATION'), ('Kingdom', 'I-LOCATION'), ('for', 'O'), ('the', 'O'), ('invaluable', 'O'), ('support', 'O'), ('they', 'O'), ('provide', 'O'), ('?', 'O'), ('I', 'O'), ('know', 'O'), ('of', 'O'), ('the', 'O'), ('excellent', 'O'), ('work', 'O'), ('of', 'O'), ('my', 'O'), ('loca ...
#
# POS tagged tree:
#  (S
#   Motor/NNP
#   (ORGANIZATION Neurone/NNP DiseaseGordon/NNP Aikman/NNP Motion/NNP)
#   made/VBD
#   ,/,
#   and/CC
#   Question/NNP
#   proposed/VBD
#   ,/,
#   That/IN
#   this/DT
#   (ORGANIZATION House/NNP)
#   do/VBP
#   now/RB
#   adjourn/VB
#   ./.
#   --/:
#   -LRB-/JJ
#   (PERSON Chris/NNP Heaton-Harris/NNP)
#   ./.
#   -RRB-/VB
#   19:18:00/CD
#   (PERSON Ian/NNP Murray/NNP)
#   -LRB-/NNP
#   (ORGANIZATION Edinburgh/NNP South/NNP)
#   -RRB-/NNP
#   -LRB-/NNP
#   Lab/NNP
#   -RRB-/NNP
#   I/PRP
#   am/VBP
#   very/RB
#   grateful/JJ
#   to/TO
#   the/DT
#   good/JJ
#   offices/NNS
#   of/IN
#   Mr/NNP
#   Speaker/NNP
#   and/CC
#   you/PRP
#   ,/,
#   Madam/NNP
#   Deputy/NNP
#   Speaker/NNP
#   ,/,
#   for/IN
#   granting/VBG
#   time/NN
#   for/IN
#   this/DT
#   Adjournment/NNP
#   debate/NN
#   ./.
#   I/PRP
#   want/VBP
#   to/TO
#   talk/VB
#   about/IN
#   the/DT
#   dreadful/JJ
#   disease/NN
#   that/WDT
#   is/VBZ
#   motor/NN
#   neurone/JJ
#   disease/NN
#   and/CC
#   to/TO
#   pay/VB
#   tribute/NN
#   to/TO
#   the/DT
#   life/NN
#   of/IN
#   (PERSON Gordon/NNP Aikman/NNP)
#   ./.
#   I/PRP
#   wish/VBP
#   we/PRP
#   were/VBD
#   not/RB
#   having/VBG
#   this/DT
#   debate/NN
#   ,/,
#   because/IN
#   that/DT
#   would/MD
#   mean/VB
#   (PERSON Gordon/NNP Aikman/NNP)
#   was/VBD
#   still/RB
#   with/IN
#   us/PRP
#   ./.
#   He/PRP
#   sadly/RB
#   passed/VBD
#   away/RB
#   on/IN
#   2/CD
#   (DATE February/NNP)
#   ,/,
#   aged/VBD
#   just/RB
#   31/CD
#   ./.
#   I/PRP
#   want/VBP
#   to/TO
#   do/VB
#   three/CD
#   things/NNS
#   this/DT
#   evening/NN
#   :/:
#   first/RB
#   ,/,
#   pay/VB
#   tribute/NN
#   in/IN
#   this/DT
#   (ORGANIZATION House/NNP)
#   to/TO
#   (PERSON Gordon/NNP Aikman/NNP)
#   and/CC
#   what/WP
#   he/PRP
#   achieved/VBD
#   both/DT
#   in/IN
#   his/PRP$
#   life/NN
#   and/CC
#   in/IN
#   his/PRP$
#   death/NN
#   ;/:
#   secondly/RB
#   ,/,
#   give/VB
#   more/JJR
#   exposure/NN
#   to/TO
#   what/WP
#   (ORGANIZATION MND/NNP)
#   is/VBZ
#   and/CC
#   how/WRB
#   the/DT
#   disease/NN
#   affects/VBZ
#   those/DT
#   stricken/VBN
#   by/IN
#   it/PRP
#   ;/:
#   and/CC
#   ,/,
#   thirdly/RB
#   ,/,
#   discuss/VB
#   what/WP
#   we/PRP
#   can/MD
#   all/DT
#   do/VB
#   and/CC
#   what/VB
#   the/DT
#   Government/NNP
#   can/MD
#   do/VB
#   to/TO
#   help/VB
#   find/VB
#   a/DT
#   cure/NN
#   ./.
#   Alberto/NNP
#   Costa/NNP
#   -LRB-/NNP
#   (LOCATION South/NNP Leicestershire/NNP)
#   -RRB-/NNP
#   -LRB-/NNP
#   Con/NNP
#   -RRB-/NNP
#   I/PRP
#   congratulate/VBP
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   on/IN
#   bringing/VBG
#   this/DT
#   much/RB
#   needed/VBN
#   debate/NN
#   to/TO
#   the/DT
#   Floor/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION House/NNP)
#   ./.
#   Will/MD
#   he/PRP
#   join/VB
#   me/PRP
#   in/IN
#   paying/VBG
#   tribute/NN
#   to/TO
#   local/JJ
#   (ORGANIZATION MND/NNP)
#   associations/NNS
#   across/IN
#   the/DT
#   (LOCATION United/NNP Kingdom/NNP)
#   for/IN
#   the/DT
#   invaluable/JJ
#   support/NN
#   they/PRP
#   provide/VBP
#   ?/.
#   I/PRP
#   know/VBP
#   of/IN
#   the/DT
#   excellent/JJ
#   work/NN
#   of/IN
#   my/PRP$
#   local/JJ
#   Leicestershire/NNP
#   and/CC
#   (LOCATION Rutland/NNP)
#   association/NN
#   ,/,
#   having/VBG
#   heard/VBN
#   at/IN
#   first/JJ
#   hand/NN
#   from/IN
#   a/DT
#   constituent/NN
#   and/CC
#   friend/NN
#   of/IN
#   mine/NN
#   ,/,
#   (PERSON Ruth/NNP Morrison/NNP)
#   ,/,
#   about/IN
#   her/PRP$
#   tragic/JJ
#   personal/JJ
#   experience/NN
#   ./.
#   The/DT
#   support/NN
#   that/WDT
#   is/VBZ
#   available/JJ
#   is/VBZ
#   of/IN
#   immense/JJ
#   value/NN
#   and/CC
#   I/PRP
#   hope/VBP
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   will/MD
#   join/VB
#   me/PRP
#   in/IN
#   paying/VBG
#   tribute/NN
#   to/TO
#   the/DT
#   work/NN
#   of/IN
#   those/DT
#   associations/NNS
#   ./.
#   (PERSON Ian/NNP Murray/NNP)
#   I/PRP
#   am/VBP
#   delighted/JJ
#   that/IN
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   was/VBD
#   able/JJ
#   to/TO
#   intervene/VB
#   to/TO
#   emphasise/VB
#   the/DT
#   good/JJ
#   work/NN
#   that/WDT
#   (ORGANIZATION MND/NNP)
#   associations/NNS
#   ,/,
#   including/VBG
#   MND/NNP
#   (LOCATION Scotland/NNP)
#   ,/,
#   do/VBP
#   across/IN
#   the/DT
#   country/NN
#   ./.
#   I/PRP
#   pay/VBP
#   tribute/JJ
#   to/TO
#   him/PRP
#   for/IN
#   highlighting/VBG
#   that/DT
#   good/JJ
#   work/NN
#   in/IN
#   the/DT
#   (ORGANIZATION House/NNP)
#   and/CC
#   I/PRP
#   ask/VBP
#   him/PRP
#   to/TO
#   pass/VB
#   on/IN
#   our/PRP$
#   best/JJS
#   wishes/NNS
#   to/TO
#   his/PRP$
#   constituents/NNS
#   who/WP
#   are/VBP
#   stricken/VBN
#   by/IN
#   this/DT
#   dreadful/JJ
#   disease/NN
#   ./.
#   (PERSON Gordon/NNP Aikman/NNP)
#   was/VBD
#   only/RB
#   29/CD
#   when/WRB
#   he/PRP
#   was/VBD
#   diagnosed/VBN
#   with/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   He/PRP
#   was/VBD
#   given/VBN
#   14/CD
#   months/NNS
#   to/TO
#   live/VB
#   but/CC
#   ,/,
#   as/IN
#   was/VBD
#   usual/JJ
#   with/IN
#   (PERSON Gordon/NNP)
#   ,/,
#   his/PRP$
#   dedication/NN
#   and/CC
#   determination/NN
#   made/VBD
#   sure/JJ
#   he/PRP
#   doubled/VBD
#   that/IN
#   to/TO
#   28/CD
#   ./.
#   Gordon/NNP
#   died/VBD
#   leaving/VBG
#   behind/IN
#   a/DT
#   loving/JJ
#   husband/NN
#   ,/,
#   (PERSON Joe/NNP)
#   ,/,
#   who/WP
#   is/VBZ
#   with/IN
#   us/PRP
#   (TIME this/DT evening/NN)
#   ,/,
#   a/DT
#   doting/NN
#   mother/NN
#   ,/,
#   (PERSON Nancy/NNP)
#   ,/,
#   and/CC
#   a/DT
#   devoted/JJ
#   sister/NN
#   ,/,
#   (PERSON Lorraine/NNP)
#   ./.
#   He/PRP
#   has/VBZ
#   become/VBN
#   a/DT
#   twinkling/VBG
#   star/NN
#   in/IN
#   the/DT
#   sky/NN
#   for/IN
#   his/PRP$
#   young/JJ
#   niece/NN
#   Ailidh/NNP
#   and/CC
#   young/JJ
#   nephew/NN
#   (PERSON Murray/NNP)
#   ,/,
#   who/WP
#   would/MD
#   describe/VB
#   (PERSON Gordon/NNP)
#   as/IN
#   ``/``
#   Uncle/NNP
#   Gordon/NNP
#   with/IN
#   wheels/NNS
#   ''/''
#   when/WRB
#   he/PRP
#   was/VBD
#   in/IN
#   his/PRP$
#   wheelchair/NN
#   ./.
#   He/PRP
#   leaves/VBZ
#   behind/IN
#   friends/NNS
#   whose/WP$
#   lives/NNS
#   will/MD
#   forever/RB
#   have/VB
#   a/DT
#   Gordon/NNP
#   Aikman-shaped/JJ
#   hole/NN
#   in/IN
#   them/PRP
#   ./.
#   All/DT
#   our/PRP$
#   thoughts/NNS
#   at/IN
#   this/DT
#   time/NN
#   go/VB
#   out/RP
#   to/TO
#   everyone/NN
#   who/WP
#   knew/VBD
#   him/PRP
#   ./.
#   Gordon/NNP
#   leaves/VBZ
#   a/DT
#   legacy/NN
#   that/IN
#   few/JJ
#   of/IN
#   us/PRP
#   will/MD
#   ever/RB
#   be/VB
#   able/JJ
#   to/TO
#   match/VB
#   ./.
#   Gordon/NNP
#   was/VBD
#   an/DT
#   inspiration/NN
#   :/:
#   dedicated/VBN
#   ,/,
#   intelligent/NN
#   ,/,
#   meticulous/JJ
#   and/CC
#   simply/RB
#   a/DT
#   lovely/RB
#   person/NN
#   to/TO
#   be/VB
#   around/RB
#   ./.
#   He/PRP
#   touched/VBD
#   the/DT
#   lives/NNS
#   of/IN
#   everyone/NN
#   who/WP
#   had/VBD
#   the/DT
#   pleasure/NN
#   of/IN
#   getting/VBG
#   to/TO
#   know/VB
#   him/PRP
#   and/CC
#   spend/VB
#   time/NN
#   with/IN
#   him/PRP
#   ./.
#   He/PRP
#   was/VBD
#   a/DT
#   graduate/NN
#   of/IN
#   the/DT
#   (ORGANIZATION University/NNP of/IN Edinburgh/NNP)
#   and/CC
#   a/DT
#   former/JJ
#   gymnast/NN
#   who/WP
#   represented/VBD
#   (LOCATION Scotland/NNP)
#   ./.
#   He/PRP
#   was/VBD
#   working/VBG
#   as/IN
#   director/NN
#   of/IN
#   research/NN
#   for/IN
#   Better/NNP
#   Together/NNP
#   ,/,
#   the/DT
#   campaign/NN
#   to/TO
#   keep/VB
#   (LOCATION Scotland/NNP)
#   in/IN
#   the/DT
#   (ORGANIZATION UK/NNP)
#   ,/,
#   during/IN
#   the/DT
#   Scottish/JJ
#   independence/NN
#   referendum/NN
#   in/IN
#   (DATE 2014/CD)
#   when/WRB
#   he/PRP
#   fell/VBD
#   ill/RB
#   ./.
#   He/PRP
#   had/VBD
#   gone/VBN
#   to/TO
#   the/DT
#   doctors/NNS
#   with/IN
#   recurring/VBG
#   numbness/NN
#   in/IN
#   his/PRP$
#   hands/NNS
#   ./.
#   He/PRP
#   was/VBD
#   beginning/VBG
#   to/TO
#   find/VB
#   it/PRP
#   difficult/JJ
#   to/TO
#   tie/VB
#   his/PRP$
#   shoelaces/NNS
#   and/CC
#   button/VB
#   his/PRP$
#   shirts/NNS
#   ./.
#   He/PRP
#   anticipated/VBD
#   ,/,
#   as/IN
#   we/PRP
#   all/DT
#   do/VBP
#   ,/,
#   that/IN
#   a/DT
#   pack/NN
#   of/IN
#   pills/NNS
#   and/CC
#   a/DT
#   bit/NN
#   of/IN
#   rest/NN
#   would/MD
#   do/VB
#   the/DT
#   trick/NN
#   ./.
#   How/WRB
#   wrong/JJ
#   could/MD
#   he/PRP
#   be/VB
#   ?/.
#   I/PRP
#   can/MD
#   not/RB
#   do/VB
#   justice/NN
#   to/TO
#   what/WP
#   happened/VBD
#   to/TO
#   (LOCATION Gordon/NNP)
#   ,/,
#   so/IN
#   I/PRP
#   will/MD
#   let/VB
#   (PERSON Gordon/NNP)
#   tell/VB
#   his/PRP$
#   own/JJ
#   story/NN
#   in/IN
#   his/PRP$
#   own/JJ
#   words/NNS
#   ,/,
#   quoting/VBG
#   from/IN
#   the/DT
#   moving/VBG
#   (LOCATION Scotland/NNP)
#   on/IN
#   (DATE Sunday/NNP)
#   article/NN
#   he/PRP
#   wrote/VBD
#   in/IN
#   the/DT
#   week/NN
#   he/PRP
#   was/VBD
#   given/VBN
#   the/DT
#   sad/JJ
#   news/NN
#   ./.
#   He/PRP
#   wrote/VBD
#   :/:
#   ``/``
#   I/PRP
#   am/VBP
#   lying/VBG
#   on/IN
#   a/DT
#   cold/JJ
#   hospital/NN
#   bed/NN
#   ,/,
#   stripped/VBD
#   down/RP
#   with/IN
#   electrodes/NNS
#   stuck/VBP
#   all/DT
#   over/IN
#   my/PRP$
#   skin/NN
#   ./.
#   A/DT
#   doctor/NN
#   quietly/RB
#   takes/VBZ
#   notes/NNS
#   as/IN
#   pulses/NNS
#   race/NN
#   through/IN
#   my/PRP$
#   body/NN
#   ./.
#   After/IN
#   almost/RB
#   an/DT
#   hour/NN
#   I/PRP
#   get/VBP
#   back/RB
#   into/IN
#   my/PRP$
#   suit/NN
#   ,/,
#   ready/JJ
#   for/IN
#   a/DT
#   packed/JJ
#   day/NN
#   of/IN
#   calls/NNS
#   and/CC
#   meetings/NNS
#   ./.
#   The/DT
#   doctor/NN
#   steps/VBZ
#   out/RP
#   to/TO
#   speak/VB
#   to/TO
#   my/PRP$
#   consultant/NN
#   ./.
#   I/PRP
#   flick/VBP
#   through/IN
#   the/DT
#   (TIME morning/NN)
#   's/POS
#   headlines/NNS
#   on/IN
#   (DATE Twitter/NNP)
#   and/CC
#   quickly/RB
#   check/VB
#   my/PRP$
#   email/NN
#   as/IN
#   I/PRP
#   wait/VBP
#   ./.
#   In/IN
#   my/PRP$
#   job/NN
#   as/IN
#   director/NN
#   of/IN
#   research/NN
#   at/IN
#   Better/NNP
#   Together/NNP
#   ,/,
#   I/PRP
#   have/VBP
#   got/VBN
#   to/TO
#   be/VB
#   up/RB
#   to/TO
#   date/NN
#   ./.
#   The/DT
#   doctor/NN
#   is/VBZ
#   gone/VBN
#   some/DT
#   time/NN
#   ./.
#   My/PRP$
#   appointment/NN
#   has/VBZ
#   already/RB
#   overrun/VBN
#   ./.
#   I/PRP
#   'm/VBP
#   irritated/JJ
#   ./.
#   He/PRP
#   returns/VBZ
#   and/CC
#   says/VBZ
#   :/:
#   `/``
#   Your/PRP$
#   neurologist/NN
#   would/MD
#   like/VB
#   to/TO
#   see/VB
#   you/PRP
#   at/IN
#   1.15/CD
#   tomorrow/NN
#   ./.
#   '/''
#   `/``
#   Tomorrow/NNP
#   wo/MD
#   n't/RB
#   work/VB
#   ./.
#   I/PRP
#   have/VBP
#   meetings/NNS
#   ./.
#   Meetings/NNS
#   I/PRP
#   ca/MD
#   n't/RB
#   miss/VB
#   ./.
#   '/''
#   He/PRP
#   tilts/VBZ
#   his/PRP$
#   head/NN
#   to/TO
#   one/CD
#   side/NN
#   ,/,
#   holding/VBG
#   my/PRP$
#   stare/NN
#   for/IN
#   what/WP
#   seems/VBZ
#   like/IN
#   an/DT
#   eternity/NN
#   ,/,
#   before/IN
#   stressing/NN
#   :/:
#   `/``
#   Your/PRP$
#   neurologist/NN
#   will/MD
#   see/VB
#   you/PRP
#   tomorrow/NN
#   ./.
#   1.15/CD
#   ./.
#   '/''
#   The/DT
#   penny/NN
#   starts/VBZ
#   to/TO
#   drop/VB
#   ./.
#   Suddenly/RB
#   that/IN
#   conference/NN
#   on/IN
#   the/DT
#   economics/NNS
#   of/IN
#   independence/NN
#   seems/VBZ
#   far/RB
#   less/RBR
#   important/JJ
#   ./.
#   Fast-forward/JJ
#   24/CD
#   hours/NNS
#   and/CC
#   I/PRP
#   am/VBP
#   back/RB
#   at/IN
#   (LOCATION Edinburgh/NNP)
#   's/POS
#   (ORGANIZATION Western/JJ General/NNP)
#   ./.
#   This/DT
#   time/NN
#   I/PRP
#   sit/VBP
#   opposite/JJ
#   my/PRP$
#   consultant/NN
#   neurologist/NN
#   ;/:
#   a/DT
#   young/JJ
#   ,/,
#   caring/VBG
#   face/NN
#   looks/VBZ
#   back/RB
#   ./.
#   He/PRP
#   speaks/VBZ
#   softly/RB
#   ,/,
#   but/CC
#   this/DT
#   time/NN
#   the/DT
#   atmosphere/NN
#   is/VBZ
#   different/JJ
#   ./.
#   He/PRP
#   talks/VBZ
#   slowly/RB
#   ./.
#   He/PRP
#   pauses/VBZ
#   ./.
#   I/PRP
#   know/VBP
#   it/PRP
#   is/VBZ
#   n't/RB
#   good/JJ
#   news/NN
#   ,/,
#   but/CC
#   nothing/NN
#   could/MD
#   prepare/VB
#   me/PRP
#   for/IN
#   what/WP
#   he/PRP
#   is/VBZ
#   about/IN
#   to/TO
#   say/VB
#   ./.
#   Tears/NNS
#   form/VBP
#   in/IN
#   his/PRP$
#   eyes/NNS
#   as/IN
#   he/PRP
#   explains/VBZ
#   that/IN
#   all/PDT
#   the/DT
#   diagnostic/JJ
#   tests/NNS
#   point/VBP
#   to/TO
#   something/NN
#   called/VBN
#   (ORGANIZATION Motor/NNP Neurone/NNP Disease/NNP)
#   or/CC
#   (ORGANIZATION MND/NNP)
#   ./.
#   I/PRP
#   'm/VBP
#   confused/JJ
#   ./.
#   `/``
#   That/DT
#   does/VBZ
#   n't/RB
#   sound/VB
#   good/JJ
#   ,/,
#   '/''
#   I/PRP
#   respond/VBP
#   awkwardly/RB
#   ,/,
#   thinking/VBG
#   to/TO
#   myself/VB
#   :/:
#   `/``
#   I/PRP
#   do/VBP
#   n't/RB
#   have/VB
#   time/NN
#   for/IN
#   this/DT
#   ./.
#   '/''
#   He/PRP
#   asks/VBZ
#   what/WP
#   I/PRP
#   know/VBP
#   about/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   `/``
#   Very/RB
#   little/JJ
#   ,/,
#   '/''
#   is/VBZ
#   my/PRP$
#   honest/JJ
#   answer/NN
#   ./.
#   `/``
#   It/PRP
#   is/VBZ
#   a/DT
#   rare/JJ
#   ,/,
#   progressive/JJ
#   and/CC
#   debilitating/VBG
#   disease/NN
#   ,/,
#   '/''
#   he/PRP
#   explains/VBZ
#   ,/,
#   `/``
#   that/IN
#   attacks/VBZ
#   the/DT
#   brain/NN
#   and/CC
#   spinal/JJ
#   cord/NN
#   ./.
#   '/''
#   I/PRP
#   do/VBP
#   n't/RB
#   believe/VB
#   what/WP
#   he/PRP
#   is/VBZ
#   telling/VBG
#   me/PRP
#   ./.
#   I/PRP
#   shake/VBP
#   my/PRP$
#   head/NN
#   in/IN
#   disbelief/NN
#   ./.
#   `/``
#   In/IN
#   time/NN
#   ,/,
#   '/''
#   he/PRP
#   says/VBZ
#   ,/,
#   `/``
#   it/PRP
#   will/MD
#   lead/VB
#   to/TO
#   weakness/NN
#   ,/,
#   and/CC
#   muscle/NN
#   wasting/NN
#   ,/,
#   '/''
#   affecting/VBG
#   how/WRB
#   I/PRP
#   walk/VBP
#   ,/,
#   talk/NN
#   ,/,
#   eat/NN
#   ,/,
#   drink/NN
#   and/CC
#   breathe/NN
#   ./.
#   How/WRB
#   could/MD
#   this/DT
#   be/VB
#   ?/.
#   My/PRP$
#   symptoms/NNS
#   seemed/VBD
#   so/RB
#   innocuous/JJ
#   ./.
#   `/``
#   Why/WRB
#   me/PRP
#   ?/.
#   Why/WRB
#   now/RB
#   ?/.
#   '/''
#   I/PRP
#   ask/VBP
#   ./.
#   He/PRP
#   bites/VBZ
#   his/PRP$
#   lip/NN
#   ,/,
#   before/IN
#   replying/VBG
#   candidly/RB
#   :/:
#   `/``
#   We/PRP
#   just/RB
#   do/VBP
#   n't/RB
#   know/VB
#   unfortunately/RB
#   ./.
#   '/''
#   When/WRB
#   I/PRP
#   press/VBP
#   further/RB
#   ,/,
#   he/PRP
#   concedes/VBZ
#   :/:
#   `/``
#   There/EX
#   is/VBZ
#   no/DT
#   cure/NN
#   ./.
#   '/''
#   I/PRP
#   cut/VBD
#   to/TO
#   the/DT
#   chase/NN
#   :/:
#   `/``
#   What/WP
#   is/VBZ
#   the/DT
#   prognosis/NN
#   ?/.
#   How/WRB
#   long/RB
#   will/MD
#   I/PRP
#   live/VB
#   ?/.
#   '/''
#   Hesitant/NNP
#   ,/,
#   he/PRP
#   prefixes/VBD
#   his/PRP$
#   answer/NN
#   with/IN
#   `/``
#   everybody/NN
#   is/VBZ
#   different/JJ
#   '/''
#   and/CC
#   `/``
#   it/PRP
#   is/VBZ
#   difficult/JJ
#   to/TO
#   predict/VB
#   '/POS
#   ./.
#   He/PRP
#   then/RB
#   wells/VBZ
#   up/RP
#   before/IN
#   admitting/VBG
#   that/IN
#   we/PRP
#   are/VBP
#   talking/VBG
#   `/``
#   just/RB
#   a/DT
#   few/JJ
#   years/NNS
#   '/POS
#   ./.
#   My/PRP$
#   head/NN
#   is/VBZ
#   a/DT
#   mess/NN
#   ./.
#   I/PRP
#   stand/VBP
#   up/RB
#   ,/,
#   walk/VBP
#   across/IN
#   to/TO
#   the/DT
#   window/NN
#   ,/,
#   run/VB
#   my/PRP$
#   hands/NNS
#   through/IN
#   my/PRP$
#   hair/NN
#   and/CC
#   stare/NN
#   out/RB
#   into/IN
#   the/DT
#   middle/JJ
#   distance/NN
#   ./.
#   My/PRP$
#   mind/NN
#   goes/VBZ
#   blank/JJ
#   ./.
#   I/PRP
#   do/VBP
#   n't/RB
#   know/VB
#   what/WP
#   do/VBP
#   ./.
#   I/PRP
#   'm/VBP
#   29/CD
#   years/NNS
#   old/JJ
#   and/CC
#   I/PRP
#   have/VBP
#   just/RB
#   been/VBN
#   given/VBN
#   a/DT
#   death/NN
#   sentence/NN
#   ./.
#   ''/''
#   Gordon/NNP
#   went/VBD
#   on/IN
#   to/TO
#   write/VB
#   :/:
#   ``/``
#   When/WRB
#   you/PRP
#   are/VBP
#   told/VBN
#   you/PRP
#   are/VBP
#   dying/VBG
#   you/PRP
#   face/VBP
#   a/DT
#   choice/NN
#   :/:
#   you/PRP
#   can/MD
#   wallow/VB
#   in/IN
#   self-pity/NN
#   ,/,
#   or/CC
#   you/PRP
#   can/MD
#   make/VB
#   the/DT
#   most/JJS
#   of/IN
#   what/WP
#   you/PRP
#   've/VBP
#   got/VBN
#   ''/''
#   ./.
#   And/CC
#   my/PRP$
#   goodness/NN
#   ,/,
#   (PERSON Gordon/NNP)
#   certainly/RB
#   made/VBD
#   the/DT
#   most/JJS
#   of/IN
#   what/WP
#   he/PRP
#   had/VBD
#   ./.
#   He/PRP
#   married/VBD
#   his/PRP$
#   husband/NN
#   (PERSON Joe/NNP)
#   and/CC
#   travelled/VBD
#   extensively/RB
#   ./.
#   As/IN
#   we/PRP
#   heard/VBP
#   at/IN
#   the/DT
#   funeral/JJ
#   and/CC
#   the/DT
#   celebration/NN
#   on/IN
#   (DATE Saturday/NNP)
#   ,/,
#   he/PRP
#   travelled/VBD
#   to/TO
#   (LOCATION New/NNP York/NNP)
#   ,/,
#   (LOCATION Boston/NNP)
#   ,/,
#   (LOCATION Amsterdam/NNP)
#   ,/,
#   (LOCATION Dublin/NNP)
#   ,/,
#   (LOCATION Stockholm/NNP)
#   ,/,
#   (LOCATION Madrid/NNP)
#   ,/,
#   (LOCATION Tenerife/NNP)
#   ,/,
#   (LOCATION Prague/NNP)
#   ,/,
#   (LOCATION Tuscany/NNP)
#   ,/,
#   (LOCATION Newquay/NNP)
#   ,/,
#   (LOCATION Paris/NNP)
#   ,/,
#   (ORGANIZATION Cork/NNP)
#   ,/,
#   (LOCATION Munich/NNP)
#   ,/,
#   (LOCATION Orkney/NNP)
#   ,/,
#   (LOCATION Fort/NNP William/NNP)
#   and/CC
#   (LOCATION California/NNP)
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   (LOCATION Israel/NNP)
#   ,/,
#   (LOCATION South/NNP Africa/NNP)
#   ,/,
#   (LOCATION Switzerland/NNP)
#   ,/,
#   and/CC
#   had/VBD
#   a/DT
#   trip/NN
#   on/IN
#   the/DT
#   Queen/NNP
#   (PERSON Mary/NNP II/NNP)
#   and/CC
#   a/DT
#   break/NN
#   in/IN
#   (LOCATION Iceland/NNP)
#   to/TO
#   see/VB
#   the/DT
#   northern/JJ
#   lights/NNS
#   ./.
#   If/IN
#   I/PRP
#   have/VBP
#   missed/VBN
#   any/DT
#   ,/,
#   I/PRP
#   apologise/VBP
#   ./.
#   He/PRP
#   also/RB
#   spent/VBD
#   as/IN
#   much/JJ
#   time/NN
#   as/IN
#   he/PRP
#   could/MD
#   with/IN
#   his/PRP$
#   family/NN
#   and/CC
#   his/PRP$
#   friends/NNS
#   ./.
#   With/IN
#   all/DT
#   of/IN
#   that/DT
#   ,/,
#   (PERSON Gordon/NNP)
#   was/VBD
#   determined/VBN
#   to/TO
#   ensure/VB
#   that/IN
#   those/DT
#   who/WP
#   suffered/VBD
#   from/IN
#   (ORGANIZATION MND/NNP)
#   got/VBD
#   the/DT
#   best/JJS
#   care/NN
#   ,/,
#   the/DT
#   best/JJS
#   deal/NN
#   and/CC
#   the/DT
#   hope/NN
#   of/IN
#   a/DT
#   cure/NN
#   in/IN
#   the/DT
#   future/NN
#   ./.
#   Understanding/VBG
#   lies/NNS
#   at/IN
#   the/DT
#   root/NN
#   of/IN
#   all/DT
#   human/JJ
#   endeavour/NN
#   ./.
#   In/IN
#   order/NN
#   to/TO
#   defeat/VB
#   something/NN
#   ,/,
#   we/PRP
#   must/MD
#   find/VB
#   out/RP
#   what/WP
#   it/PRP
#   is/VBZ
#   first/JJ
#   ,/,
#   so/RB
#   here/RB
#   is/VBZ
#   what/WP
#   we/PRP
#   do/VBP
#   know/VB
#   and/CC
#   ,/,
#   most/JJS
#   importantly/RB
#   for/IN
#   tonight/NN
#   's/POS
#   debate/NN
#   ,/,
#   what/WP
#   we/PRP
#   do/VBP
#   not/RB
#   know/VB
#   about/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   (PERSON Chris/NNP Stephens/NNP)
#   -LRB-/NNP
#   (LOCATION Glasgow/NNP South/NNP West/NNP)
#   -RRB-/NNP
#   -LRB-/NNP
#   SNP/NNP
#   -RRB-/NNP
#   I/PRP
#   congratulate/VBP
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   on/IN
#   securing/VBG
#   this/DT
#   debate/NN
#   ./.
#   I/PRP
#   agree/VBP
#   with/IN
#   him/PRP
#   that/IN
#   (PERSON Gordon/NNP Aikman/NNP)
#   was/VBD
#   indeed/RB
#   an/DT
#   inspiration/NN
#   ./.
#   Does/VBZ
#   he/PRP
#   agree/VB
#   that/IN
#   his/PRP$
#   campaigning/NN
#   work/NN
#   ,/,
#   particularly/RB
#   with/IN
#   the/DT
#   (ORGANIZATION First/NNP Minister/NNP of/IN Scotland/NNP)
#   ,/,
#   ensuring/VBG
#   changes/NNS
#   to/TO
#   the/DT
#   law/NN
#   around/IN
#   voice/NN
#   therapy/NN
#   ,/,
#   for/IN
#   example/NN
#   ,/,
#   and/CC
#   doubling/VBG
#   the/DT
#   number/NN
#   of/IN
#   specialist/JJ
#   nurses/NNS
#   ,/,
#   was/VBD
#   important/JJ
#   to/TO
#   his/PRP$
#   campaign/NN
#   ?/.
#   (PERSON Ian/NNP Murray/NNP)
#   I/PRP
#   do/VBP
#   agree/RB
#   ,/,
#   and/CC
#   I/PRP
#   am/VBP
#   delighted/JJ
#   that/IN
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   was/VBD
#   able/JJ
#   to/TO
#   make/VB
#   that/DT
#   point/NN
#   ,/,
#   but/CC
#   as/IN
#   the/DT
#   (ORGANIZATION First/NNP Minister/NNP)
#   said/VBD
#   on/IN
#   (DATE Saturday/NNP)
#   at/IN
#   the/DT
#   celebration/NN
#   of/IN
#   (PERSON Gordon/NNP)
#   's/POS
#   life/NN
#   ,/,
#   all/PDT
#   the/DT
#   credit/NN
#   for/IN
#   those/DT
#   changes/NNS
#   to/TO
#   care/VB
#   in/IN
#   (LOCATION Scotland/NNP)
#   goes/VBZ
#   to/TO
#   (PERSON Gordon/NNP)
#   and/CC
#   his/PRP$
#   campaign/NN
#   ./.
#   There/EX
#   is/VBZ
#   a/DT
#   need/NN
#   for/IN
#   us/PRP
#   all/DT
#   now/RB
#   to/TO
#   take/VB
#   that/DT
#   campaign/NN
#   and/CC
#   make/VB
#   sure/JJ
#   that/IN
#   the/DT
#   rest/NN
#   is/VBZ
#   delivered/VBN
#   ./.
#   Researchers/NNS
#   have/VBP
#   yet/RB
#   to/TO
#   discover/VB
#   how/WRB
#   or/CC
#   why/WRB
#   people/NNS
#   develop/VBP
#   the/DT
#   disease/NN
#   ./.
#   In/IN
#   (PERSON Gordon/NNP)
#   's/POS
#   case/NN
#   and/CC
#   in/IN
#   around/RB
#   (PERCENT 95/CD %/NN)
#   of/IN
#   diagnoses/NNS
#   ,/,
#   there/EX
#   is/VBZ
#   no/DT
#   family/NN
#   history/NN
#   of/IN
#   the/DT
#   condition/NN
#   ./.
#   (ORGANIZATION MND/NNP)
#   is/VBZ
#   a/DT
#   fatal/JJ
#   ,/,
#   rapidly/RB
#   progressing/VBG
#   neurological/JJ
#   disease/NN
#   that/WDT
#   affects/VBZ
#   the/DT
#   brain/NN
#   and/CC
#   spinal/JJ
#   cord/NN
#   ./.
#   It/PRP
#   can/MD
#   leave/VB
#   people/NNS
#   locked/VBN
#   in/IN
#   a/DT
#   failing/NN
#   body/NN
#   ,/,
#   unable/JJ
#   to/TO
#   move/VB
#   ,/,
#   talk/NN
#   or/CC
#   ,/,
#   eventually/RB
#   ,/,
#   breathe/NN
#   ./.
#   It/PRP
#   kills/VBZ
#   a/DT
#   third/JJ
#   of/IN
#   people/NNS
#   within/IN
#   a/DT
#   year/NN
#   and/CC
#   more/JJR
#   than/IN
#   (PERCENT 50/CD %/NN)
#   within/IN
#   two/CD
#   years/NNS
#   of/IN
#   diagnosis/NN
#   ./.
#   It/PRP
#   affects/VBZ
#   up/IN
#   to/TO
#   5,000/CD
#   adults/NNS
#   at/IN
#   any/DT
#   one/CD
#   time/NN
#   in/IN
#   the/DT
#   UK/NNP
#   and/CC
#   kills/NNS
#   six/CD
#   people/NNS
#   every/DT
#   day/NN
#   in/IN
#   the/DT
#   UK/NNP
#   ./.
#   Mark/NNP
#   (PERSON Menzies/NNP)
#   -LRB-/NNP
#   Fylde/NNP
#   -RRB-/NNP
#   -LRB-/NNP
#   Con/NNP
#   -RRB-/NNP
#   I/PRP
#   thank/VBD
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   for/IN
#   securing/VBG
#   this/DT
#   evening/NN
#   's/POS
#   debate/NN
#   ./.
#   I/PRP
#   never/RB
#   met/VBD
#   (PERSON Gordon/NNP)
#   ,/,
#   but/CC
#   I/PRP
#   have/VBP
#   been/VBN
#   inspired/VBN
#   by/IN
#   what/WP
#   I/PRP
#   have/VBP
#   found/VBN
#   out/RP
#   about/IN
#   him/PRP
#   in/IN
#   the/DT
#   last/JJ
#   two/CD
#   weeks/NNS
#   ./.
#   We/PRP
#   all/DT
#   come/VBP
#   across/IN
#   constituents/NNS
#   who/WP
#   will/MD
#   face/VB
#   life-changing/JJ
#   situations/NNS
#   ,/,
#   and/CC
#   (PERSON Gordon/NNP)
#   will/MD
#   become/VB
#   the/DT
#   reference/NN
#   point/NN
#   ./.
#   I/PRP
#   will/MD
#   refer/VB
#   people/NNS
#   to/TO
#   what/WP
#   he/PRP
#   did/VBD
#   ,/,
#   how/WRB
#   he/PRP
#   coped/VBD
#   with/IN
#   adversity/NN
#   and/CC
#   how/WRB
#   he/PRP
#   helped/VBD
#   to/TO
#   improve/VB
#   and/CC
#   change/VB
#   the/DT
#   lives/NNS
#   of/IN
#   others/NNS
#   ./.
#   If/IN
#   I/PRP
#   may/MD
#   also/RB
#   say/VB
#   in/IN
#   this/DT
#   intervention/NN
#   ,/,
#   Madam/NNP
#   Deputy/NNP
#   Speaker/NNP
#   ,/,
#   I/PRP
#   would/MD
#   urge/VB
#   the/DT
#   Minister/NNP
#   to/TO
#   look/VB
#   at/IN
#   the/DT
#   (PERSON Gordon/NNP)
#   's/POS
#   Fightback/NNP
#   website/NN
#   and/CC
#   take/VB
#   on/IN
#   board/NN
#   some/DT
#   of/IN
#   the/DT
#   points/NNS
#   that/IN
#   he/PRP
#   raised/VBD
#   ,/,
#   because/IN
#   we/PRP
#   have/VBP
#   much/JJ
#   to/TO
#   learn/VB
#   from/IN
#   what/WP
#   he/PRP
#   told/VBD
#   us/PRP
#   ./.
#   (PERSON Ian/NNP Murray/NNP)
#   I/PRP
#   am/VBP
#   delighted/VBN
#   at/IN
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   's/POS
#   intervention/NN
#   ;/:
#   he/PRP
#   is/VBZ
#   indeed/RB
#   right/JJ
#   ./.
#   Many/JJ
#   people/NNS
#   have/VBP
#   drawn/VBN
#   inspiration/NN
#   from/IN
#   (PERSON Gordon/NNP)
#   's/POS
#   Fightback/NNP
#   ,/,
#   the/DT
#   way/NN
#   in/IN
#   which/WDT
#   he/PRP
#   dealt/VBZ
#   with/IN
#   the/DT
#   disease/NN
#   ,/,
#   the/DT
#   dignity/NN
#   with/IN
#   which/WDT
#   he/PRP
#   did/VBD
#   so/RB
#   ,/,
#   and/CC
#   the/DT
#   fact/NN
#   that/IN
#   he/PRP
#   spent/VBD
#   his/PRP$
#   remaining/JJ
#   time/NN
#   fighting/VBG
#   to/TO
#   raise/VB
#   over/RP
#   half/PDT
#   a/DT
#   million/CD
#   pounds/NNS
#   for/IN
#   the/DT
#   things/NNS
#   that/IN
#   he/PRP
#   believed/VBD
#   in/IN
#   ,/,
#   when/WRB
#   most/JJS
#   of/IN
#   us/PRP
#   would/MD
#   have/VB
#   been/VBN
#   lesser/JJR
#   human/JJ
#   beings/NNS
#   and/CC
#   wallowed/VBN
#   in/IN
#   self-pity/NN
#   or/CC
#   done/VBN
#   something/NN
#   else/RB
#   ./.
#   It/PRP
#   is/VBZ
#   testament/JJ
#   to/TO
#   that/IN
#   that/DT
#   we/PRP
#   have/VBP
#   the/DT
#   (ORGANIZATION Secretary/NNP of/IN State/NNP)
#   for/IN
#   (LOCATION Scotland/NNP)
#   and/CC
#   the/DT
#   Minister/NNP
#   in/IN
#   the/DT
#   Chamber/NNP
#   tonight/VBD
#   listening/VBG
#   to/TO
#   the/DT
#   debate/NN
#   ./.
#   Hopefully/NNP
#   the/DT
#   Minister/NNP
#   will/MD
#   be/VB
#   able/JJ
#   to/TO
#   respond/VB
#   with/IN
#   some/DT
#   positive/JJ
#   developments/NNS
#   to/TO
#   keep/VB
#   (PERSON Gordon/NNP)
#   's/POS
#   memory/NN
#   alive/JJ
#   ./.
#   Some/DT
#   people/NNS
#   may/MD
#   experience/VB
#   changes/NNS
#   in/IN
#   thinking/NN
#   and/CC
#   behaviour/NN
#   ,/,
#   with/IN
#   a/DT
#   proportion/NN
#   experiencing/VBG
#   frontotemporal/JJ
#   dementia/NN
#   ,/,
#   which/WDT
#   is/VBZ
#   a/DT
#   rare/JJ
#   form/NN
#   of/IN
#   dementia/NN
#   ./.
#   This/DT
#   is/VBZ
#   the/DT
#   key/JJ
#   thing/NN
#   about/IN
#   (ORGANIZATION MND/NNP)
#   ,/,
#   though/IN
#   :/:
#   it/PRP
#   has/VBZ
#   no/DT
#   cure/NN
#   ./.
#   It/PRP
#   is/VBZ
#   that/IN
#   last/JJ
#   point/NN
#   that/WDT
#   drove/VBD
#   (PERSON Gordon/NNP)
#   on/IN
#   ./.
#   He/PRP
#   was/VBD
#   a/DT
#   tireless/NN
#   and/CC
#   courageous/JJ
#   campaigner/NN
#   on/IN
#   behalf/NN
#   of/IN
#   people/NNS
#   living/VBG
#   with/IN
#   (ORGANIZATION MND/NNP)
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   their/PRP$
#   families/NNS
#   and/CC
#   loved/JJ
#   ones/NNS
#   ./.
#   He/PRP
#   created/VBD
#   his/PRP$
#   (PERSON Gordon/NNP)
#   's/POS
#   Fightback/NNP
#   campaign/NN
#   ,/,
#   which/WDT
#   we/PRP
#   have/VBP
#   heard/VBN
#   about/IN
#   tonight/NN
#   ,/,
#   and/CC
#   his/PRP$
#   tenacious/JJ
#   work/NN
#   with/IN
#   (ORGANIZATION MND/NNP)
#   (LOCATION Scotland/NNP)
#   was/VBD
#   inspirational/JJ
#   to/TO
#   many/JJ
#   and/CC
#   helped/VBD
#   to/TO
#   raise/VB
#   awareness/NN
#   of/IN
#   (ORGANIZATION MND/NNP)
#   across/IN
#   the/DT
#   country/NN
#   ./.
#   Gordon/NNP
#   had/VBD
#   raised/VBN
#   over/IN
#   #/#
#   500,000/CD
#   by/IN
#   the/DT
#   time/NN
#   he/PRP
#   died/VBD
#   --/:
#   more/RBR
#   now/RB
#   ,/,
#   incidentally/RB
#   --/:
#   but/CC
#   he/PRP
#   had/VBD
#   also/RB
#   put/VBN
#   (ORGANIZATION MND/NNP)
#   on/IN
#   the/DT
#   map/NN
#   ./.
#   Remember/VB
#   the/DT
#   ice/NN
#   bucket/NN
#   challenge/NN
#   ,/,
#   Madam/NNP
#   Deputy/NNP
#   Speaker/NNP
#   ?/.
#   I/PRP
#   do/VBP
#   not/RB
#   know/VB
#   whether/IN
#   you/PRP
#   participated/VBD
#   yourself/PRP
#   --/:
#   if/IN
#   not/RB
#   ,/,
#   we/PRP
#   could/MD
#   maybe/RB
#   go/VB
#   into/IN
#   (ORGANIZATION Palace/NNP Yard/NNP)
#   after/IN
#   this/DT
#   debate/NN
#   and/CC
#   relive/VB
#   what/WP
#   happened/VBD
#   in/IN
#   (DATE 2014/CD)
#   --/:
#   but/CC
#   that/DT
#   was/VBD
#   the/DT
#   (DATE summer/NN)
#   campaign/NN
#   ,/,
#   where/WRB
#   we/PRP
#   all/DT
#   soaked/VBD
#   each/DT
#   other/JJ
#   with/IN
#   iced/JJ
#   water/NN
#   in/IN
#   the/DT
#   name/NN
#   of/IN
#   (ORGANIZATION MND/NNP)
#   awareness/NN
#   and/CC
#   fundraising/NN
#   ./.
#   It/PRP
#   was/VBD
#   with/IN
#   campaigns/NNS
#   such/JJ
#   as/IN
#   these/DT
#   that/IN
#   (PERSON Gordon/NNP)
#   doubled/VBD
#   the/DT
#   number/NN
#   of/IN
#   --/:
#   Madam/NNP
#   Deputy/NNP
#   Speaker/NNP
#   -LRB-/NNP
#   Mrs/NNP
#   (PERSON Eleanor/NNP Laing/NNP)
#   -RRB-/NNP
#   Order/NNP
#   ./.
#   For/IN
#   the/DT
#   avoidance/NN
#   of/IN
#   doubt/NN
#   ,/,
#   I/PRP
#   am/VBP
#   glad/JJ
#   that/IN
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   has/VBZ
#   mentioned/VBN
#   this/DT
#   ./.
#   Never/NNP
#   was/VBD
#   there/EX
#   a/DT
#   better/JJR
#   campaign/NN
#   to/TO
#   draw/VB
#   attention/NN
#   to/TO
#   something/NN
#   that/WDT
#   needed/VBD
#   attention/NN
#   drawn/NN
#   to/TO
#   it/PRP
#   ./.
#   Although/IN
#   I/PRP
#   managed/VBD
#   to/TO
#   avoid/VB
#   it/PRP
#   myself/PRP
#   ,/,
#   I/PRP
#   did/VBD
#   engineer/VB
#   other/JJ
#   people/NNS
#   's/POS
#   participation/NN
#   ./.
#   The/DT
#   hon./NN
#   Gentleman/NNP
#   has/VBZ
#   done/VBN
#   very/RB
#   well/RB
#   to/TO
#   mention/VB
#   this/DT
#   issue/NN
#   today/NN
#   ./.
#   I/PRP
#   had/VBD
#   not/RB
#   realised/VBN
#   that/IN
#   the/DT
#   two/CD
#   things/NNS
#   were/VBD
#   connected/VBN
#   ./.
#   What/WP
#   an/DT
#   absolutely/RB
#   brilliant/JJ
#   campaign/NN
#   ./.
#   (PERSON Ian/NNP Murray/NNP)
#   I/PRP
#   am/VBP
#   delighted/JJ
#   ,/,
#   Madam/NNP
#   Deputy/NNP
#   Speaker/NNP
#   ,/,
#   that/IN
#   you/PRP
#   are/VBP
#   now/RB
#   able/JJ
#   to/TO
#   make/VB
#   the/DT
#   connection/NN
#   between/IN
#   that/DT
#   campaign/NN
#   and/CC
#   (PERSON Gordon/NNP)
#   's/POS
#   Fightback/NNP
#   ,/,
#   and/CC
#   are/VBP
#   aware/JJ
#   of/IN
#   the/DT
#   significant/JJ
#   amount/NN
#   of/IN
#   money/NN
#   that/WDT
#   was/VBD
#   raised/VBN
#   in/IN
#   (DATE 2014/CD)
#   ./.
#   I/PRP
#   do/VBP
#   not/RB
#   think/VB
#   there/EX
#   was/VBD
#   ever/RB
#   an/DT
#   end-point/NN
#   to/TO
#   the/DT
#   ice/NN
#   bucket/NN
#   challenge/NN
#   ./.
#   If/IN
#   there/EX
#   was/VBD
#   an/DT
#   end-point/JJ
#   ,/,
#   perhaps/RB
#   someone/NN
#   from/IN
#   MND/NNP
#   (LOCATION Scotland/NNP)
#   could/MD
#   let/VB
#   me/PRP
#   know/VB
#   ./.
#   I/PRP
#   think/VBP
#   the/DT
#   way/NN
#   it/PRP
#   went/VBD
#   was/VBD
#   that/IN
#   if/IN
#   someone/NN
#   was/VBD
#   soaked/VBN
#   ,/,
#   they/PRP
#   nominated/VBD
#   others/NNS
#   ,/,
#   as/IN
#   indeed/RB
#   you/PRP
#   have/VBP
#   done/VBN
#   Madam/NNP
#   Deputy/NNP
#   Speaker/NNP
#   ./.
#   With/IN
#   the/DT
#   grace/NN
#   of/IN
#   the/DT
#   (ORGANIZATION House/NNP)
#   therefore/NN
#   ,/,
#   I/PRP
#   would/MD
#   like/VB
#   to/TO
#   nominate/VB
#   Madam/NNP
#   Deputy/NNP
#   Speaker/NNP
#   to/TO
#   do/VB
#   the/DT
#   bucket/NN
#   challenge/NN
#   ./.
#   I/PRP
#   think/VBP
#   the/DT
#   terminology/NN
#   is/VBZ
#   ,/,
#   Madam/NNP
#   Deputy/NNP
#   Speaker/NNP
#   ,/,
#   ``/``
#   You/PRP
#   have/VBP
#   seven/CD
#   days/NNS
#   ''/''
#   ./.
#   That/DT
#   ,/,
#   then/RB
#   ,/,
#   was/VBD
#   the/DT
#   (DATE summer/NN)
#   campaign/NN
#   when/WRB
#   we/PRP
#   all/DT
#   soaked/VBD
#   each/DT
#   other/JJ
#   with/IN
#   iced/JJ
#   water/NN
#   in/IN
#   the/DT
#   name/NN
#   of/IN
#   (ORGANIZATION MND/NNP)
#   awareness/NN
#   and/CC
#   fundraising/NN
#   ./.
#   It/PRP
#   was/VBD
#   through/IN
#   campaigns/NNS
#   such/JJ
#   as/IN
#   these/DT
#   that/IN
#   (PERSON Gordon/NNP)
#   doubled/VBD
#   the/DT
#   number/NN
#   of/IN
#   specialist/JJ
#   nurses/NNS
#   in/IN
#   (LOCATION Scotland/NNP)
#   ,/,
#   paid/VBN
#   for/IN
#   by/IN
#   the/DT
#   (ORGANIZATION NHS/NNP)
#   rather/RB
#   than/IN
#   by/IN
#   charitable/JJ
#   donations/NNS
#   ./.
#   Among/IN
#   (PERSON Gordon/NNP)
#   's/POS
#   more/RBR
#   recent/JJ
#   achievements/NNS
#   was/VBD
#   ensuring/VBG
#   that/IN
#   (ORGANIZATION MND/NNP)
#   patients/NNS
#   with/IN
#   communication/NN
#   difficulties/NNS
#   had/VBD
#   access/NN
#   to/TO
#   their/PRP$
#   own/JJ
#   voice/NN
#   synthesizers/NNS
#   on/IN
#   the/DT
#   (ORGANIZATION NHS/NNP)
#   ./.
#   It/PRP
#   was/VBD
#   (PERSON Gordon/NNP)
#   's/POS
#   biggest/JJS
#   fear/NN
#   --/:
#   not/RB
#   just/RB
#   losing/VBG
#   his/PRP$
#   own/JJ
#   voice/NN
#   ,/,
#   but/CC
#   the/DT
#   synthesisation/NN
#   of/IN
#   his/PRP$
#   own/JJ
#   voice/NN
#   being/VBG
#   someone/NN
#   else/RB
#   's/POS
#   ./.
#   He/PRP
#   fought/VBD
#   for/IN
#   that/DT
#   and/CC
#   got/VBD
#   it/PRP
#   changed/VBD
#   ./.
#   Despite/IN
#   those/DT
#   and/CC
#   other/JJ
#   improvements/NNS
#   ,/,
#   however/RB
#   ,/,
#   there/EX
#   is/VBZ
#   still/RB
#   much/RB
#   more/JJR
#   to/TO
#   be/VB
#   done/VBN
#   in/IN
#   the/DT
#   battle/NN
#   to/TO
#   defeat/VB
#   (ORGANIZATION MND/NNP)
#   ./.
#   First/NNP
#   and/CC
#   foremost/RB
#   ,/,
#   if/IN
#   we/PRP
#   are/VBP
#   to/TO
#   find/VB
#   a/DT
#   cure/NN
#   for/IN
#   (ORGANIZATION MND/NNP)
#   ,/,
#   we/PRP
#   must/MD
#   vastly/RB
#   improve/VB
#   our/PRP$
#   understanding/NN
#   of/IN
#   its/PRP$
#   root/NN
#   causes/NNS
#   ,/,
#   and/CC
#   it/PRP
#   is/VBZ
#   here/RB
#   that/IN
#   I/PRP
#   hope/VBP
#   the/DT
#   Minister/NNP
#   can/MD
#   help/VB
#   us/PRP
#   (TIME this/DT evening/NN)
#   ./.
#   (ORGANIZATION MND/NNP)
#   is/VBZ
#   a/DT
#   question/NN
#   to/TO
#   which/WDT
#   we/PRP
#   have/VBP
#   yet/RB
#   to/TO
#   find/VB
#   a/DT
#   suitable/JJ
#   answer/NN
#   ./.
#   Researchers/NNS
#   still/RB
#   do/VBP
#   not/RB
#   know/VB
#   what/WP
#   causes/VBZ
#   the/DT
#   disease/NN
#   ./.
#   A/DT
#   key/JJ
#   recommendation/NN
#   of/IN
#   the/DT
#   (PERSON Gordon/NNP)
#   's/POS
#   Fightback/NNP
#   campaign/NN
#   is/VBZ
#   to/TO
#   double/VB
#   public/JJ
#   investment/NN
#   in/IN
#   (ORGANIZATION MND/NNP)
#   research/NN
#   from/IN
#   its/PRP$
#   current/JJ
#   level/NN
#   of/IN
#   (MONEY #/# 5/CD million/CD)
#   a/DT
#   year/NN
#   to/TO
#   (MONEY #/# 10/CD million/CD)
#   a/DT
#   year/NN
#   ./.
#   Unlike/IN
#   some/DT
#   of/IN
#   (PERSON Gordon/NNP)
#   's/POS
#   wonderful/JJ
#   achievements/NNS
#   that/IN
#   we/PRP
#   have/VBP
#   highlighted/VBN
#   (TIME this/DT evening/NN)
#   ,/,
#   there/EX
#   has/VBZ
#   to/TO
#   date/NN
#   been/VBN
#   no/DT
#   action/NN
#   taken/VBN
#   to/TO
#   meet/VB
#   that/DT
#   goal/NN
#   ./.
#   At/IN
#   present/JJ
#   ,/,
#   (ORGANIZATION MND/NNP)
#   research/NN
#   relies/VBZ
#   heavily/RB
#   on/IN
#   the/DT
#   support/NN
#   and/CC
#   contributions/NNS
#   of/IN
#   the/DT
#   voluntary/JJ
#   sector/NN
#   ./.
#   The/DT
#   (ORGANIZATION MND/NNP Association/NNP)
#   ,/,
#   sister/NN
#   associations/NNS
#   in/IN
#   (LOCATION England/NNP)
#   and/CC
#   (LOCATION Wales/NNP)
#   and/CC
#   MND/NNP
#   (LOCATION Scotland/NNP)
#   have/VBP
#   a/DT
#   research/NN
#   portfolio/NN
#   comprising/NN
#   over/IN
#   80/CD
#   projects/NNS
#   ,/,
#   totalling/VBG
#   over/IN
#   (MONEY #/# 14/CD million/CD)
#   of/IN
#   charitable/JJ
#   funds/NNS
#   ,/,
#   including/VBG
#   (MONEY #/# 5/CD million/CD)
#   raised/VBN
#   by/IN
#   the/DT
#   very/RB
#   ice/JJ
#   bucket/NN
#   challenge/NN
#   in/IN
#   which/WDT
#   you/PRP
#   will/MD
#   participate/VB
#   ,/,
#   Madam/NNP
#   Deputy/NNP
#   Speaker/NNP
#   ,/,
#   in/IN
#   the/DT
#   next/JJ
#   seven/CD
#   days/NNS
#   ./.
#   The/DT
#   association/NN
#   's/POS
#   support/NN
#   for/IN
#   (ORGANIZATION MND/NNP)
#   research/NN
#   focuses/VBZ
#   on/IN
#   five/CD
#   key/JJ
#   themes/NNS
#   ./.
#   I/PRP
#   am/VBP
#   conscious/JJ
#   ,/,
#   (ORGANIZATION Madam/NNP Deputy/NNP Speaker/NNP)
#   ,/,
#   that/IN
#   this/DT
#   might/MD
#   be/VB
#   my/PRP$
#   last/JJ
#   ever/RB
#   speech/RB
#   in/IN
#   this/DT
#   Chamber/NNP
#   ,/,
#   but/CC
#   I/PRP
#   shall/MD
#   carry/VB
#   on/IN
#   regardless/NN
#   ./.
#   The/DT
#   five/CD
#   themes/NNS
#   are/VBP
#   identifying/VBG
#   the/DT
#   causes/NNS
#   of/IN
#   (ORGANIZATION MND/NNP)
#   ;/:
#   developing/VBG
#   models/NNS
#   of/IN
#   (ORGANIZATION MND/NNP)
#   ;/:
#   identifying/VBG
#   markers/NNS
#   of/IN
#   disease/NN
#   progression/NN
#   ;/:
#   developing/VBG
#   treatments/NNS
#   ;/:
#   and/CC
#   improving/VBG
#   healthcare/NN
#   and/CC
#   disease/NN
#   management/NN
#   for/IN
#   those/DT
#   affected/JJ
#   ./.
#   We/PRP
#   have/VBP
#   a/DT
#   real/JJ
#   opportunity/NN
#   to/TO
#   embrace/VB
#   the/DT
#   leading/VBG
#   research/NN
#   base/NN
#   in/IN
#   this/DT
#   country/NN
#   to/TO
#   do/VB
#   just/RB
#   that/DT
#   ./.
#   For/IN
#   centuries/NNS
#   ,/,
#   major/JJ
#   leaps/NNS
#   forward/RB
#   in/IN
#   medicine/NN
#   and/CC
#   science/NN
#   have/VBP
#   been/VBN
#   made/VBN
#   in/IN
#   the/DT
#   (ORGANIZATION UK/NNP)
#   ./.
#   With/IN
#   the/DT
#   right/JJ
#   investment/NN
#   and/CC
#   support/NN
#   ,/,
#   we/PRP
#   could/MD
#   find/VB
#   a/DT
#   cure/NN
#   for/IN
#   (ORGANIZATION MND/NNP)
#   here/RB
#   now/RB
#   ./.
#   (LOCATION Scotland/NNP)
#   is/VBZ
#   uniquely/RB
#   placed/VBN
#   to/TO
#   become/VB
#   a/DT
#   hub/NN
#   for/IN
#   innovative/JJ
#   research/NN
#   into/IN
#   the/DT
#   disease/NN
#   for/IN
#   a/DT
#   number/NN
#   of/IN
#   reasons/NNS
#   ./.
#   (ORGANIZATION Edinburgh/NNP University/NNP)
#   's/POS
#   (PERSON Euan/NNP MacDonald/NNP)
#   centre/NN
#   is/VBZ
#   already/RB
#   undertaking/JJ
#   cutting-edge/JJ
#   research/NN
#   into/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   Patients/NNS
#   already/RB
#   have/VBP
#   a/DT
#   unique/JJ
#   patient/NN
#   identifier/NN
#   ,/,
#   which/WDT
#   means/VBZ
#   those/DT
#   with/IN
#   (ORGANIZATION MND/NNP)
#   can/MD
#   be/VB
#   more/RBR
#   easily/RB
#   identified/VBN
#   and/CC
#   monitored/VBN
#   throughout/IN
#   their/PRP$
#   interaction/NN
#   with/IN
#   the/DT
#   health/NN
#   service/NN
#   ./.
#   The/DT
#   increased/JJ
#   number/NN
#   of/IN
#   specialist/JJ
#   (ORGANIZATION MND/NNP)
#   nurses/NNS
#   will/MD
#   allow/VB
#   better/JJR
#   ,/,
#   more/RBR
#   detailed/JJ
#   tracking/NN
#   of/IN
#   how/WRB
#   the/DT
#   disease/NN
#   progresses/VBZ
#   in/IN
#   patients/NNS
#   ./.
#   Progress/NNP
#   has/VBZ
#   been/VBN
#   made/VBN
#   ./.
#   The/DT
#   (PERSON Euan/JJ MacDonald/NNP)
#   centre/NN
#   thinks/VBZ
#   it/PRP
#   might/MD
#   have/VB
#   found/VBN
#   a/DT
#   potential/JJ
#   reason/NN
#   why/WRB
#   motor/NN
#   neurons/NNS
#   are/VBP
#   vulnerable/JJ
#   to/TO
#   stress/VB
#   and/CC
#   disease/VB
#   ,/,
#   which/WDT
#   could/MD
#   be/VB
#   one/CD
#   of/IN
#   the/DT
#   very/RB
#   first/JJ
#   steps/NNS
#   to/TO
#   avoiding/VBG
#   or/CC
#   halting/VBG
#   the/DT
#   progression/NN
#   of/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   This/DT
#   collaborative/JJ
#   project/NN
#   ,/,
#   involving/VBG
#   the/DT
#   universities/NNS
#   of/IN
#   (LOCATION Edinburgh/NNP)
#   and/CC
#   (LOCATION Cambridge/NNP)
#   and/CC
#   institutions/NNS
#   as/IN
#   far/RB
#   afield/NN
#   as/IN
#   (LOCATION Japan/NNP)
#   ,/,
#   is/VBZ
#   also/RB
#   helping/VBG
#   understand/VB
#   how/WRB
#   motor/NN
#   neurons/NNS
#   develop/VBP
#   and/CC
#   regenerate/VBP
#   ./.
#   The/DT
#   cure/NN
#   could/MD
#   be/VB
#   in/IN
#   this/DT
#   generation/NN
#   's/POS
#   hands/NNS
#   ./.
#   Funding/VBG
#   in/IN
#   the/DT
#   (LOCATION United/NNP States/NNPS)
#   --/:
#   where/WRB
#   the/DT
#   (ORGANIZATION ALS/NNP Association/NNP)
#   ,/,
#   the/DT
#   (LOCATION US/NNP)
#   equivalent/NN
#   of/IN
#   the/DT
#   (ORGANIZATION MND/NNP Association/NNP)
#   ,/,
#   has/VBZ
#   identified/VBN
#   a/DT
#   key/JJ
#   genome/NN
#   with/IN
#   funds/NNS
#   raised/VBN
#   by/IN
#   the/DT
#   (LOCATION US/NNP)
#   bucket/NN
#   challenge/NN
#   --/:
#   could/MD
#   be/VB
#   the/DT
#   first/JJ
#   step/NN
#   towards/NNS
#   a/DT
#   cure/NN
#   ./.
#   As/RB
#   well/RB
#   as/IN
#   doubling/VBG
#   public/JJ
#   research/NN
#   funding/NN
#   ,/,
#   the/DT
#   Minister/NNP
#   could/MD
#   help/VB
#   by/IN
#   making/VBG
#   ``/``
#   fast-track/JJ
#   ''/''
#   benefits/NNS
#   fit/VBP
#   for/IN
#   purpose/NN
#   ./.
#   People/NNS
#   with/IN
#   (ORGANIZATION MND/NNP)
#   do/VBP
#   not/RB
#   live/VB
#   long/RB
#   --/:
#   we/PRP
#   know/VBP
#   that/DT
#   --/:
#   but/CC
#   it/PRP
#   can/MD
#   take/VB
#   several/JJ
#   months/NNS
#   to/TO
#   process/VB
#   applications/NNS
#   for/IN
#   the/DT
#   benefits/NNS
#   that/IN
#   they/PRP
#   need/VBP
#   ,/,
#   such/JJ
#   as/IN
#   personal/JJ
#   independence/NN
#   payments/NNS
#   ./.
#   Currently/RB
#   ,/,
#   the/DT
#   ``/``
#   fast-track/NN
#   ''/''
#   system/NN
#   applies/VBZ
#   only/RB
#   to/TO
#   people/NNS
#   who/WP
#   are/VBP
#   judged/VBN
#   to/TO
#   have/VB
#   less/JJR
#   than/IN
#   six/CD
#   months/NNS
#   to/TO
#   live/VB
#   ./.
#   That/DT
#   needs/VBZ
#   to/TO
#   be/VB
#   extended/VBN
#   to/TO
#   12/CD
#   months/NNS
#   ,/,
#   or/CC
#   ,/,
#   indeed/RB
#   ,/,
#   the/DT
#   system/NN
#   should/MD
#   apply/VB
#   at/IN
#   the/DT
#   time/NN
#   of/IN
#   diagnosis/NN
#   ./.
#   The/DT
#   hon./JJ
#   Member/NNP
#   for/IN
#   (LOCATION Dumfries/NNPS)
#   and/CC
#   (PERSON Galloway/NNP)
#   -LRB-/NNP
#   (PERSON Richard/NNP Arkless/NNP)
#   -RRB-/NNP
#   hoped/VBD
#   to/TO
#   attend/VB
#   the/DT
#   debate/NN
#   ,/,
#   but/CC
#   he/PRP
#   is/VBZ
#   stuck/VBN
#   on/IN
#   a/DT
#   train/NN
#   somewhere/RB
#   between/IN
#   (ORGANIZATION Wigan/NNP)
#   and/CC
#   (LOCATION London/NNP)
#   ,/,
#   and/CC
#   the/DT
#   main/JJ
#   business/NN
#   ended/VBD
#   early/RB
#   today/NN
#   ./.
#   Let/VB
#   me/PRP
#   just/RB
#   mention/NN
#   that/IN
#   his/PRP$
#   mother/NN
#   and/CC
#   brother-in-law/NN
#   both/DT
#   died/VBD
#   of/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   I/PRP
#   believe/VBP
#   that/IN
#   he/PRP
#   met/VBD
#   the/DT
#   (ORGANIZATION
#     Under-Secretary/NNP
#     of/IN
#     State/NNP
#     for/IN
#     Health/NNP)
#   ,/,
#   the/DT
#   hon./NN
#   Member/NNP
#   for/IN
#   (ORGANIZATION Warrington/NNP South/NNP)
#   -LRB-/NNP
#   (PERSON David/NNP Mowat/NNP)
#   -RRB-/NNP
#   ,/,
#   just/RB
#   before/IN
#   (DATE Christmas/NNP)
#   ,/,
#   with/IN
#   the/DT
#   aim/NN
#   of/IN
#   ensuring/VBG
#   that/IN
#   when/WRB
#   a/DT
#   (ORGANIZATION DWP/NNP)
#   assessment/NN
#   was/VBD
#   completed/VBN
#   for/IN
#   someone/NN
#   suffering/NN
#   from/IN
#   (ORGANIZATION MND/NNP)
#   ,/,
#   that/IN
#   person/NN
#   would/MD
#   not/RB
#   be/VB
#   reassessed/VBN
#   ./.
#   However/RB
#   ,/,
#   I/PRP
#   understand/VBP
#   from/IN
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   that/IN
#   the/DT
#   (ORGANIZATION Department/NNP)
#   for/IN
#   Work/NNP
#   and/CC
#   Pensions/NNP
#   is/VBZ
#   still/RB
#   issuing/VBG
#   letters/NNS
#   about/IN
#   reassessment/NN
#   ./.
#   I/PRP
#   should/MD
#   be/VB
#   grateful/JJ
#   if/IN
#   the/DT
#   Minister/NNP
#   wrote/VBD
#   to/TO
#   the/DT
#   hon./NN
#   Gentleman/NNP
#   ,/,
#   and/CC
#   me/PRP
#   ,/,
#   to/TO
#   update/VB
#   us/PRP
#   on/IN
#   what/WP
#   progress/NN
#   has/VBZ
#   been/VBN
#   made/VBN
#   in/IN
#   relation/NN
#   to/TO
#   not/RB
#   issuing/VBG
#   such/JJ
#   letters/NNS
#   when/WRB
#   people/NNS
#   have/VBP
#   been/VBN
#   diagnosed/VBN
#   with/IN
#   (ORGANIZATION MND/NNP)
#   and/CC
#   a/DT
#   proper/JJ
#   assessment/NN
#   has/VBZ
#   already/RB
#   been/VBN
#   carried/VBN
#   out/RP
#   ./.
#   Let/VB
#   me/PRP
#   also/RB
#   pay/VBP
#   a/DT
#   brief/JJ
#   tribute/NN
#   to/TO
#   another/DT
#   friend/NN
#   of/IN
#   mine/NN
#   who/WP
#   died/VBD
#   from/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   (PERSON Robert/NNP Wilson/NNP)
#   died/VBD
#   in/IN
#   (DATE August/NNP last/JJ year/NN)
#   ./.
#   He/PRP
#   was/VBD
#   a/DT
#   former/JJ
#   partner/NN
#   at/IN
#   (ORGANIZATION Deloitte/NNP)
#   in/IN
#   (LOCATION Edinburgh/NNP)
#   ,/,
#   and/CC
#   became/VBD
#   the/DT
#   first/JJ
#   chair/NN
#   of/IN
#   the/DT
#   Scottish/NNP
#   Premier/NNP
#   League/NNP
#   in/IN
#   (DATE 1998/CD)
#   after/IN
#   helping/VBG
#   to/TO
#   set/VB
#   it/PRP
#   up/RP
#   ./.
#   I/PRP
#   got/VBD
#   to/TO
#   know/VB
#   (PERSON Robert/NNP)
#   when/WRB
#   he/PRP
#   advised/VBD
#   the/DT
#   (ORGANIZATION Foundation/NNP of/IN Hearts/NNP)
#   to/TO
#   be/VB
#   in/IN
#   a/DT
#   position/NN
#   to/TO
#   take/VB
#   Heart/NNP
#   of/IN
#   (LOCATION Midlothian/NNP)
#   football/NN
#   club/NN
#   out/IN
#   of/IN
#   impending/VBG
#   liquidation/NN
#   ./.
#   His/PRP$
#   straight-talking/JJ
#   style/NN
#   was/VBD
#   direct/JJ
#   ./.
#   He/PRP
#   said/VBD
#   things/NNS
#   as/IN
#   he/PRP
#   saw/VBD
#   them/PRP
#   ./.
#   He/PRP
#   was/VBD
#   always/RB
#   challenging/VBG
#   ,/,
#   and/CC
#   always/RB
#   hugely/RB
#   helpful/JJ
#   ./.
#   We/PRP
#   were/VBD
#   lucky/JJ
#   to/TO
#   have/VB
#   him/PRP
#   ,/,
#   and/CC
#   so/RB
#   was/VBD
#   the/DT
#   club/NN
#   ./.
#   It/PRP
#   is/VBZ
#   thanks/NNS
#   in/IN
#   large/JJ
#   part/NN
#   to/TO
#   (LOCATION Robert/NNP)
#   that/IN
#   it/PRP
#   survives/VBZ
#   and/CC
#   thrives/NNS
#   today/NN
#   ;/:
#   it/PRP
#   would/MD
#   have/VB
#   disappeared/VBN
#   had/VBD
#   it/PRP
#   not/RB
#   been/VBN
#   for/IN
#   people/NNS
#   like/IN
#   him/PRP
#   ./.
#   Robert/NNP
#   and/CC
#   I/PRP
#   subsequently/RB
#   served/VBD
#   together/RB
#   on/IN
#   the/DT
#   board/NN
#   of/IN
#   Hearts/NNP
#   football/NN
#   club/NN
#   ./.
#   Everyone/NN
#   was/VBD
#   really/RB
#   fond/JJ
#   of/IN
#   him/PRP
#   ./.
#   We/PRP
#   were/VBD
#   robbed/VBN
#   of/IN
#   his/PRP$
#   intense/JJ
#   intellect/NN
#   ,/,
#   his/PRP$
#   passion/NN
#   for/IN
#   the/DT
#   club/NN
#   ,/,
#   and/CC
#   his/PRP$
#   companionship/NN
#   when/WRB
#   (ORGANIZATION MND/NNP)
#   took/VBD
#   his/PRP$
#   life/NN
#   ./.
#   He/PRP
#   was/VBD
#   respected/VBN
#   and/CC
#   admired/VBN
#   by/IN
#   all/DT
#   ,/,
#   and/CC
#   will/MD
#   be/VB
#   very/RB
#   sadly/RB
#   missed/VBN
#   ,/,
#   especially/RB
#   by/IN
#   his/PRP$
#   wonderfully/RB
#   supportive/JJ
#   family/NN
#   ./.
#   Gordon/NNP
#   had/VBD
#   a/DT
#   nickname/NN
#   when/WRB
#   he/PRP
#   worked/VBD
#   at/IN
#   the/DT
#   (ORGANIZATION Scottish/JJ Parliament/NNP)
#   ./.
#   His/PRP$
#   nickname/NN
#   was/VBD
#   ``/``
#   (PERCENT 14/CD %/NN)
#   ''/''
#   ./.
#   Many/JJ
#   people/NNS
#   may/MD
#   ask/VB
#   why/WRB
#   that/DT
#   was/VBD
#   ./.
#   It/PRP
#   was/VBD
#   because/RB
#   when/WRB
#   he/PRP
#   worked/VBD
#   as/IN
#   a/DT
#   researcher/NN
#   for/IN
#   the/DT
#   (ORGANIZATION Scottish/NNP Labour/NNP Party/NNP)
#   ,/,
#   he/PRP
#   was/VBD
#   responsible/JJ
#   for/IN
#   (PERCENT 14/CD %/NN)
#   of/IN
#   all/PDT
#   the/DT
#   freedom/NN
#   of/IN
#   information/NN
#   requests/NNS
#   submitted/VBD
#   to/TO
#   the/DT
#   (ORGANIZATION Scottish/JJ Government/NNP)
#   ./.
#   That/IN
#   fact/NN
#   was/VBD
#   even/RB
#   mentioned/VBN
#   by/IN
#   the/DT
#   former/JJ
#   (ORGANIZATION First/NNP Minister/NNP)
#   ,/,
#   the/DT
#   right/JJ
#   hon./NN
#   Member/NNP
#   for/IN
#   (PERSON Gordon/NNP)
#   -LRB-/NNP
#   (PERSON Alex/NNP Salmond/NNP)
#   -RRB-/NNP
#   ,/,
#   at/IN
#   (ORGANIZATION First/NNP Minister/NNP)
#   's/POS
#   Questions/NNP
#   ./.
#   The/DT
#   right/JJ
#   hon./NN
#   Gentleman/NNP
#   was/VBD
#   rather/RB
#   irritated/VBN
#   by/IN
#   it/PRP
#   ./.
#   If/IN
#   (PERSON Gordon/NNP)
#   is/VBZ
#   to/TO
#   leave/VB
#   any/DT
#   legacy/NN
#   ,/,
#   irritating/VBG
#   the/DT
#   former/JJ
#   (ORGANIZATION First/NNP Minister/NNP)
#   is/VBZ
#   very/RB
#   high/JJ
#   up/RP
#   in/IN
#   my/PRP$
#   book/NN
#   ./.
#   Tonight/NNP
#   ,/,
#   however/RB
#   ,/,
#   I/PRP
#   want/VBP
#   us/PRP
#   to/TO
#   change/VB
#   (PERSON Gordon/NNP)
#   's/POS
#   nickname/NN
#   ./.
#   I/PRP
#   want/VBP
#   us/PRP
#   to/TO
#   change/VB
#   it/PRP
#   from/IN
#   ``/``
#   (PERCENT 14/CD %/NN)
#   ''/''
#   to/TO
#   ``/``
#   (PERCENT 100/CD %/NN)
#   ''/''
#   ,/,
#   and/CC
#   we/PRP
#   can/MD
#   do/VB
#   that/DT
#   by/IN
#   doubling/VBG
#   the/DT
#   annual/JJ
#   research/NN
#   budget/NN
#   for/IN
#   (ORGANIZATION MND/NNP)
#   from/IN
#   (MONEY #/# 5/CD million/CD)
#   to/TO
#   (MONEY #/# 10/CD million/CD)
#   a/DT
#   year/NN
#   ./.
#   Gordon/NNP
#   ,/,
#   in/IN
#   his/PRP$
#   death/NN
#   ,/,
#   transformed/VBD
#   the/DT
#   lives/NNS
#   of/IN
#   so/RB
#   many/JJ
#   ./.
#   The/DT
#   world/NN
#   is/VBZ
#   a/DT
#   better/JJR
#   place/NN
#   for/IN
#   his/PRP$
#   having/VBG
#   been/VBN
#   in/IN
#   it/PRP
#   ./.
#   The/DT
#   understanding/NN
#   of/IN
#   (ORGANIZATION MND/NNP)
#   is/VBZ
#   enhanced/VBN
#   by/IN
#   his/PRP$
#   dedication/NN
#   to/TO
#   educating/VBG
#   ./.
#   The/DT
#   care/NN
#   of/IN
#   those/DT
#   suffering/NN
#   is/VBZ
#   enshrined/VBN
#   in/IN
#   his/PRP$
#   having/VBG
#   fought/VBN
#   for/IN
#   it/PRP
#   ./.
#   The/DT
#   rights/NNS
#   of/IN
#   those/DT
#   affected/VBN
#   are/VBP
#   secured/VBN
#   because/IN
#   he/PRP
#   demanded/VBD
#   that/IN
#   ./.
#   The/DT
#   cure/NN
#   for/IN
#   (ORGANIZATION MND/NNP)
#   is/VBZ
#   closer/RBR
#   after/IN
#   his/PRP$
#   fundraising/NN
#   for/IN
#   it/PRP
#   ./.
#   Gordon/NNP
#   did/VBD
#   so/RB
#   much/JJ
#   in/IN
#   such/JJ
#   a/DT
#   short/JJ
#   space/NN
#   of/IN
#   time/NN
#   ,/,
#   and/CC
#   now/RB
#   it/PRP
#   is/VBZ
#   our/PRP$
#   time/NN
#   to/TO
#   find/VB
#   a/DT
#   way/NN
#   to/TO
#   honour/VB
#   that/DT
#   legacy/NN
#   ./.
#   I/PRP
#   say/VBP
#   this/DT
#   to/TO
#   the/DT
#   Minister/NNP
#   :/:
#   let/VB
#   us/PRP
#   pledge/VB
#   tonight/NN
#   to/TO
#   be/VB
#   a/DT
#   little/JJ
#   more/JJR
#   like/IN
#   (PERSON Gordon/NNP)
#   ,/,
#   and/CC
#   double/VB
#   the/DT
#   (ORGANIZATION MND/NNP)
#   research/NN
#   budget/NN
#   ./.
#   In/IN
#   life/NN
#   ,/,
#   (PERSON Gordon/NNP)
#   gave/VBD
#   a/DT
#   voice/NN
#   to/TO
#   (ORGANIZATION MND/NNP)
#   patients/NNS
#   ;/:
#   in/IN
#   death/NN
#   ,/,
#   (PERSON Gordon/NNP)
#   's/POS
#   own/JJ
#   voice/NN
#   speaks/NNS
#   on/IN
#   ./.
#   It/PRP
#   speaks/VBZ
#   on/IN
#   in/IN
#   the/DT
# ...
#   and/CC
#   in/IN
#   the/DT
#   lives/NNS
#   that/IN
#   he/PRP
#   touched/VBD
#   ./.
#   I/PRP
#   opened/VBD
#   my/PRP$
#   speech/NN
#   in/IN
#   (LOCATION Gordon/NNP)
#   's/POS
#   words/NNS
#   ,/,
#   and/CC
#   I/PRP
#   will/MD
#   finish/VB
#   with/IN
#   them/PRP
#   ,/,
#   as/IN
#   echoed/VBN
#   by/IN
#   the/DT
#   Scottish/JJ
#   Labour/NNP
#   leader/NN
#   (PERSON Kezia/NNP Dugdale/NNP)
#   at/IN
#   his/PRP$
#   funeral/JJ
#   on/IN
#   (DATE Saturday/NNP)
#   ./.
#   (PERSON Gordon/NNP)
#   said/VBD
#   :/:
#   ``/``
#   What/WP
#   I/PRP
#   have/VBP
#   lost/VBN
#   in/IN
#   strength/NN
#   of/IN
#   body/NN
#   ,/,
#   I/PRP
#   make/VBP
#   up/RP
#   for/IN
#   in/IN
#   strength/NN
#   of/IN
#   mind/NN
#   ./.
#   I/PRP
#   am/VBP
#   more/RBR
#   determined/JJ
#   and/CC
#   driven/VBN
#   than/IN
#   ever/RB
#   .../:
#   I/PRP
#   want/VBP
#   to/TO
#   make/VB
#   every/DT
#   day/NN
#   count/NN
#   ./.
#   My/PRP$
#   love/NN
#   is/VBZ
#   deeper/JJR
#   ./.
#   I/PRP
#   find/VBP
#   joy/NN
#   in/IN
#   simpler/JJ
#   things/NNS
#   and/CC
#   in/IN
#   different/JJ
#   places/NNS
#   ./.
#   I/PRP
#   am/VBP
#   more/RBR
#   chilled/JJ
#   out/RB
#   ,/,
#   at/IN
#   peace/NN
#   with/IN
#   the/DT
#   fact/NN
#   that/IN
#   there/EX
#   is/VBZ
#   so/RB
#   much/JJ
#   in/IN
#   life/NN
#   that/WDT
#   is/VBZ
#   out/IN
#   of/IN
#   our/PRP$
#   control/NN
#   ./.
#   Let/VB
#   's/POS
#   celebrate/VB
#   the/DT
#   rich/JJ
#   ,/,
#   diverse/JJ
#   and/CC
#   complicated/JJ
#   world/NN
#   we/PRP
#   live/VBP
#   in/IN
#   ./.
#   Let/VB
#   's/POS
#   savour/JJ
#   each/DT
#   day/NN
#   ./.
#   Let/VB
#   's/POS
#   measure/NN
#   life/NN
#   not/RB
#   by/IN
#   length/NN
#   but/CC
#   by/IN
#   depth/NN
#   ./.
#   ''/''
#   (PERSON Gordon/NNP Lewis/NNP Aikman/NNP)
#   ,/,
#   born/VBN
#   on/IN
#   2/CD
#   (DATE April/NNP 1985/CD)
#   ,/,
#   died/VBD
#   on/IN
#   2/CD
#   (DATE February/NNP 2017/CD)
#   ,/,
#   aged/VBD
#   31/CD
#   ./.
#   May/NNP
#   he/PRP
#   rest/VB
#   in/IN
#   peace/NN
#   ,/,
#   but/CC
#   may/MD
#   his/PRP$
#   legacy/NN
#   live/VBP
#   on/IN
#   ./.
#   19:40:00/CD
#   The/DT
#   Minister/NNP
#   for/IN
#   Universities/NNP
#   ,/,
#   Science/NNP
#   ,/,
#   Research/NNP
#   and/CC
#   Innovation/NNP
#   -LRB-/NNP
#   (PERSON Joseph/NNP Johnson/NNP)
#   -RRB-/NNP
#   I/PRP
#   thank/VBD
#   fellow/JJ
#   Members/NNS
#   for/IN
#   their/PRP$
#   contributions/NNS
#   and/CC
#   passion/NN
#   on/IN
#   this/DT
#   topic/NN
#   ,/,
#   and/CC
#   in/IN
#   particular/JJ
#   the/DT
#   hon./JJ
#   Member/NNP
#   for/IN
#   (ORGANIZATION Edinburgh/NNP South/NNP)
#   -LRB-/NNP
#   (PERSON Ian/NNP Murray/NNP)
#   -RRB-/NNP
#   for/IN
#   calling/VBG
#   this/DT
#   debate/NN
#   ./.
#   We/PRP
#   have/VBP
#   heard/VBN
#   (TIME this/DT evening/VBG)
#   how/WRB
#   many/JJ
#   in/IN
#   this/DT
#   (ORGANIZATION House/NNP)
#   were/VBD
#   saddened/VBN
#   to/TO
#   hear/VB
#   of/IN
#   (PERSON Gordon/NNP Aikman/NNP)
#   's/POS
#   passing/NN
#   this/DT
#   month/NN
#   ,/,
#   and/CC
#   we/PRP
#   have/VBP
#   heard/VBN
#   how/WRB
#   his/PRP$
#   courageous/JJ
#   and/CC
#   incredible/JJ
#   efforts/NNS
#   to/TO
#   raise/VB
#   awareness/NN
#   of/IN
#   motor/NN
#   neurone/NN
#   disease/NN
#   and/CC
#   help/NN
#   others/NNS
#   were/VBD
#   truly/JJ
#   inspirational/JJ
#   and/CC
#   have/VBP
#   made/VBN
#   a/DT
#   huge/JJ
#   difference/NN
#   to/TO
#   the/DT
#   lives/NNS
#   of/IN
#   (ORGANIZATION MND/NNP)
#   sufferers/NNS
#   ./.
#   His/PRP$
#   loss/NN
#   will/MD
#   of/IN
#   course/NN
#   be/VB
#   most/RBS
#   keenly/RB
#   felt/VBN
#   by/IN
#   those/DT
#   who/WP
#   knew/VBD
#   him/PRP
#   best/JJS
#   ,/,
#   such/JJ
#   as/IN
#   people/NNS
#   who/WP
#   are/VBP
#   in/IN
#   this/DT
#   (DATE Chamber/NNP today/NN)
#   ,/,
#   and/CC
#   all/DT
#   Members/NNP
#   '/POS
#   thoughts/NNS
#   are/VBP
#   with/IN
#   his/PRP$
#   family/NN
#   and/CC
#   friends/NNS
#   at/IN
#   this/DT
#   difficult/JJ
#   time/NN
#   ./.
#   Sadly/RB
#   ,/,
#   (PERSON Gordon/NNP)
#   's/POS
#   condition/NN
#   was/VBD
#   not/RB
#   unique/JJ
#   ./.
#   It/PRP
#   is/VBZ
#   estimated/VBN
#   that/IN
#   there/EX
#   are/VBP
#   up/RB
#   to/TO
#   5,000/CD
#   people/NNS
#   with/IN
#   (ORGANIZATION MND/NNP)
#   in/IN
#   the/DT
#   UK/NNP
#   today/NN
#   ,/,
#   while/IN
#   each/DT
#   year/NN
#   approximately/RB
#   1,100/CD
#   people/NNS
#   are/VBP
#   diagnosed/VBN
#   around/IN
#   the/DT
#   world/NN
#   ./.
#   The/DT
#   Government/NNP
#   are/VBP
#   aware/JJ
#   of/IN
#   the/DT
#   immense/JJ
#   difficulties/NNS
#   and/CC
#   challenges/NNS
#   faced/VBN
#   by/IN
#   (ORGANIZATION MND/NNP)
#   sufferers/NNS
#   and/CC
#   we/PRP
#   are/VBP
#   taking/VBG
#   significant/JJ
#   action/NN
#   ,/,
#   both/DT
#   via/IN
#   research/NN
#   funding/NN
#   and/CC
#   alterations/NNS
#   to/TO
#   clinical/JJ
#   guidelines/NNS
#   ,/,
#   to/TO
#   improve/VB
#   (ORGANIZATION MND/NNP)
#   patient/NN
#   care/NN
#   and/CC
#   treatments/NNS
#   ./.
#   As/IN
#   the/DT
#   hon./NN
#   Member/NNP
#   for/IN
#   (ORGANIZATION Edinburgh/NNP South/NNP)
#   said/VBD
#   ,/,
#   funding/VBG
#   (ORGANIZATION MND/NNP)
#   research/NN
#   is/VBZ
#   key/JJ
#   if/IN
#   we/PRP
#   are/VBP
#   to/TO
#   find/VB
#   a/DT
#   cure/NN
#   and/CC
#   improve/VB
#   treatments/NNS
#   for/IN
#   (ORGANIZATION MND/NNP)
#   patients/NNS
#   ./.
#   We/PRP
#   are/VBP
#   investing/VBG
#   over/IN
#   (MONEY #/# 1/CD billion/CD)
#   a/DT
#   year/NN
#   in/IN
#   the/DT
#   (ORGANIZATION
#     National/NNP
#     Institute/NNP
#     for/IN
#     Health/NNP
#     Research/NNP)
#   ,/,
#   whose/WP$
#   spend/NN
#   on/IN
#   research/NN
#   relating/VBG
#   to/TO
#   neurological/JJ
#   conditions/NNS
#   was/VBD
#   (MONEY #/# 53/CD million/CD)
#   in/IN
#   (DATE 2015-16/JJ)
#   ./.
#   In/IN
#   addition/NN
#   ,/,
#   the/DT
#   (ORGANIZATION Government/NNP)
#   fund/VBD
#   the/DT
#   seven/CD
#   research/NN
#   councils/NNS
#   ,/,
#   which/WDT
#   invest/VBP
#   around/RB
#   (MONEY #/# 3/CD billion/CD)
#   each/DT
#   year/NN
#   in/IN
#   research/NN
#   covering/VBG
#   the/DT
#   full/JJ
#   spectrum/NN
#   of/IN
#   academic/JJ
#   disciplines/NNS
#   ,/,
#   from/IN
#   the/DT
#   medical/JJ
#   and/CC
#   biological/JJ
#   sciences/NNS
#   to/TO
#   astronomy/VB
#   ,/,
#   physics/NNS
#   ,/,
#   chemistry/NN
#   and/CC
#   engineering/NN
#   ,/,
#   social/JJ
#   sciences/NNS
#   ,/,
#   economics/NNS
#   ,/,
#   environmental/JJ
#   sciences/NNS
#   and/CC
#   the/DT
#   arts/NNS
#   and/CC
#   humanities/NNS
#   ./.
#   The/DT
#   majority/NN
#   of/IN
#   research/NN
#   council/NN
#   investment/NN
#   in/IN
#   (ORGANIZATION MND/NNP)
#   research/NN
#   is/VBZ
#   made/VBN
#   by/IN
#   the/DT
#   (ORGANIZATION Medical/NNP Research/NNP Council/NNP)
#   ,/,
#   with/IN
#   some/DT
#   relevant/JJ
#   research/NN
#   also/RB
#   funded/VBD
#   through/IN
#   the/DT
#   Biotechnology/NNP
#   and/CC
#   (ORGANIZATION Biological/NNP Sciences/NNP Research/NNP Council/NNP)
#   ./.
#   The/DT
#   (ORGANIZATION MRC/NNP)
#   supports/VBZ
#   research/NN
#   relating/VBG
#   to/TO
#   a/DT
#   broad/JJ
#   portfolio/NN
#   of/IN
#   neurodegenerative/JJ
#   diseases/NNS
#   and/CC
#   currently/RB
#   spends/VBZ
#   ,/,
#   as/IN
#   the/DT
#   hon./NN
#   (PERSON Gentleman/NNP)
#   said/VBD
#   ,/,
#   about/RB
#   (MONEY #/# 5/CD million/CD)
#   per/IN
#   year/NN
#   on/IN
#   research/NN
#   relating/VBG
#   to/TO
#   (ORGANIZATION MND/NNP)
#   ./.
#   The/DT
#   (ORGANIZATION MRC/NNP)
#   funds/NNS
#   research/NN
#   at/IN
#   many/JJ
#   leading/VBG
#   institutes/NNS
#   in/IN
#   the/DT
#   country/NN
#   ,/,
#   including/VBG
#   the/DT
#   (ORGANIZATION
#     MRC/NNP
#     Laboratory/NNP
#     of/IN
#     Molecular/NNP
#     Biology/NNP)
#   ,/,
#   the/DT
#   (ORGANIZATION UCL/NNP Institute/NNP of/IN Neurology/NNP)
#   ,/,
#   the/DT
#   (ORGANIZATION National/NNP Hospital/NNP for/IN Neurology/NNP)
#   and/CC
#   Neurosurgery/NNP
#   and/CC
#   (ORGANIZATION the/DT University/NNP of/IN Oxford/NNP)
#   ./.
#   MRC-funded/JJ
#   research/NN
#   includes/VBZ
#   projects/NNS
#   to/TO
#   increase/VB
#   understanding/NN
#   of/IN
#   the/DT
#   basic/JJ
#   molecular/JJ
#   mechanisms/NNS
#   underlying/VBG
#   (ORGANIZATION MND/NNP)
#   ,/,
#   improve/VB
#   the/DT
#   assessment/NN
#   of/IN
#   disease/NN
#   progression/NN
#   and/CC
#   identify/JJ
#   biomarkers/NNS
#   of/IN
#   disease/NN
#   activity/NN
#   in/IN
#   patients/NNS
#   with/IN
#   different/JJ
#   types/NNS
#   of/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   It/PRP
#   also/RB
#   works/VBZ
#   in/IN
#   partnership/NN
#   with/IN
#   charities/NNS
#   and/CC
#   other/JJ
#   funders/NNS
#   ,/,
#   nationally/RB
#   and/CC
#   internationally/RB
#   ,/,
#   to/TO
#   support/VB
#   research/NN
#   into/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   In/IN
#   addition/NN
#   to/TO
#   the/DT
#   (ORGANIZATION MRC/NNP)
#   ,/,
#   the/DT
#   BBSRC/NNP
#   funds/NNS
#   world-class/JJ
#   bioscience/NN
#   and/CC
#   biotechnology/NN
#   that/WDT
#   underpins/VBZ
#   health/NN
#   research/NN
#   ./.
#   In/IN
#   the/DT
#   context/NN
#   of/IN
#   (ORGANIZATION MND/NNP)
#   ,/,
#   this/DT
#   may/MD
#   include/VB
#   the/DT
#   basic/JJ
#   bioscience/NN
#   of/IN
#   motor/NN
#   neurones/NNS
#   ./.
#   Over/IN
#   the/DT
#   last/JJ
#   five/CD
#   financial/JJ
#   years/NNS
#   ,/,
#   the/DT
#   BBSRC/NNP
#   has/VBZ
#   spent/VBN
#   about/RB
#   (MONEY #/# 4.7/CD million/CD)
#   on/IN
#   research/NN
#   projects/NNS
#   which/WDT
#   focus/VBP
#   on/IN
#   basic/JJ
#   underpinning/JJ
#   research/NN
#   that/WDT
#   will/MD
#   increase/VB
#   understanding/NN
#   of/IN
#   the/DT
#   normal/JJ
#   cellular/JJ
#   processes/NNS
#   that/WDT
#   support/VBP
#   motor/NN
#   neurone/NN
#   function/NN
#   ./.
#   In/IN
#   addition/NN
#   to/TO
#   research/NN
#   funding/NN
#   ,/,
#   we/PRP
#   understand/VBP
#   that/DT
#   positively/RB
#   influencing/VBG
#   the/DT
#   healthcare/NN
#   and/CC
#   clinical/JJ
#   system/NN
#   is/VBZ
#   key/JJ
#   if/IN
#   we/PRP
#   are/VBP
#   to/TO
#   improve/VB
#   the/DT
#   lives/NNS
#   of/IN
#   (ORGANIZATION MND/NNP)
#   sufferers/NNS
#   ./.
#   The/DT
#   (ORGANIZATION Government/NNP)
#   understand/NN
#   that/IN
#   one/CD
#   of/IN
#   the/DT
#   major/JJ
#   hurdles/NNS
#   facing/VBG
#   (ORGANIZATION MND/NNP)
#   patients/NNS
#   is/VBZ
#   the/DT
#   challenge/NN
#   of/IN
#   getting/VBG
#   an/DT
#   accurate/NN
#   and/CC
#   fast/JJ
#   diagnosis/NN
#   ./.
#   No/UH
#   two/CD
#   people/NNS
#   with/IN
#   (ORGANIZATION MND/NNP)
#   will/MD
#   be/VB
#   affected/VBN
#   in/IN
#   exactly/RB
#   the/DT
#   same/JJ
#   way/NN
#   ,/,
#   and/CC
#   there/EX
#   is/VBZ
#   no/DT
#   one/NN
#   test/NN
#   to/TO
#   diagnose/VB
#   the/DT
#   condition/NN
#   ./.
#   The/DT
#   disease/NN
#   can/MD
#   be/VB
#   difficult/JJ
#   to/TO
#   identify/VB
#   in/IN
#   its/PRP$
#   early/JJ
#   stages/NNS
#   ,/,
#   as/IN
#   the/DT
#   symptoms/NNS
#   are/VBP
#   often/RB
#   mild/JJ
#   and/CC
#   shared/VBN
#   with/IN
#   more/RBR
#   common/JJ
#   conditions/NNS
#   ./.
#   The/DT
#   (ORGANIZATION
#     National/NNP
#     Institute/NNP
#     for/IN
#     Health/NNP
#     and/CC
#     Care/NNP
#     Excellence/NNP)
#   published/VBD
#   its/PRP$
#   (ORGANIZATION MND/NNP)
#   assessment/NN
#   and/CC
#   management/NN
#   guidance/NN
#   document/NN
#   in/IN
#   (DATE February/NNP 2016/CD)
#   ./.
#   The/DT
#   guidance/NN
#   sets/VBZ
#   out/RP
#   (ORGANIZATION MND/NNP)
#   's/POS
#   signs/NNS
#   and/CC
#   symptoms/NNS
#   ,/,
#   provides/VBZ
#   information/NN
#   about/IN
#   local/JJ
#   referral/JJ
#   arrangements/NNS
#   and/CC
#   recommends/VBZ
#   that/DT
#   robust/JJ
#   protocols/NNS
#   and/CC
#   pathways/NNS
#   are/VBP
#   in/IN
#   place/NN
#   to/TO
#   inform/VB
#   healthcare/NN
#   professionals/NNS
#   about/IN
#   the/DT
#   disease/NN
#   and/CC
#   how/WRB
#   it/PRP
#   might/MD
#   present/VB
#   itself/PRP
#   ./.
#   I/PRP
#   know/VBP
#   ,/,
#   and/CC
#   am/VBP
#   glad/JJ
#   ,/,
#   that/IN
#   the/DT
#   guidance/NN
#   was/VBD
#   described/VBN
#   by/IN
#   the/DT
#   leading/VBG
#   charity/NN
#   ,/,
#   (ORGANIZATION
#     the/DT
#     Motor/NNP
#     Neurone/NNP
#     Disease/NNP
#     Association/NNP)
#   ,/,
#   as/IN
#   ``/``
#   hugely/RB
#   significant/JJ
#   ''/''
#   ./.
#   We/PRP
#   know/VBP
#   that/DT
#   (ORGANIZATION MND/NNP)
#   patients/NNS
#   value/NN
#   and/CC
#   need/VBP
#   specialist/NN
#   services/NNS
#   ,/,
#   and/CC
#   this/DT
#   is/VBZ
#   something/NN
#   that/IN
#   (PERSON Gordon/NNP Aikman/NNP)
#   successfully/RB
#   campaigned/VBD
#   for/IN
#   in/IN
#   (LOCATION Scotland/NNP)
#   ./.
#   (ORGANIZATION NHS/NNP England/NNP)
#   has/VBZ
#   set/VBN
#   out/RP
#   that/IN
#   services/NNS
#   for/IN
#   (ORGANIZATION MND/NNP)
#   patients/NNS
#   should/MD
#   be/VB
#   specialised/VBN
#   ./.
#   Care/NNP
#   for/IN
#   (ORGANIZATION MND/NNP)
#   patients/NNS
#   involves/VBZ
#   a/DT
#   multidisciplinary/JJ
#   team/NN
#   approach/NN
#   from/IN
#   (ORGANIZATION MND/NNP)
#   specialists/NNS
#   who/WP
#   should/MD
#   work/VB
#   to/TO
#   ensure/VB
#   that/IN
#   patients/NNS
#   are/VBP
#   fully/RB
#   supported/VBN
#   and/CC
#   co-ordinate/JJ
#   with/IN
#   other/JJ
#   care/NN
#   providers/NNS
#   or/CC
#   teams/NNS
#   as/IN
#   necessary/JJ
#   ./.
#   NHS/NNP
#   (LOCATION England/NNP)
#   commissions/VBZ
#   the/DT
#   care/NN
#   that/IN
#   patients/NNS
#   may/MD
#   receive/VB
#   from/IN
#   25/CD
#   specialised/JJ
#   neurological/JJ
#   treatment/NN
#   centres/NNS
#   across/IN
#   (LOCATION England/NNP)
#   ./.
#   It/PRP
#   has/VBZ
#   published/VBN
#   a/DT
#   service/NN
#   specification/NN
#   setting/VBG
#   out/RP
#   what/WP
#   providers/NNS
#   must/MD
#   have/VB
#   in/IN
#   place/NN
#   to/TO
#   deliver/VB
#   specialised/JJ
#   neurological/JJ
#   care/NN
#   ./.
#   This/DT
#   supports/VBZ
#   equity/NN
#   of/IN
#   access/NN
#   to/TO
#   a/DT
#   high/JJ
#   quality/NN
#   service/NN
#   for/IN
#   patients/NNS
#   ,/,
#   wherever/IN
#   they/PRP
#   live/VBP
#   ./.
#   Patients/NNS
#   are/VBP
#   also/RB
#   able/JJ
#   to/TO
#   access/NN
#   the/DT
#   drug/NN
#   Riluzole/NNP
#   on/IN
#   the/DT
#   (ORGANIZATION NHS/NNP)
#   ./.
#   This/DT
#   is/VBZ
#   the/DT
#   only/RB
#   licensed/JJ
#   treatment/NN
#   available/JJ
#   that/WDT
#   can/MD
#   slow/VB
#   the/DT
#   progression/NN
#   of/IN
#   the/DT
#   disease/NN
#   ./.
#   I/PRP
#   know/VBP
#   that/IN
#   specialist/NN
#   (ORGANIZATION MND/NNP)
#   nurses/NNS
#   are/VBP
#   highly/RB
#   valued/VBN
#   by/IN
#   (ORGANIZATION MND/NNP)
#   patients/NNS
#   and/CC
#   their/PRP$
#   families/NNS
#   ./.
#   Recruitment/NN
#   of/IN
#   nurse/JJ
#   specialists/NNS
#   is/VBZ
#   a/DT
#   local/JJ
#   matter/NN
#   ,/,
#   but/CC
#   it/PRP
#   is/VBZ
#   important/JJ
#   to/TO
#   highlight/VB
#   that/DT
#   such/JJ
#   nurses/NNS
#   are/VBP
#   a/DT
#   key/JJ
#   part/NN
#   of/IN
#   the/DT
#   national/JJ
#   specialised/VBD
#   services/NNS
#   that/WDT
#   (ORGANIZATION NHS/NNP England/NNP)
#   delivers/NNS
#   for/IN
#   patients/NNS
#   with/IN
#   neurological/JJ
#   problems/NNS
#   such/JJ
#   as/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   Another/DT
#   of/IN
#   (PERSON Gordon/NNP Aikman/NNP)
#   's/POS
#   seven/CD
#   key/JJ
#   campaign/NN
#   points/NNS
#   was/VBD
#   to/TO
#   guarantee/VB
#   that/IN
#   no/DT
#   (ORGANIZATION MND/NNP)
#   patient/NN
#   should/MD
#   die/VB
#   without/IN
#   a/DT
#   voice/NN
#   ./.
#   Augmentative/JJ
#   and/CC
#   alternative/JJ
#   communication/NN
#   --/:
#   (ORGANIZATION AAC/NNP)
#   --/:
#   aids/NNS
#   are/VBP
#   used/VBN
#   to/TO
#   restore/VB
#   communication/NN
#   for/IN
#   people/NNS
#   who/WP
#   can/MD
#   not/RB
#   communicate/VB
#   using/VBG
#   speech/NN
#   ,/,
#   and/CC
#   to/TO
#   address/VB
#   severe/JJ
#   impacts/NNS
#   on/IN
#   independence/NN
#   and/CC
#   quality/NN
#   of/IN
#   life/NN
#   ./.
#   (ORGANIZATION NHS/NNP England/NNP)
#   has/VBZ
#   established/VBN
#   a/DT
#   national/JJ
#   (ORGANIZATION AAC/NNP)
#   service/NN
#   ,/,
#   commissioned/VBN
#   from/IN
#   13/CD
#   centres/NNS
#   ./.
#   It/PRP
#   is/VBZ
#   the/DT
#   first/JJ
#   national/JJ
#   (ORGANIZATION AAC/NNP)
#   service/NN
#   of/IN
#   its/PRP$
#   kind/NN
#   in/IN
#   the/DT
#   country/NN
#   ./.
#   Priority/NNP
#   for/IN
#   assessment/NN
#   is/VBZ
#   given/VBN
#   to/TO
#   patients/NNS
#   who/WP
#   have/VBP
#   a/DT
#   life-limiting/JJ
#   condition/NN
#   such/JJ
#   as/IN
#   (ORGANIZATION MND/NNP)
#   ./.
#   I/PRP
#   am/VBP
#   glad/JJ
#   that/IN
#   this/DT
#   was/VBD
#   welcomed/VBN
#   by/IN
#   stakeholders/NNS
#   as/IN
#   a/DT
#   major/JJ
#   step/NN
#   forward/RB
#   in/IN
#   providing/VBG
#   clarity/NN
#   and/CC
#   consistency/NN
#   of/IN
#   provision/NN
#   ./.
#   I/PRP
#   hope/VBP
#   that/IN
#   this/DT
#   debate/NN
#   has/VBZ
#   reassured/VBN
#   fellow/JJ
#   Members/NNS
#   that/IN
#   the/DT
#   Government/NNP
#   are/VBP
#   aware/JJ
#   of/IN
#   the/DT
#   immense/JJ
#   difficulties/NNS
#   and/CC
#   challenges/NNS
#   faced/VBN
#   by/IN
#   motor/NN
#   neurone/NN
#   disease/NN
#   sufferers/NNS
#   and/CC
#   that/IN
#   we/PRP
#   are/VBP
#   taking/VBG
#   action/NN
#   in/IN
#   multiple/JJ
#   areas/NNS
#   to/TO
#   improve/VB
#   the/DT
#   care/NN
#   and/CC
#   prognosis/NN
#   of/IN
#   (ORGANIZATION MND/NNP)
#   patients/NNS
#   ./.
#   (PERSON Gordon/NNP Aikman/NNP)
#   's/POS
#   legacy/NN
#   will/MD
#   live/VB
#   on/IN
#   for/IN
#   a/DT
#   long/JJ
#   time/NN
#   due/JJ
#   to/TO
#   his/PRP$
#   courage/NN
#   and/CC
#   his/PRP$
#   determination/NN
#   to/TO
#   raise/VB
#   the/DT
#   profile/NN
#   of/IN
#   (ORGANIZATION MND/NNP)
#   and/CC
#   to/TO
#   make/VB
#   a/DT
#   real/JJ
#   difference/NN
#   to/TO
#   the/DT
#   lives/NNS
#   of/IN
#   (ORGANIZATION MND/NNP)
#   sufferers/NNS
#   ./.
#   Question/NN
#   put/VBD
#   and/CC
#   agreed/VBD
#   to/TO
#   ./.
#   19:47:00/CD
#   (ORGANIZATION House/NNP)
#   adjourned/VBD
#   ./.)

# %%
# Count occurences of each entity

sample_ents = set(get_ents(sample_tree))
sample_ents

# %%
# Export entities version

file_out = open('four_entity_process_stanford_NER_%s.txt' %file_out_suffix,'w+')
for item in sample_ents:
    file_out.write("%s \n" %(item,))
file_out.close()

# %% [markdown]
# ## To DO
#
# - Wrap above into a function and run for each file
# - Collate all found entities together and count up, get most commonly occurring ones
# - Find how to add probability - from nltk.tag.stanford documentation?

# %% [markdown]
# ## Full run

# %%
# Imports

# Stanford imports
from nltk.tag.stanford import StanfordNERTagger
from nltk.tokenize.stanford import StanfordTokenizer
# Other imports
import os
import nltk
from collections import defaultdict
# NLTK imports
from nltk import pos_tag
from nltk.chunk import conlltags2tree
from nltk.tree import Tree

import tkinter

import pandas as pd
import numpy as np

from collections import Counter
import operator


### Define paths ###

#Set core path for Stanford NLP packages
main_path = os.path.join("C:\\Users\\rothw\\Documents\\Python Scripts\\Python NLP\\StanfordNLP\\",
                         "stanford-corenlp-full-2016-10-31\\")
# Set paths where the Standford NLP .jar files are located
pathlist = [os.path.join(main_path,"stanford-corenlp-3.7.0"),
            os.path.join(main_path,"ner\\stanford-ner.jar"),
            os.path.join(main_path,"postagger\\stanford-postagger.jar")]
###            os.path.join(main_path,"parser\\stanford-parser.jar"),
###            os.path.join(main_path,"parser\\stanford-parser-3.6.0-models.jar"),
# Set path to Stanford models
mpath = [os.path.join(main_path,"postagger\\models"),
         os.path.join(main_path,"ner\\classifiers")]
# Set path to java.exe
javapath = "C:\\Program Files\\Java\\jre1.8.0_121\\bin\\java.exe"

# Add paths to the CLASSPATH environmental variable (as instructed by NLTK)
os.environ['CLASSPATH'] = os.pathsep.join(pathlist)
os.environ['STANFORD_MODELS'] = os.pathsep.join(mpath)
os.environ['JAVAHOME'] = javapath



# Define function to tag NER sentence with BIO tags
def stanfordNE2BIO(tagged_sent):
    bio_tagged_sent = []
    prev_tag = "O"
    for token, tag in tagged_sent:
        if tag == "O": #O
            bio_tagged_sent.append((token, tag))
            prev_tag = tag
            continue
        if tag != "O" and prev_tag == "O": # Begin NE
            bio_tagged_sent.append((token, "B-"+tag))
            prev_tag = tag
        elif prev_tag != "O" and prev_tag == tag: # Inside NE
            bio_tagged_sent.append((token, "I-"+tag))
            prev_tag = tag
        elif prev_tag != "O" and prev_tag != tag: # Adjacent NE
            bio_tagged_sent.append((token, "B-"+tag))
            prev_tag = tag
    # Return BIO tagged sentence
    return bio_tagged_sent



### Main function ###

def stanford_ner_full_run(file_in, file_out_suffix):
    
    # Read in file
    sample = open(file_in, 'r', encoding='utf8').read()
    
    
    # Tokenize sentence with stanford NLP
    tkn_sent = StanfordTokenizer().tokenize(sample)

    # Named entity tagging with stanford NLP
    tag_sent = StanfordNERTagger('english.muc.7class.distsim.crf.ser.gz').tag(tkn_sent)
    
    # Apply BIO tags to the tagged sentence
    bio_tagged_sent = stanfordNE2BIO(tag_sent)
    
    # Collate BIO parts of entities together
    sent_tokens, sent_ne_tags = zip(*bio_tagged_sent)
    sent_pos_tags = [pos for token, pos in pos_tag(sent_tokens)]

    sent_conlltags = [(token, pos, ne) for token, pos, ne
                     in zip(sent_tokens, sent_pos_tags, sent_ne_tags)]
    ne_tree = conlltags2tree(sent_conlltags)

    
    # Get entities from the trees
    ne_in_sent = []
    for subtree in ne_tree:
        if type(subtree) == Tree: # If subtree is a noun chunk, i.e. NE != "O"
            ne_label = subtree.label()
            ne_string = " ".join([token for token, pos in subtree.leaves()])
            ne_in_sent.append((ne_string, ne_label))
    
    # Output entities (with duplicates retained)
    return ne_in_sent

# %%
ents_mn = stanford_ner_full_run('c:\\Users\\rothw\\Documents\\Python Scripts\\Python NLP\\Motor Neurone Disease-Gordon Aikman 2017-02-20.txt','motor_neurone')
ents_tr = stanford_ner_full_run('c:\\Users\\rothw\\Documents\\Python Scripts\\Python NLP\\President Trump- State Visit 2017-02-20.txt', 'trump')
ents_hi = stanford_ner_full_run('c:\\Users\\rothw\\Documents\\Python Scripts\\Python NLP\\High Speed Rail (London - West Midlands) Bill 2017-02-20.txt', 'highspeedrail')
ents_va = stanford_ner_full_run('c:\\Users\\rothw\\Documents\\Python Scripts\\Python NLP\\Vauxhall-Opel- Proposed Takeover 2017-02-20.txt', 'vauxhallopel')

# %%
# Rack all outputs together

ents_all = ents_mn + ents_tr + ents_hi + ents_va

# %%
# Count occurences of each entity

counts = Counter(ents_all)
counts_sorted = sorted(counts.items(), key=operator.itemgetter(1), reverse=True)
counts_sorted
# Out:
# [(('Trump', 'PERSON'), 85),
#  (('MND', 'ORGANIZATION'), 70),
#  (('United States', 'LOCATION'), 62),
#  (('House', 'ORGANIZATION'), 60),
#  (('Donald Trump', 'PERSON'), 58),
#  (('Government', 'ORGANIZATION'), 55),
#  (('Gordon', 'PERSON'), 33),
#  (('Vauxhall', 'ORGANIZATION'), 31),
#  (('Greg Clark', 'PERSON'), 31),
#  (('America', 'LOCATION'), 30),
#  (('Secretary of State', 'ORGANIZATION'), 29),
#  (('PSA', 'ORGANIZATION'), 25),
#  (('Scotland', 'LOCATION'), 22),
#  (('Europe', 'LOCATION'), 22),
#  (('NATO', 'ORGANIZATION'), 22),
#  (('London', 'LOCATION'), 19),
#  (('Paul Flynn', 'PERSON'), 19),
#  (('Ellesmere Port', 'LOCATION'), 18),
#  (('United Kingdom', 'LOCATION'), 17),
#  (('Alex Salmond', 'PERSON'), 17),
#  (('Britain', 'LOCATION'), 16),
#  (('US', 'LOCATION'), 15),
#  (('United States of America', 'LOCATION'), 15),
#  (('UK', 'ORGANIZATION'), 13),
#  (('Parliament', 'ORGANIZATION'), 13),
#  (('GM', 'ORGANIZATION'), 13),
#  (('White House', 'ORGANIZATION'), 11),
#  (('Obama', 'PERSON'), 11),
#  (('Administration', 'ORGANIZATION'), 11),
#  (('EU', 'ORGANIZATION'), 10),
#  (('Lords Select Committee', 'ORGANIZATION'), 10),
#  (('Gillan', 'PERSON'), 10),
#  (('Gordon Aikman', 'PERSON'), 9),
#  (('Newport West', 'ORGANIZATION'), 9),
#  (('France', 'LOCATION'), 9),
#  (('Birmingham', 'LOCATION'), 9),
#  (('Trump', 'ORGANIZATION'), 8),
#  (('Her Majesty', 'ORGANIZATION'), 8),
#  (('Lewis', 'PERSON'), 8),
#  (('Naz Shah', 'PERSON'), 8),
#  (('Mr Turner', 'PERSON'), 8),
#  (('Germany', 'LOCATION'), 8),
#  (('Alan Duncan', 'PERSON'), 8),
#  (('Luton', 'LOCATION'), 8),
#  (('Cambridge', 'LOCATION'), 7),
#  (('Department', 'ORGANIZATION'), 7),
#  (('Walker', 'PERSON'), 7),
#  (('Nigel Evans', 'PERSON'), 7),
#  (('Stephen Doughty', 'PERSON'), 7),
#  (('Edward Leigh', 'PERSON'), 7),
#  (('Camden', 'LOCATION'), 7),
#  (('Ian Murray', 'PERSON'), 6),
#  (('Saturday', 'DATE'), 6),
#  (('Charles Walker', 'PERSON'), 6),
#  (('Bradford West', 'ORGANIZATION'), 6),
#  (('Washington', 'LOCATION'), 6),
#  (('Liam Byrne', 'PERSON'), 6),
#  (('Lords', 'LOCATION'), 6),
#  (('Select Committee', 'ORGANIZATION'), 6),
#  (('HS2 Ltd', 'ORGANIZATION'), 6),
#  (('Keir Starmer', 'PERSON'), 6),
#  (('this evening', 'TIME'), 5),
#  (('England', 'LOCATION'), 5),
#  (('Petitions Committee', 'ORGANIZATION'), 5),
#  (('2016', 'DATE'), 5),
#  (('Simon Burns', 'PERSON'), 5),
#  (('European Union', 'LOCATION'), 5),
#  (('UK Government', 'ORGANIZATION'), 5),
#  (('Nigel Adams', 'PERSON'), 5),
#  (('Committee', 'ORGANIZATION'), 5),
#  (('Chesham', 'LOCATION'), 5),
#  (('Amersham', 'ORGANIZATION'), 5),
#  (('Meriden', 'LOCATION'), 5),
#  (('St Pancras', 'ORGANIZATION'), 5),
#  (('David Higgins', 'PERSON'), 5),
#  (('Justin Madders', 'PERSON'), 5),
#  (('Opel', 'ORGANIZATION'), 5),
#  (('Edinburgh South', 'ORGANIZATION'), 4),
#  (('Edinburgh', 'LOCATION'), 4),
#  (('First Minister', 'ORGANIZATION'), 4),
#  (('NHS', 'ORGANIZATION'), 4),
#  (('# 5 million', 'MONEY'), 4),
#  (('14 %', 'PERCENT'), 4),
#  (('Russia', 'LOCATION'), 4),
#  (('Hillary Clinton', 'PERSON'), 4),
#  (('Ribble Valley', 'ORGANIZATION'), 4),
#  (('Evans', 'PERSON'), 4),
#  (('George W. Bush', 'PERSON'), 4),
#  (('China', 'LOCATION'), 4),
#  (('Andrew Turner', 'PERSON'), 4),
#  (('USA', 'ORGANIZATION'), 4),
#  (('Gainsborough', 'PERSON'), 4),
#  (('Carol Monaghan', 'PERSON'), 4),
#  (('Parliament', 'LOCATION'), 4),
#  (('Houses of Parliament', 'ORGANIZATION'), 4),
#  (('Andrew Jones', 'PERSON'), 4),
#  (('Lindsay Hoyle', 'PERSON'), 4),
#  (('TROs', 'ORGANIZATION'), 4),
#  (('Royal Assent', 'ORGANIZATION'), 4),
#  (('Neil Caulfield', 'PERSON'), 4),
#  (('Caroline Spelman', 'PERSON'), 4),
#  (('Mrs Gillan', 'PERSON'), 4),
#  (('2014', 'DATE'), 3),
#  (('New York', 'LOCATION'), 3),
#  (('Wales', 'LOCATION'), 3),
#  (('Madam Deputy Speaker', 'ORGANIZATION'), 3),
#  (('MRC', 'ORGANIZATION'), 3),
#  (('NHS England', 'ORGANIZATION'), 3),
#  (('AAC', 'ORGANIZATION'), 3),
#  (('last week', 'DATE'), 3),
#  (('Trump', 'LOCATION'), 3),
#  (('Mr Walker', 'PERSON'), 3),
#  (('Donald John Trump', 'PERSON'), 3),
#  (('European Union', 'ORGANIZATION'), 3),
#  (('Chelmsford', 'LOCATION'), 3),
#  (('20th century', 'DATE'), 3),
#  (('1950s', 'DATE'), 3),
#  (('Alistair Carmichael', 'PERSON'), 3),
#  (('this weekend', 'DATE'), 3),
#  (('Defence', 'ORGANIZATION'), 3),
#  (('Bethnal Green', 'ORGANIZATION'), 3),
#  (('James Cartlidge', 'PERSON'), 3),
#  (('US Administration', 'ORGANIZATION'), 3),
#  (('Vladimir Putin', 'PERSON'), 3),
#  (('Cardiff South', 'ORGANIZATION'), 3),
#  (('Westminster Hall', 'LOCATION'), 3),
#  (('Chris Bryant', 'PERSON'), 3),
#  (('Foreign Affairs Committee', 'ORGANIZATION'), 3),
#  (('Atlantic', 'LOCATION'), 3),
#  (('Hannah Bardell', 'PERSON'), 3),
#  (('Eisenhower', 'PERSON'), 3),
#  (('Mr Trump', 'PERSON'), 3),
#  (('Carmichael', 'PERSON'), 3),
#  (('State', 'ORGANIZATION'), 3),
#  (('Department for Transport', 'ORGANIZATION'), 3),
#  (('House of Lords', 'ORGANIZATION'), 3),
#  (('Kenilworth', 'LOCATION'), 3),
#  (('Holborn', 'PERSON'), 3),
#  (('Solihull Council', 'ORGANIZATION'), 3),
#  (('Neil', 'PERSON'), 3),
#  (('Holborn', 'LOCATION'), 3),
#  (('HS2 Ltd.', 'ORGANIZATION'), 3),
#  (('Nissan', 'ORGANIZATION'), 3),
#  (('Joe', 'PERSON'), 2),
#  (('Murray', 'PERSON'), 2),
#  (('Gordon', 'LOCATION'), 2),
#  (('morning', 'TIME'), 2),
#  (('Paris', 'LOCATION'), 2),
#  (('Munich', 'LOCATION'), 2),
#  (('California', 'LOCATION'), 2),
#  (('South Africa', 'LOCATION'), 2),
#  (('summer', 'DATE'), 2),
#  (('# 10 million', 'MONEY'), 2),
#  (('MND Association', 'ORGANIZATION'), 2),
#  (('Euan MacDonald', 'PERSON'), 2),
#  (('Japan', 'LOCATION'), 2),
#  (('February 2017', 'DATE'), 2),
#  (('Gentleman', 'PERSON'), 2),
#  (('House of Commons', 'ORGANIZATION'), 2),
#  (('Newport West', 'LOCATION'), 2),
#  (('State Visit', 'ORGANIZATION'), 2),
#  (('Dewsbury', 'LOCATION'), 2),
#  (('Brighton', 'LOCATION'), 2),
#  (('South Korea', 'LOCATION'), 2),
#  (('Commonwealth Office', 'ORGANIZATION'), 2),
#  (('Andrew Rawnsley', 'PERSON'), 2),
#  (('Donald Trump', 'ORGANIZATION'), 2),
#  (('Brexit', 'PERSON'), 2),
#  (('Melania Trump', 'PERSON'), 2),
#  (('Reagan', 'PERSON'), 2),
#  (('1914', 'DATE'), 2),
#  (('1939', 'DATE'), 2),
#  (('Poland', 'LOCATION'), 2),
#  (('21st century', 'DATE'), 2),
#  (('Orkney', 'ORGANIZATION'), 2),
#  (('2 %', 'PERCENT'), 2),
#  (('2006', 'DATE'), 2),
#  (('Mr Speaker', 'PERSON'), 2),
#  (('Tony Blair', 'PERSON'), 2),
#  (('Government Members', 'ORGANIZATION'), 2),
#  (('Jim Cunningham', 'PERSON'), 2),
#  (('Coventry South', 'ORGANIZATION'), 2),
#  (('Mandela', 'PERSON'), 2),
#  (('2020', 'DATE'), 2),
#  (('2013', 'DATE'), 2),
#  (('Rushanara Ali', 'ORGANIZATION'), 2),
#  (('Crispin Blunt', 'PERSON'), 2),
#  (('Reigate', 'LOCATION'), 2),
#  (('this morning', 'TIME'), 2),
#  (('Congress', 'ORGANIZATION'), 2),
#  (('Pentagon', 'ORGANIZATION'), 2),
#  (('CIA', 'ORGANIZATION'), 2),
#  (('Islamophobia', 'LOCATION'), 2),
#  (('Colombia', 'LOCATION'), 2),
#  (('Procedure Committee', 'ORGANIZATION'), 2),
#  (('Saudi Arabia', 'LOCATION'), 2),
#  (('Indonesia', 'LOCATION'), 2),
#  (('Hampstead', 'LOCATION'), 2),
#  (('Kilburn', 'PERSON'), 2),
#  (('Barack Obama', 'PERSON'), 2),
#  (('Martin Vickers', 'PERSON'), 2),
#  (('Maybole', 'LOCATION'), 2),
#  (('American Presidents', 'ORGANIZATION'), 2),
#  (('Penarth', 'ORGANIZATION'), 2),
#  (('Opposition Members', 'ORGANIZATION'), 2),
#  (('Daniel Zeichner', 'PERSON'), 2),
#  (('Fox News', 'ORGANIZATION'), 2),
#  (('today', 'DATE'), 2),
#  (('Hodge Hill', 'ORGANIZATION'), 2),
#  (('US State Department', 'ORGANIZATION'), 2),
#  (('2012', 'DATE'), 2),
#  (('Opposition', 'ORGANIZATION'), 2),
#  (('Seema Malhotra', 'PERSON'), 2),
#  (('Turner', 'PERSON'), 2),
#  (('West Midlands', 'LOCATION'), 2),
#  (('Chelmsley Wood', 'LOCATION'), 2),
#  (('Solihull', 'LOCATION'), 2),
#  (('Solihull Metropolitan Borough Council', 'ORGANIZATION'), 2),
#  (('Labour Government', 'ORGANIZATION'), 2),
#  (('Secretaries of State', 'ORGANIZATION'), 2),
#  (('Andy McDonald', 'ORGANIZATION'), 2),
#  (('CLA', 'ORGANIZATION'), 2),
#  (('Southam', 'ORGANIZATION'), 2),
#  (('Beaconsfield', 'ORGANIZATION'), 2),
#  (('Simon Kirby', 'PERSON'), 2),
#  (('Lord Snape', 'PERSON'), 2),
#  (('Grieve', 'PERSON'), 2),
#  (('Great Missenden', 'LOCATION'), 2),
#  (('Members of Parliament', 'ORGANIZATION'), 2),
#  (('National Exhibition Centre', 'ORGANIZATION'), 2),
#  (('Coventry', 'ORGANIZATION'), 2),
#  (('St Pancras', 'LOCATION'), 2),
#  (('September', 'DATE'), 2),
#  (('Barnett', 'ORGANIZATION'), 2),
#  (('Barnett', 'PERSON'), 2),
#  (('Secretary of State for Business', 'ORGANIZATION'), 2),
#  (('Thursday', 'DATE'), 2),
#  (('Carlos Tavares', 'PERSON'), 2),
#  (('Brexit', 'LOCATION'), 2),
#  (('South West Bedfordshire', 'LOCATION'), 2),
#  (('Bedfordshire', 'LOCATION'), 2),
#  (('Rebecca Long Bailey', 'PERSON'), 2),
#  (('Salford', 'ORGANIZATION'), 2),
#  (('Eccles', 'PERSON'), 2),
#  (('French Government', 'ORGANIZATION'), 2),
#  (('Peugeot', 'ORGANIZATION'), 2),
#  (('Automotive Council', 'ORGANIZATION'), 2),
#  (('75 %', 'PERCENT'), 2),
#  (('80 %', 'PERCENT'), 2),
#  (('Cheshire', 'LOCATION'), 2),
#  (('Vauxhall Ellesmere Port', 'ORGANIZATION'), 2),
#  (('PSA Group', 'ORGANIZATION'), 2),
#  (('Neurone DiseaseGordon Aikman Motion', 'ORGANIZATION'), 1),
#  (('Chris Heaton-Harris', 'PERSON'), 1),
#  (('February', 'DATE'), 1),
#  (('South Leicestershire', 'LOCATION'), 1),
#  (('Rutland', 'LOCATION'), 1),
#  (('Ruth Morrison', 'PERSON'), 1),
#  (('Nancy', 'PERSON'), 1),
#  (('Lorraine', 'PERSON'), 1),
#  (('University of Edinburgh', 'ORGANIZATION'), 1),
#  (('Sunday', 'DATE'), 1),
#  (('Twitter', 'DATE'), 1),
#  (('Western General', 'ORGANIZATION'), 1),
#  (('Motor Neurone Disease', 'ORGANIZATION'), 1),
#  (('Boston', 'LOCATION'), 1),
#  (('Amsterdam', 'LOCATION'), 1),
#  (('Dublin', 'LOCATION'), 1),
#  (('Stockholm', 'LOCATION'), 1),
#  (('Madrid', 'LOCATION'), 1),
#  (('Tenerife', 'LOCATION'), 1),
#  (('Prague', 'LOCATION'), 1),
#  (('Tuscany', 'LOCATION'), 1),
#  (('Newquay', 'LOCATION'), 1),
#  (('Cork', 'ORGANIZATION'), 1),
#  (('Orkney', 'LOCATION'), 1),
#  (('Fort William', 'LOCATION'), 1),
#  (('Israel', 'LOCATION'), 1),
#  (('Switzerland', 'LOCATION'), 1),
#  (('Mary II', 'PERSON'), 1),
#  (('Iceland', 'LOCATION'), 1),
#  (('Chris Stephens', 'PERSON'), 1),
#  (('Glasgow South West', 'LOCATION'), 1),
#  (('First Minister of Scotland', 'ORGANIZATION'), 1),
#  (('95 %', 'PERCENT'), 1),
#  (('50 %', 'PERCENT'), 1),
#  (('Menzies', 'PERSON'), 1),
#  (('Palace Yard', 'ORGANIZATION'), 1),
#  (('Eleanor Laing', 'PERSON'), 1),
#  (('# 14 million', 'MONEY'), 1),
#  (('Edinburgh University', 'ORGANIZATION'), 1),
#  (('ALS Association', 'ORGANIZATION'), 1),
#  (('Dumfries', 'LOCATION'), 1),
#  (('Galloway', 'PERSON'), 1),
#  (('Richard Arkless', 'PERSON'), 1),
#  (('Wigan', 'ORGANIZATION'), 1),
#  (('Under-Secretary of State for Health', 'ORGANIZATION'), 1),
#  (('Warrington South', 'ORGANIZATION'), 1),
#  (('David Mowat', 'PERSON'), 1),
#  (('Christmas', 'DATE'), 1),
#  (('DWP', 'ORGANIZATION'), 1),
#  (('Robert Wilson', 'PERSON'), 1),
#  (('August last year', 'DATE'), 1),
#  (('Deloitte', 'ORGANIZATION'), 1),
#  (('1998', 'DATE'), 1),
#  (('Robert', 'PERSON'), 1),
#  (('Foundation of Hearts', 'ORGANIZATION'), 1),
#  (('Midlothian', 'LOCATION'), 1),
#  (('Robert', 'LOCATION'), 1),
#  (('Scottish Parliament', 'ORGANIZATION'), 1),
#  (('Scottish Labour Party', 'ORGANIZATION'), 1),
#  (('Scottish Government', 'ORGANIZATION'), 1),
#  (('100 %', 'PERCENT'), 1),
#  (('Kezia Dugdale', 'PERSON'), 1),
#  (('Gordon Lewis Aikman', 'PERSON'), 1),
#  (('April 1985', 'DATE'), 1),
#  (('Joseph Johnson', 'PERSON'), 1),
#  (('Chamber today', 'DATE'), 1),
#  (('# 1 billion', 'MONEY'), 1),
#  (('National Institute for Health Research', 'ORGANIZATION'), 1),
#  (('# 53 million', 'MONEY'), 1),
#  (('2015-16', 'DATE'), 1),
#  (('# 3 billion', 'MONEY'), 1),
#  (('Medical Research Council', 'ORGANIZATION'), 1),
#  (('Biological Sciences Research Council', 'ORGANIZATION'), 1),
#  (('MRC Laboratory of Molecular Biology', 'ORGANIZATION'), 1),
#  (('UCL Institute of Neurology', 'ORGANIZATION'), 1),
#  (('National Hospital for Neurology', 'ORGANIZATION'), 1),
#  (('the University of Oxford', 'ORGANIZATION'), 1),
#  (('# 4.7 million', 'MONEY'), 1),
#  (('National Institute for Health and Care Excellence', 'ORGANIZATION'), 1),
#  (('February 2016', 'DATE'), 1),
#  (('the Motor Neurone Disease Association', 'ORGANIZATION'), 1),
#  (('Public Gallery', 'LOCATION'), 1),
#  (('Public Gallery', 'ORGANIZATION'), 1),
#  (('U.K.', 'LOCATION'), 1),
#  (('US Government', 'ORGANIZATION'), 1),
#  (('1952', 'DATE'), 1),
#  (('Lithuania', 'LOCATION'), 1),
#  (('Pritchard', 'PERSON'), 1),
#  (('South China', 'LOCATION'), 1),
#  (('Ukraine', 'LOCATION'), 1),
#  (('Jacob Rees-Mogg', 'PERSON'), 1),
#  (('North East Somerset', 'LOCATION'), 1),
#  (('Emperor Hirohito', 'PERSON'), 1),
#  (('Nanking', 'LOCATION'), 1),
#  (('Michael Flynn', 'PERSON'), 1),
#  (('Caroline Lucas', 'PERSON'), 1),
#  (('Pavilion', 'LOCATION'), 1),
#  (('97 %', 'PERCENT'), 1),
#  (('Lord Ricketts', 'PERSON'), 1),
#  (('Trump Big Brother', 'ORGANIZATION'), 1),
#  (('Adam Holloway', 'PERSON'), 1),
#  (('last seven days', 'DATE'), 1),
#  (('Richard Nixon', 'PERSON'), 1),
#  (('Rees-Mogg', 'PERSON'), 1),
#  (('Mr Flynn', 'PERSON'), 1),
#  (('Donald J. Trump', 'PERSON'), 1),
#  (('Ribble Valley', 'LOCATION'), 1),
#  (('2015', 'DATE'), 1),
#  (('Conservative Government', 'ORGANIZATION'), 1),
#  (('Nancy Pelosi', 'PERSON'), 1),
#  (('George Clooney', 'PERSON'), 1),
#  (('Harry Reid', 'PERSON'), 1),
#  (('Barron Trump', 'ORGANIZATION'), 1),
#  (('Lord', 'ORGANIZATION'), 1),
#  (('Florida', 'LOCATION'), 1),
#  (('Slovenia', 'LOCATION'), 1),
#  (('Tiananmen Square', 'LOCATION'), 1),
#  (('David Lammy', 'PERSON'), 1),
#  (('Tottenham', 'LOCATION'), 1),
#  (('Holloway', 'PERSON'), 1),
#  (('Ku Klux Klan', 'PERSON'), 1),
#  (('Black History Month', 'ORGANIZATION'), 1),
#  (('Kennedy', 'LOCATION'), 1),
#  (('Truman', 'PERSON'), 1),
#  (('Julian Lewis', 'PERSON'), 1),
#  (('1918', 'DATE'), 1),
#  (('1945', 'DATE'), 1),
#  (('Belgium', 'LOCATION'), 1),
#  (('1949', 'DATE'), 1),
#  (('James Duddridge', 'PERSON'), 1),
#  (('Rochford', 'ORGANIZATION'), 1),
#  (('Southend East', 'LOCATION'), 1),
#  (('Defence Select Committee', 'ORGANIZATION'), 1),
#  (('3.5 %', 'PERCENT'), 1),
#  (('Charles', 'PERSON'), 1),
#  (('P. G. Wodehouse', 'PERSON'), 1),
#  (('Justin Trudeau', 'PERSON'), 1),
#  (('Canada', 'LOCATION'), 1),
#  (('Salmond', 'PERSON'), 1),
#  (('Alex Salmond Mr Walker', 'PERSON'), 1),
#  (('Kremlin', 'ORGANIZATION'), 1),
#  (('Penarth', 'LOCATION'), 1),
#  (('1944', 'DATE'), 1),
#  (('Nazis', 'ORGANIZATION'), 1),
#  (('Normandy', 'LOCATION'), 1),
#  (('Omaha', 'LOCATION'), 1),
#  (('American Administration', 'ORGANIZATION'), 1),
#  (('Rupa Huq', 'PERSON'), 1),
#  (('Ealing Central', 'ORGANIZATION'), 1),
#  (('Erdogan', 'PERSON'), 1),
#  (('Trudeau', 'PERSON'), 1),
#  (('Mall', 'ORGANIZATION'), 1),
#  (('Palace of Westminster', 'ORGANIZATION'), 1),
#  (('Westminster Hall', 'PERSON'), 1),
#  (('Benedict', 'PERSON'), 1),
#  (('Gulf', 'LOCATION'), 1),
#  (('Aung San Suu Kyi', 'LOCATION'), 1),
#  (('Burmese Government', 'ORGANIZATION'), 1),
#  (('1788', 'DATE'), 1),
#  (('James Madison', 'PERSON'), 1),
#  (('New Hampshire', 'LOCATION'), 1),
#  (('Wisconsin', 'LOCATION'), 1),
#  (('South Carolina', 'LOCATION'), 1),
#  (('Prime Ministers', 'ORGANIZATION'), 1),
#  (('Edward Heath', 'PERSON'), 1),
#  (('Bible', 'LOCATION'), 1),
#  (('2001', 'DATE'), 1),
#  (('Bradford West', 'LOCATION'), 1),
#  (('past 31 days', 'DATE'), 1),
#  (('Muslim Council of Britain', 'ORGANIZATION'), 1),
#  (('# 31 billion-plus', 'MONEY'), 1),
#  (('# 20.5 billion', 'MONEY'), 1),
#  (('James Berry', 'PERSON'), 1),
#  (('Kingston', 'LOCATION'), 1),
#  (('Surbiton', 'ORGANIZATION'), 1),
#  (('Mabs Hussain', 'PERSON'), 1),
#  (('Iqra Primary School', 'ORGANIZATION'), 1),
#  (('Sahara', 'LOCATION'), 1),
#  (('Lister', 'PERSON'), 1),
#  (('Bradford', 'PERSON'), 1),
#  (('Defence Committee', 'ORGANIZATION'), 1),
#  (('Joanna Cherry', 'PERSON'), 1),
#  (('Edinburgh South West', 'LOCATION'), 1),
#  (('Radio Scotland', 'LOCATION'), 1),
#  (('Philadelphia', 'LOCATION'), 1),
#  (('State Department', 'ORGANIZATION'), 1),
#  (('Rhondda', 'LOCATION'), 1),
#  (('US Head of State', 'ORGANIZATION'), 1),
#  (('Head of Government', 'ORGANIZATION'), 1),
#  (('White House of the State Department', 'ORGANIZATION'), 1),
#  (('Kirsten Oswald', 'PERSON'), 1),
#  (("Trump 's Administration", 'ORGANIZATION'), 1),
#  (('Sweden', 'LOCATION'), 1),
#  (('41 %', 'PERCENT'), 1),
#  (('Ceausescu', 'PERSON'), 1),
#  (('Edward Leigh That', 'PERSON'), 1),
#  (('Mugabe', 'PERSON'), 1),
#  (('Iraq', 'ORGANIZATION'), 1),
#  (('Livingston', 'PERSON'), 1),
#  (('Edward Leigh I', 'PERSON'), 1),
#  (('Tulip Siddiq', 'PERSON'), 1),
#  (('Nixon', 'PERSON'), 1),
#  (('George Bush', 'PERSON'), 1),
#  (('Whitehall', 'ORGANIZATION'), 1),
#  (('Trump Administration', 'ORGANIZATION'), 1),
#  (('Roger Mullin', 'PERSON'), 1),
#  (('Kirkcaldy', 'LOCATION'), 1),
#  (('September 1959', 'DATE'), 1),
#  (('Ayrshire', 'LOCATION'), 1),
#  (('autumn', 'DATE'), 1),
#  (('1946', 'DATE'), 1),
#  (('1953', 'DATE'), 1),
#  (('1961', 'DATE'), 1),
#  (('1959', 'DATE'), 1),
#  (('March 1939', 'DATE'), 1),
#  (('Clinton', 'PERSON'), 1),
#  (('Hugh MacDiarmid', 'PERSON'), 1),
#  (('Mrs Anne Main', 'PERSON'), 1),
#  (('Glasgow North West', 'LOCATION'), 1),
#  (('Nicola Sturgeon', 'PERSON'), 1),
#  (('Michelle Thomson', 'PERSON'), 1),
#  (('Edinburgh West', 'LOCATION'), 1),
#  (('Randy Krone', 'PERSON'), 1),
#  (('Dallas', 'LOCATION'), 1),
#  (('Australia', 'LOCATION'), 1),
#  (('Pandora', 'ORGANIZATION'), 1),
#  (('Patrick Grady', 'PERSON'), 1),
#  (('Glasgow North', 'ORGANIZATION'), 1),
#  (('this one this evening', 'TIME'), 1),
#  (('this afternoon', 'TIME'), 1),
#  (('Nigel Farage', 'PERSON'), 1),
#  (('Trump Tower', 'ORGANIZATION'), 1),
#  (('November', 'DATE'), 1),
#  (('Gregory Campbell', 'PERSON'), 1),
#  (('East Londonderry', 'LOCATION'), 1),
#  (('Candidate Trump', 'ORGANIZATION'), 1),
#  (('the Netherlands', 'LOCATION'), 1),
#  (('Westminster', 'LOCATION'), 1),
#  (('Brussels', 'LOCATION'), 1),
#  (('Dawn Butler', 'PERSON'), 1),
#  (('Edmund Burke', 'PERSON'), 1),
#  (('Martin Luther King', 'ORGANIZATION'), 1),
#  (('Selby', 'ORGANIZATION'), 1),
#  (('British Prime Ministers', 'ORGANIZATION'), 1),
#  (('Ms Tasmina Ahmed-Sheikh', 'ORGANIZATION'), 1),
#  (('South Perthshire', 'LOCATION'), 1),
#  (('Natalie McGarry', 'PERSON'), 1),
#  (('Glasgow East', 'LOCATION'), 1),
#  (('Jane Austen', 'PERSON'), 1),
#  (('Selby', 'PERSON'), 1),
#  (('Kuwait', 'LOCATION'), 1),
#  (('US Administrations', 'ORGANIZATION'), 1),
#  (('Duchess of Cambridge', 'ORGANIZATION'), 1),
#  (('Kate', 'PERSON'), 1),
#  (('Geneva', 'LOCATION'), 1),
#  (('Home Secretary', 'ORGANIZATION'), 1),
#  (('Daesh', 'LOCATION'), 1),
#  (('Putin', 'PERSON'), 1),
#  (('Catherine West', 'PERSON'), 1),
#  (('Hornsey', 'ORGANIZATION'), 1),
#  (('Butler', 'PERSON'), 1),
#  (('earlier this month', 'DATE'), 1),
#  (('Tottenham', 'ORGANIZATION'), 1),
#  (('Iraq', 'LOCATION'), 1),
#  (('Syria', 'LOCATION'), 1),
#  (('Iran', 'LOCATION'), 1),
#  (('Somalia', 'LOCATION'), 1),
#  (('Sudan', 'LOCATION'), 1),
#  (('Yemen', 'LOCATION'), 1),
#  (('Angela Merkel', 'PERSON'), 1),
#  (('Tulip Siddiq', 'ORGANIZATION'), 1),
#  (('Paula Sherriff', 'ORGANIZATION'), 1),
#  (("Her Majesty 's Government", 'ORGANIZATION'), 1),
#  (('Wood Green', 'ORGANIZATION'), 1),
#  (('Catherine West', 'LOCATION'), 1),
#  (('Royal Visits Committee', 'ORGANIZATION'), 1),
#  (('Cabinet Office', 'ORGANIZATION'), 1),
#  (('Department for International Trade', 'ORGANIZATION'), 1),
#  (('Friday', 'DATE'), 1),
#  (('US Secretary of Homeland Security', 'ORGANIZATION'), 1),
#  (('John Kelly', 'PERSON'), 1),
#  (('Finland', 'LOCATION'), 1),
#  (('Feltham', 'PERSON'), 1),
#  (('1960', 'DATE'), 1),
#  (('1996', 'DATE'), 1),
#  (('2011', 'DATE'), 1),
#  (('Mr Salmond', 'PERSON'), 1),
#  (('Alan Duncan Thank', 'PERSON'), 1),
#  (('February 1917', 'DATE'), 1),
#  (('Acquire Land Compulsorily 18:01:00 The Parliamentary Under-Secretary of State for Transport',
#    'ORGANIZATION'),
#   1),
#  (('Lord Ahmad of Wimbledon', 'ORGANIZATION'), 1),
#  (('Lord Viscount Younger', 'PERSON'), 1),
#  (('Baroness Buscombe', 'PERSON'), 1),
#  (('Lord Walker', 'PERSON'), 1),
#  (('Secretary of State for Transport', 'ORGANIZATION'), 1),
#  (('1984', 'DATE'), 1),
#  (('Transport', 'ORGANIZATION'), 1),
#  (('John Spellar', 'PERSON'), 1),
#  (('Warley', 'ORGANIZATION'), 1),
#  (('TRO', 'ORGANIZATION'), 1),
#  (('McDonald', 'PERSON'), 1),
#  (('Middlesbrough', 'LOCATION'), 1),
#  (('Spellar', 'PERSON'), 1),
#  (('Transport Ministers', 'ORGANIZATION'), 1),
#  (('Andy McDonald', 'PERSON'), 1),
#  (('2009', 'DATE'), 1),
#  (('2010', 'DATE'), 1),
#  (('Cheryl Gillan', 'PERSON'), 1),
#  (('McDonald Let', 'ORGANIZATION'), 1),
#  (('Secretaries of State and Ministers', 'ORGANIZATION'), 1),
#  (('London Borough Camden', 'LOCATION'), 1),
#  (('Camden Borough Council and Transport', 'ORGANIZATION'), 1),
#  (('TfL', 'ORGANIZATION'), 1),
#  (('Camden Council', 'ORGANIZATION'), 1),
#  (('Labour', 'ORGANIZATION'), 1),
#  (('McDonald There', 'ORGANIZATION'), 1),
#  (('Deutsche Bahn', 'ORGANIZATION'), 1),
#  (('SNCF', 'ORGANIZATION'), 1),
#  (('Nederlandse Spoorwegen', 'ORGANIZATION'), 1),
#  (('State for Transport', 'ORGANIZATION'), 1),
#  (('Jeremy Wright', 'PERSON'), 1),
#  (('Dominic Grieve', 'PERSON'), 1),
#  (('David', 'PERSON'), 1),
#  (('Rolls-Royce', 'ORGANIZATION'), 1),
#  (('Financial Times', 'ORGANIZATION'), 1),
#  (('January 2017', 'DATE'), 1),
#  (('Chilterns', 'LOCATION'), 1),
#  (('Snape', 'PERSON'), 1),
#  (('Missenden Parish Council', 'ORGANIZATION'), 1),
#  (('October 2016', 'DATE'), 1),
#  (('Aylesbury', 'LOCATION'), 1),
#  (('House of Lords Committee', 'ORGANIZATION'), 1),
#  (('Holborn', 'ORGANIZATION'), 1),
#  (('Natascha Engel', 'ORGANIZATION'), 1),
#  (('Gillan Thank', 'PERSON'), 1),
#  (('Hilary Wharf', 'PERSON'), 1),
#  (('Bruce Weston', 'PERSON'), 1),
#  (('HS2 Action Alliance', 'ORGANIZATION'), 1),
#  (('Councillor Martin Tett', 'PERSON'), 1),
#  (('Chiltern District Council', 'ORGANIZATION'), 1),
#  (('Isobel Darby', 'PERSON'), 1),
#  (('last weekend', 'DATE'), 1),
#  (('Google', 'ORGANIZATION'), 1),
#  (('Clerks Department', 'ORGANIZATION'), 1),
#  (('Ray Challinor', 'PERSON'), 1),
#  (('Hyde Heath', 'PERSON'), 1),
#  (('Alan Brown', 'PERSON'), 1),
#  (('Kilmarnock', 'ORGANIZATION'), 1),
#  (('Bill', 'PERSON'), 1),
#  (('Crewe', 'LOCATION'), 1),
#  (('Bickenhill', 'LOCATION'), 1),
#  (('Blythe', 'PERSON'), 1),
#  (('Birmingham City University', 'ORGANIZATION'), 1),
#  (('Natural Capital Committee', 'ORGANIZATION'), 1),
#  (('Treasury', 'ORGANIZATION'), 1),
#  (('Chiltern', 'PERSON'), 1),
#  (('London Euston', 'LOCATION'), 1),
#  (('the Transport Secretary', 'ORGANIZATION'), 1),
#  (('August', 'DATE'), 1),
#  (('Gatwick', 'LOCATION'), 1),
#  (('Balsall Common', 'ORGANIZATION'), 1),
#  (('High Speed Rail', 'ORGANIZATION'), 1),
#  (('Bill Committee', 'ORGANIZATION'), 1),
#  (('Commons Select Committee', 'ORGANIZATION'), 1),
#  (('shadow Secretary of State', 'ORGANIZATION'), 1),
#  (("Lord 's Select Committee", 'ORGANIZATION'), 1),
#  (('# 100,000', 'MONEY'), 1),
#  (('Lord Ahmed', 'PERSON'), 1),
#  (('Lords Grand Committee', 'ORGANIZATION'), 1),
#  (('Lords HS2 Committee', 'ORGANIZATION'), 1),
#  (('Euston', 'LOCATION'), 1),
#  (('London Borough of Camden', 'LOCATION'), 1),
#  (('City of Westminster', 'ORGANIZATION'), 1),
#  (('Mark Field', 'ORGANIZATION'), 1),
#  (('Great Missenden', 'PERSON'), 1),
#  (('Doncaster', 'LOCATION'), 1),
#  (('SNP', 'ORGANIZATION'), 1),
#  (('Leeds', 'LOCATION'), 1),
#  (('Leeds', 'ORGANIZATION'), 1),
#  (('Bill through Parliament', 'ORGANIZATION'), 1),
#  (('November 2013', 'DATE'), 1),
#  (('General Motors', 'ORGANIZATION'), 1),
#  (('Tuesday', 'DATE'), 1),
#  (('Ammann', 'PERSON'), 1),
#  (('two hours later', 'DATE'), 1),
#  (('night', 'TIME'), 1),
#  (('Neston', 'LOCATION'), 1),
#  (('IBC', 'ORGANIZATION'), 1),
#  (('Andrew Selous', 'PERSON'), 1),
#  (('Spain', 'LOCATION'), 1),
#  (('Rebecca Long Bailey Haphazard', 'PERSON'), 1),
#  (('David Rutley', 'PERSON'), 1),
#  (('Macclesfield', 'ORGANIZATION'), 1),
#  (('Callum McCaig', 'PERSON'), 1),
#  (('Aberdeen South', 'ORGANIZATION'), 1),
#  (('Neston', 'ORGANIZATION'), 1),
#  (('Lancaster House', 'ORGANIZATION'), 1),
#  (('John Redwood', 'PERSON'), 1),
#  (('Wokingham', 'LOCATION'), 1),
#  (('Hinkley Point C', 'ORGANIZATION'), 1),
#  (('Iain Wright', 'PERSON'), 1),
#  (('Hartlepool', 'LOCATION'), 1),
#  (('Graham Evans', 'PERSON'), 1),
#  (('Weaver Vale', 'ORGANIZATION'), 1),
#  (('Carshalton', 'ORGANIZATION'), 1),
#  (('Andrew Tyrie', 'PERSON'), 1),
#  (('Treasury Committee', 'ORGANIZATION'), 1),
#  (('October', 'DATE'), 1),
#  (('Angela Eagle', 'PERSON'), 1),
#  (('Jeremy Lefroy', 'PERSON'), 1),
#  (('Stafford', 'ORGANIZATION'), 1),
#  (('Aston Martin', 'ORGANIZATION'), 1),
#  (('Triumph', 'ORGANIZATION'), 1),
#  (('Maria Eagle', 'ORGANIZATION'), 1),
#  (('Jaguar Land Rover', 'ORGANIZATION'), 1),
#  (('Seema Kennedy', 'PERSON'), 1),
#  (('Leyland', 'LOCATION'), 1),
#  (('National Automotive Innovation Centre', 'ORGANIZATION'), 1),
#  (('Alison McGovern', 'PERSON'), 1),
#  (('Wirral South', 'ORGANIZATION'), 1),
#  (('Unilever', 'ORGANIZATION'), 1),
#  (('Wirral South', 'LOCATION'), 1),
#  (('Desmond Swayne', 'PERSON'), 1),
#  (('General Motors USA', 'ORGANIZATION'), 1),
#  (('General Motors GB', 'ORGANIZATION'), 1),
#  (('Pat McFadden', 'PERSON'), 1),
#  (('Wolverhampton South East', 'LOCATION'), 1),
#  (('Astra', 'ORGANIZATION'), 1),
#  (('Peter Bone', 'PERSON'), 1),
#  (('Margaret Greenwood', 'PERSON'), 1),
#  (('Wirral', 'LOCATION'), 1),
#  (('Nigel Mills', 'PERSON'), 1),
#  (('Amber Valley', 'ORGANIZATION'), 1),
#  (('Matheson', 'PERSON'), 1),
#  (('Coventry Member', 'ORGANIZATION'), 1),
#  (('Government Departments', 'ORGANIZATION'), 1),
#  (('Craig Whittaker', 'PERSON'), 1),
#  (('Calder Valley', 'ORGANIZATION'), 1),
#  (('1999', 'DATE'), 1),
#  (('Jim Shannon', 'PERSON'), 1),
#  (('Tom Pursglove', 'PERSON'), 1),
#  (('Liz McInnes', 'PERSON'), 1),
#  (('Heywood', 'ORGANIZATION'), 1),
#  (('Middleton', 'PERSON'), 1),
#  (('last few days', 'DATE'), 1),
#  (('Ian C. Lucas', 'PERSON'), 1),
#  (('Wrexham', 'LOCATION'), 1),
#  (('north Wales', 'LOCATION'), 1),
#  (('Merseyside', 'LOCATION'), 1),
#  (('Helen Goodman', 'PERSON'), 1),
#  (('Auckland', 'LOCATION'), 1),
#  (('Kerry McCarthy', 'PERSON'), 1),
#  (('Bristol East', 'LOCATION'), 1),
#  (('the first 40 years', 'DATE'), 1),
#  (('Stephen Timms', 'PERSON'), 1)]

# %%
# Export

file_out = open('four_entity_process_stanford.txt','w+')

for row in counts_sorted:
    for item in row:
        file_out.write("%s, " %(item,))
    file_out.write("\n")
file_out.close()

# %% [markdown]
# ## Conclusion
#
# - 707 entities were found across the 4 debates that took place on 20th Feb 2017
# - out of these, only 19 (15% of the total) occurred 3 or more times; only 9 (7%of the total) occurred 4 or more times
# - these feel like reasonable volumes to then have an expert review and decide whether or not to add to a "known entity lookup"

# %% [markdown]
# ## Scrap Code

# %%
nltk.tag.stanford?

# %%
len(counts_sorted)
# Out:
# 707

# %%
flatten = lambda l: [item for sublist in counts_sorted for item in sublist]

# %%
flatten
# Out:
# <function __main__.<lambda>>

# %%
print(flatten)
# Out:
# <function <lambda> at 0x0000018302B95400>

# %%
flatten(counts_sorted)
# Out:
# [('MND', 'ORGANIZATION'),
#  70,
#  ('Gordon', 'PERSON'),
#  30,
#  ('Scotland', 'LOCATION'),
#  12,
#  ('Gordon Aikman', 'PERSON'),
#  9,
#  ('House', 'ORGANIZATION'),
#  7,
#  ('Ian Murray', 'PERSON'),
#  6,
#  ('this evening', 'TIME'),
#  4,
#  ('First Minister', 'ORGANIZATION'),
#  4,
#  ('# 5 million', 'MONEY'),
#  4,
#  ('Edinburgh South', 'ORGANIZATION'),
#  3,
#  ('2014', 'DATE'),
#  3,
#  ('Edinburgh', 'LOCATION'),
#  3,
#  ('Saturday', 'DATE'),
#  3,
#  ('NHS', 'ORGANIZATION'),
#  3,
#  ('England', 'LOCATION'),
#  3,
#  ('14 %', 'PERCENT'),
#  3,
#  ('MRC', 'ORGANIZATION'),
#  3,
#  ('NHS England', 'ORGANIZATION'),
#  3,
#  ('AAC', 'ORGANIZATION'),
#  3,
#  ('Joe', 'PERSON'),
#  2,
#  ('UK', 'ORGANIZATION'),
#  2,
#  ('Gordon', 'LOCATION'),
#  2,
#  ('summer', 'DATE'),
#  2,
#  ('# 10 million', 'MONEY'),
#  2,
#  ('MND Association', 'ORGANIZATION'),
#  2,
#  ('Euan MacDonald', 'PERSON'),
#  2,
#  ('US', 'LOCATION'),
#  2,
#  ('Government', 'ORGANIZATION'),
#  2,
#  ('Neurone DiseaseGordon Aikman Motion', 'ORGANIZATION'),
#  1,
#  ('Chris Heaton-Harris', 'PERSON'),
#  1,
#  ('February', 'DATE'),
#  1,
#  ('South Leicestershire', 'LOCATION'),
#  1,
#  ('United Kingdom', 'LOCATION'),
#  1,
#  ('Rutland', 'LOCATION'),
#  1,
#  ('Ruth Morrison', 'PERSON'),
#  1,
#  ('Nancy', 'PERSON'),
#  1,
#  ('Lorraine', 'PERSON'),
#  1,
#  ('Murray', 'PERSON'),
#  1,
#  ('University of Edinburgh', 'ORGANIZATION'),
#  1,
#  ('Sunday', 'DATE'),
#  1,
#  ('morning', 'TIME'),
#  1,
#  ('Twitter', 'DATE'),
#  1,
#  ('Western General', 'ORGANIZATION'),
#  1,
#  ('Motor Neurone Disease', 'ORGANIZATION'),
#  1,
#  ('New York', 'LOCATION'),
#  1,
#  ('Boston', 'LOCATION'),
#  1,
#  ('Amsterdam', 'LOCATION'),
#  1,
#  ('Dublin', 'LOCATION'),
#  1,
#  ('Stockholm', 'LOCATION'),
#  1,
#  ('Madrid', 'LOCATION'),
#  1,
#  ('Tenerife', 'LOCATION'),
#  1,
#  ('Prague', 'LOCATION'),
#  1,
#  ('Tuscany', 'LOCATION'),
#  1,
#  ('Newquay', 'LOCATION'),
#  1,
#  ('Paris', 'LOCATION'),
#  1,
#  ('Cork', 'ORGANIZATION'),
#  1,
#  ('Munich', 'LOCATION'),
#  1,
#  ('Orkney', 'LOCATION'),
#  1,
#  ('Fort William', 'LOCATION'),
#  1,
#  ('California', 'LOCATION'),
#  1,
#  ('Israel', 'LOCATION'),
#  1,
#  ('South Africa', 'LOCATION'),
#  1,
#  ('Switzerland', 'LOCATION'),
#  1,
#  ('Mary II', 'PERSON'),
#  1,
#  ('Iceland', 'LOCATION'),
#  1,
#  ('Chris Stephens', 'PERSON'),
#  1,
#  ('Glasgow South West', 'LOCATION'),
#  1,
#  ('First Minister of Scotland', 'ORGANIZATION'),
#  1,
#  ('95 %', 'PERCENT'),
#  1,
#  ('50 %', 'PERCENT'),
#  1,
#  ('Menzies', 'PERSON'),
#  1,
#  ('Secretary of State', 'ORGANIZATION'),
#  1,
#  ('Palace Yard', 'ORGANIZATION'),
#  1,
#  ('Eleanor Laing', 'PERSON'),
#  1,
#  ('Wales', 'LOCATION'),
#  1,
#  ('# 14 million', 'MONEY'),
#  1,
#  ('Madam Deputy Speaker', 'ORGANIZATION'),
#  1,
#  ('Edinburgh University', 'ORGANIZATION'),
#  1,
#  ('Cambridge', 'LOCATION'),
#  1,
#  ('Japan', 'LOCATION'),
#  1,
#  ('United States', 'LOCATION'),
#  1,
#  ('ALS Association', 'ORGANIZATION'),
#  1,
#  ('Dumfries', 'LOCATION'),
#  1,
#  ('Galloway', 'PERSON'),
#  1,
#  ('Richard Arkless', 'PERSON'),
#  1,
#  ('Wigan', 'ORGANIZATION'),
#  1,
#  ('London', 'LOCATION'),
#  1,
#  ('Under-Secretary of State for Health', 'ORGANIZATION'),
#  1,
#  ('Warrington South', 'ORGANIZATION'),
#  1,
#  ('David Mowat', 'PERSON'),
#  1,
#  ('Christmas', 'DATE'),
#  1,
#  ('DWP', 'ORGANIZATION'),
#  1,
#  ('Department', 'ORGANIZATION'),
#  1,
#  ('Robert Wilson', 'PERSON'),
#  1,
#  ('August last year', 'DATE'),
#  1,
#  ('Deloitte', 'ORGANIZATION'),
#  1,
#  ('1998', 'DATE'),
#  1,
#  ('Robert', 'PERSON'),
#  1,
#  ('Foundation of Hearts', 'ORGANIZATION'),
#  1,
#  ('Midlothian', 'LOCATION'),
#  1,
#  ('Robert', 'LOCATION'),
#  1,
#  ('Scottish Parliament', 'ORGANIZATION'),
#  1,
#  ('Scottish Labour Party', 'ORGANIZATION'),
#  1,
#  ('Scottish Government', 'ORGANIZATION'),
#  1,
#  ('Alex Salmond', 'PERSON'),
#  1,
#  ('100 %', 'PERCENT'),
#  1,
#  ('Kezia Dugdale', 'PERSON'),
#  1,
#  ('Gordon Lewis Aikman', 'PERSON'),
#  1,
#  ('April 1985', 'DATE'),
#  1,
#  ('February 2017', 'DATE'),
#  1,
#  ('Joseph Johnson', 'PERSON'),
#  1,
#  ('Chamber today', 'DATE'),
#  1,
#  ('# 1 billion', 'MONEY'),
#  1,
#  ('National Institute for Health Research', 'ORGANIZATION'),
#  1,
#  ('# 53 million', 'MONEY'),
#  1,
#  ('2015-16', 'DATE'),
#  1,
#  ('# 3 billion', 'MONEY'),
#  1,
#  ('Medical Research Council', 'ORGANIZATION'),
#  1,
#  ('Biological Sciences Research Council', 'ORGANIZATION'),
#  1,
#  ('Gentleman', 'PERSON'),
#  1,
#  ('MRC Laboratory of Molecular Biology', 'ORGANIZATION'),
#  1,
#  ('UCL Institute of Neurology', 'ORGANIZATION'),
#  1,
#  ('National Hospital for Neurology', 'ORGANIZATION'),
#  1,
#  ('the University of Oxford', 'ORGANIZATION'),
#  1,
#  ('# 4.7 million', 'MONEY'),
#  1,
#  ('National Institute for Health and Care Excellence', 'ORGANIZATION'),
#  1,
#  ('February 2016', 'DATE'),
#  1,
#  ('the Motor Neurone Disease Association', 'ORGANIZATION'),
#  1]

# %%
for row in ents_tr:
    if row[0].index('Trump')>0:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-c8381639bbd1> in <module>()
#       1 for row in ents_tr:
# ----> 2     if row[0].index('Trump')>0:
#       3         print(row)
#
# ValueError: substring not found

# %%
ents_tr
# Out:
# [('Charles Walker', 'PERSON'),
#  ('Public Gallery', 'LOCATION'),
#  ('House of Commons', 'ORGANIZATION'),
#  ('Public Gallery', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Newport West', 'LOCATION'),
#  ('House', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Walker', 'PERSON'),
#  ('Petitions Committee', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('State Visit', 'ORGANIZATION'),
#  ('U.K.', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('US Government', 'ORGANIZATION'),
#  ('State Visit', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('1952', 'DATE'),
#  ('Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('Alex Salmond', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Paul Flynn', 'PERSON'),
#  ('Europe', 'LOCATION'),
#  ('Europe', 'LOCATION'),
#  ('Lithuania', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Pritchard', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('United Kingdom', 'LOCATION'),
#  ('United States of America', 'LOCATION'),
#  ('White House', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Europe', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('White House', 'ORGANIZATION'),
#  ('South China', 'LOCATION'),
#  ('Ukraine', 'LOCATION'),
#  ('Dewsbury', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Paul Flynn', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Jacob Rees-Mogg', 'PERSON'),
#  ('North East Somerset', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Emperor Hirohito', 'PERSON'),
#  ('Nanking', 'LOCATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Michael Flynn', 'PERSON'),
#  ('Russia', 'LOCATION'),
#  ('Hillary Clinton', 'PERSON'),
#  ('Obama', 'PERSON'),
#  ('Caroline Lucas', 'PERSON'),
#  ('Brighton', 'LOCATION'),
#  ('Pavilion', 'LOCATION'),
#  ('Brighton', 'LOCATION'),
#  ('Trump', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('97 %', 'PERCENT'),
#  ('Trump', 'PERSON'),
#  ('South Korea', 'LOCATION'),
#  ('Japan', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('Her Majesty', 'ORGANIZATION'),
#  ('Commonwealth Office', 'ORGANIZATION'),
#  ('Lord Ricketts', 'PERSON'),
#  ('US', 'LOCATION'),
#  ('Government', 'ORGANIZATION'),
#  ('Nigel Evans', 'PERSON'),
#  ('Ribble Valley', 'ORGANIZATION'),
#  ('Gentleman', 'PERSON'),
#  ('Charles Walker', 'PERSON'),
#  ('Paul Flynn', 'PERSON'),
#  ('Trump', 'ORGANIZATION'),
#  ('Trump Big Brother', 'ORGANIZATION'),
#  ('Adam Holloway', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Paul Flynn', 'PERSON'),
#  ('last seven days', 'DATE'),
#  ('Trump', 'PERSON'),
#  ('Richard Nixon', 'PERSON'),
#  ('last week', 'DATE'),
#  ('America', 'LOCATION'),
#  ('Trump', 'LOCATION'),
#  ('House', 'ORGANIZATION'),
#  ('Andrew Rawnsley', 'PERSON'),
#  ('Britain', 'LOCATION'),
#  ('Donald Trump', 'ORGANIZATION'),
#  ('Andrew Rawnsley', 'PERSON'),
#  ('Rees-Mogg', 'PERSON'),
#  ('Walker', 'PERSON'),
#  ('Charles Walker', 'PERSON'),
#  ('Newport West', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Mr Flynn', 'PERSON'),
#  ('Paul Flynn', 'PERSON'),
#  ('Mr Walker', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Donald J. Trump', 'PERSON'),
#  ('Charles Walker', 'PERSON'),
#  ('Nigel Evans', 'PERSON'),
#  ('Nigel Evans', 'PERSON'),
#  ('Ribble Valley', 'LOCATION'),
#  ('Mr Walker', 'PERSON'),
#  ('2016', 'DATE'),
#  ('2015', 'DATE'),
#  ('Conservative Government', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('United States of America', 'LOCATION'),
#  ('Nancy Pelosi', 'PERSON'),
#  ('George Clooney', 'PERSON'),
#  ('Harry Reid', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Donald John Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Donald John Trump', 'PERSON'),
#  ('Brexit', 'PERSON'),
#  ('European Union', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('United Kingdom', 'LOCATION'),
#  ('United States of America', 'LOCATION'),
#  ('Saturday', 'DATE'),
#  ('Donald Trump', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Donald Trump', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Simon Burns', 'PERSON'),
#  ('Chelmsford', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Hillary Clinton', 'PERSON'),
#  ('Evans', 'PERSON'),
#  ('California', 'LOCATION'),
#  ('New York', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('Administration', 'ORGANIZATION'),
#  ('Administration', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Barron Trump', 'ORGANIZATION'),
#  ('Melania Trump', 'PERSON'),
#  ('Melania Trump', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Lord', 'ORGANIZATION'),
#  ('Saturday', 'DATE'),
#  ('Florida', 'LOCATION'),
#  ('Slovenia', 'LOCATION'),
#  ('House', 'ORGANIZATION'),
#  ('Newport West', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Tiananmen Square', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Donald John Trump', 'PERSON'),
#  ('David Lammy', 'PERSON'),
#  ('Tottenham', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('France', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Britain', 'LOCATION'),
#  ('Holloway', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('Ku Klux Klan', 'PERSON'),
#  ('Black History Month', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Britain', 'LOCATION'),
#  ('Kennedy', 'LOCATION'),
#  ('Truman', 'PERSON'),
#  ('Reagan', 'PERSON'),
#  ('Julian Lewis', 'PERSON'),
#  ('20th century', 'DATE'),
#  ('1950s', 'DATE'),
#  ('1950s', 'DATE'),
#  ('1950s', 'DATE'),
#  ('1914', 'DATE'),
#  ('1918', 'DATE'),
#  ('1939', 'DATE'),
#  ('1945', 'DATE'),
#  ('1914', 'DATE'),
#  ('Belgium', 'LOCATION'),
#  ('United States of America', 'LOCATION'),
#  ('1939', 'DATE'),
#  ('Poland', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('1949', 'DATE'),
#  ('NATO', 'ORGANIZATION'),
#  ('United States of America', 'LOCATION'),
#  ('21st century', 'DATE'),
#  ('Europe', 'LOCATION'),
#  ('James Duddridge', 'PERSON'),
#  ('Rochford', 'ORGANIZATION'),
#  ('Southend East', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Lewis', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Alistair Carmichael', 'PERSON'),
#  ('Orkney', 'ORGANIZATION'),
#  ('this weekend', 'DATE'),
#  ('NATO', 'ORGANIZATION'),
#  ('Lewis', 'PERSON'),
#  ('NATO', 'ORGANIZATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('Defence Select Committee', 'ORGANIZATION'),
#  ('Defence', 'ORGANIZATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('2 %', 'PERCENT'),
#  ('NATO', 'ORGANIZATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('3.5 %', 'PERCENT'),
#  ('NATO', 'ORGANIZATION'),
#  ('2 %', 'PERCENT'),
#  ('Donald Trump', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('NATO', 'ORGANIZATION'),
#  ('Alex Salmond', 'PERSON'),
#  ('Newport West', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Her Majesty', 'ORGANIZATION'),
#  ('Lewis', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Bethnal Green', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Government', 'ORGANIZATION'),
#  ('Alex Salmond', 'PERSON'),
#  ('Trump', 'ORGANIZATION'),
#  ('Charles', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Scotland', 'LOCATION'),
#  ('2006', 'DATE'),
#  ('Alex Salmond', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('New York', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('P. G. Wodehouse', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('UK', 'ORGANIZATION'),
#  ('Government', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Justin Trudeau', 'PERSON'),
#  ('Canada', 'LOCATION'),
#  ('Walker', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('Charles Walker', 'PERSON'),
#  ('Salmond', 'PERSON'),
#  ('Mr Speaker', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Alex Salmond Mr Walker', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('United States of America', 'LOCATION'),
#  ('Newport West', 'LOCATION'),
#  ('United States of America', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('James Cartlidge', 'PERSON'),
#  ('Walker', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('NATO', 'ORGANIZATION'),
#  ('US Administration', 'ORGANIZATION'),
#  ('Administration', 'ORGANIZATION'),
#  ('Vladimir Putin', 'PERSON'),
#  ('Kremlin', 'ORGANIZATION'),
#  ('US', 'LOCATION'),
#  ('Vladimir Putin', 'PERSON'),
#  ('Tony Blair', 'PERSON'),
#  ('Administration', 'ORGANIZATION'),
#  ('Nigel Evans', 'PERSON'),
#  ('US Administration', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Obama', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('James Cartlidge', 'PERSON'),
#  ('EU', 'ORGANIZATION'),
#  ('Obama', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Vladimir Putin', 'PERSON'),
#  ('Russia', 'LOCATION'),
#  ('United Kingdom', 'LOCATION'),
#  ('Stephen Doughty', 'PERSON'),
#  ('Cardiff South', 'ORGANIZATION'),
#  ('Penarth', 'LOCATION'),
#  ('Walker', 'PERSON'),
#  ('Newport West', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('1944', 'DATE'),
#  ('Nazis', 'ORGANIZATION'),
#  ('Government Members', 'ORGANIZATION'),
#  ('Normandy', 'LOCATION'),
#  ('Omaha', 'LOCATION'),
#  ('Europe', 'LOCATION'),
#  ('American Administration', 'ORGANIZATION'),
#  ('George W. Bush', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('Government', 'ORGANIZATION'),
#  ('Rupa Huq', 'PERSON'),
#  ('Ealing Central', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Erdogan', 'PERSON'),
#  ('Stephen Doughty', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Government', 'ORGANIZATION'),
#  ('Gordon', 'PERSON'),
#  ('Alex Salmond', 'PERSON'),
#  ('Trudeau', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Mall', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('Jim Cunningham', 'PERSON'),
#  ('Coventry South', 'ORGANIZATION'),
#  ('Obama', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Stephen Doughty', 'PERSON'),
#  ('Palace of Westminster', 'ORGANIZATION'),
#  ('Westminster Hall', 'PERSON'),
#  ('Mandela', 'PERSON'),
#  ('Obama', 'PERSON'),
#  ('Benedict', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('Gulf', 'LOCATION'),
#  ('Aung San Suu Kyi', 'LOCATION'),
#  ('Burmese Government', 'ORGANIZATION'),
#  ('House', 'ORGANIZATION'),
#  ('1788', 'DATE'),
#  ('James Madison', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Simon Burns', 'PERSON'),
#  ('Chelmsford', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Hillary Clinton', 'PERSON'),
#  ('New Hampshire', 'LOCATION'),
#  ('Wisconsin', 'LOCATION'),
#  ('South Carolina', 'LOCATION'),
#  ('Obama', 'PERSON'),
#  ('2016', 'DATE'),
#  ('20th century', 'DATE'),
#  ('America', 'LOCATION'),
#  ('Hillary Clinton', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Britain', 'LOCATION'),
#  ('Britain', 'LOCATION'),
#  ('Prime Ministers', 'ORGANIZATION'),
#  ('Edward Heath', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Simon Burns', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('2020', 'DATE'),
#  ('Alex Salmond', 'PERSON'),
#  ('Simon Burns', 'PERSON'),
#  ('Bible', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Britain', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('European Union', 'LOCATION'),
#  ('2001', 'DATE'),
#  ('2006', 'DATE'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('Mr Speaker', 'PERSON'),
#  ('Westminster Hall', 'LOCATION'),
#  ('Parliament', 'ORGANIZATION'),
#  ('Naz Shah', 'PERSON'),
#  ('Bradford West', 'ORGANIZATION'),
#  ('Walker', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Bradford West', 'LOCATION'),
#  ('past 31 days', 'DATE'),
#  ('Donald Trump', 'PERSON'),
#  ('White House', 'ORGANIZATION'),
#  ('2013', 'DATE'),
#  ('Muslim Council of Britain', 'ORGANIZATION'),
#  ('# 31 billion-plus', 'MONEY'),
#  ('# 20.5 billion', 'MONEY'),
#  ('2013', 'DATE'),
#  ('London', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Naz Shah', 'PERSON'),
#  ('James Berry', 'PERSON'),
#  ('Kingston', 'LOCATION'),
#  ('Surbiton', 'ORGANIZATION'),
#  ('Bethnal Green', 'ORGANIZATION'),
#  ('Rushanara Ali', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('US', 'LOCATION'),
#  ('US', 'LOCATION'),
#  ('Naz Shah', 'PERSON'),
#  ('Bradford West', 'ORGANIZATION'),
#  ('Mabs Hussain', 'PERSON'),
#  ('Iqra Primary School', 'ORGANIZATION'),
#  ('Sahara', 'LOCATION'),
#  ('Lister', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Bradford', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('China', 'LOCATION'),
#  ('China', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('United States of America', 'LOCATION'),
#  ('House', 'ORGANIZATION'),
#  ('Lewis', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('House', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Crispin Blunt', 'PERSON'),
#  ('Reigate', 'LOCATION'),
#  ('Mr Walker', 'PERSON'),
#  ('Newport West', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Her Majesty', 'ORGANIZATION'),
#  ('United Kingdom', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('Defence Committee', 'ORGANIZATION'),
#  ('Lewis', 'PERSON'),
#  ('Joanna Cherry', 'PERSON'),
#  ('Edinburgh South West', 'LOCATION'),
#  ('Radio Scotland', 'LOCATION'),
#  ('this morning', 'TIME'),
#  ('Trump', 'LOCATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('Europe', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Philadelphia', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United Kingdom', 'LOCATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('Congress', 'ORGANIZATION'),
#  ('Congress', 'ORGANIZATION'),
#  ('State Department', 'ORGANIZATION'),
#  ('Pentagon', 'ORGANIZATION'),
#  ('CIA', 'ORGANIZATION'),
#  ('White House', 'ORGANIZATION'),
#  ('Alex Salmond', 'PERSON'),
#  ('Alex Salmond', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('White House', 'ORGANIZATION'),
#  ('Defence', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('Administration', 'ORGANIZATION'),
#  ('Chris Bryant', 'PERSON'),
#  ('Rhondda', 'LOCATION'),
#  ('Administration', 'ORGANIZATION'),
#  ('White House', 'ORGANIZATION'),
#  ('2020', 'DATE'),
#  ('United States', 'LOCATION'),
#  ('United Kingdom', 'LOCATION'),
#  ('US Head of State', 'ORGANIZATION'),
#  ('Administration', 'ORGANIZATION'),
#  ('Head of Government', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('Europe', 'LOCATION'),
#  ('White House of the State Department', 'ORGANIZATION'),
#  ('Pentagon', 'ORGANIZATION'),
#  ('CIA', 'ORGANIZATION'),
#  ('Charles Walker', 'PERSON'),
#  ('Kirsten Oswald', 'PERSON'),
#  ('Walker', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('UK Government', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('America', 'LOCATION'),
#  ("Trump 's Administration", 'ORGANIZATION'),
#  ('EU', 'ORGANIZATION'),
#  ('UK Government', 'ORGANIZATION'),
#  ('Sweden', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Islamophobia', 'LOCATION'),
#  ('41 %', 'PERCENT'),
#  ('England', 'LOCATION'),
#  ('Wales', 'LOCATION'),
#  ('UK Government', 'ORGANIZATION'),
#  ('Scotland', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('UK Government', 'ORGANIZATION'),
#  ('Edward Leigh', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('China', 'LOCATION'),
#  ('China', 'LOCATION'),
#  ('Ceausescu', 'PERSON'),
#  ('Chris Bryant', 'PERSON'),
#  ('Colombia', 'LOCATION'),
#  ('Colombia', 'LOCATION'),
#  ('Foreign Affairs Committee', 'ORGANIZATION'),
#  ('Procedure Committee', 'ORGANIZATION'),
#  ('Edward Leigh That', 'PERSON'),
#  ('Mugabe', 'PERSON'),
#  ('Saudi Arabia', 'LOCATION'),
#  ('Saudi Arabia', 'LOCATION'),
#  ('Lewis', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('NATO', 'ORGANIZATION'),
#  ('Ribble Valley', 'ORGANIZATION'),
#  ('Evans', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Atlantic', 'LOCATION'),
#  ('House', 'ORGANIZATION'),
#  ('Iraq', 'ORGANIZATION'),
#  ('NHS', 'ORGANIZATION'),
#  ('Atlantic', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Hannah Bardell', 'PERSON'),
#  ('Livingston', 'PERSON'),
#  ('Edward Leigh', 'PERSON'),
#  ('Hannah Bardell', 'PERSON'),
#  ('Trump', 'ORGANIZATION'),
#  ('House', 'ORGANIZATION'),
#  ('Edward Leigh I', 'PERSON'),
#  ('Alex Salmond', 'PERSON'),
#  ('Edward Leigh', 'PERSON'),
#  ('Indonesia', 'LOCATION'),
#  ('Indonesia', 'LOCATION'),
#  ('Obama', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Andrew Turner', 'PERSON'),
#  ('Tulip Siddiq', 'PERSON'),
#  ('Hampstead', 'LOCATION'),
#  ('Kilburn', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Government', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('America', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Newport West', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Barack Obama', 'PERSON'),
#  ('George W. Bush', 'PERSON'),
#  ('Nixon', 'PERSON'),
#  ('George Bush', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Whitehall', 'ORGANIZATION'),
#  ('House', 'ORGANIZATION'),
#  ('Donald Trump', 'PERSON'),
#  ('Trump Administration', 'ORGANIZATION'),
#  ('Chelmsford', 'LOCATION'),
#  ('Simon Burns', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Martin Vickers', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Government', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('Bradford West', 'ORGANIZATION'),
#  ('Naz Shah', 'PERSON'),
#  ('Naz Shah', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Martin Vickers', 'PERSON'),
#  ('Ribble Valley', 'ORGANIZATION'),
#  ('Evans', 'PERSON'),
#  ('USA', 'ORGANIZATION'),
#  ('UK', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('Gordon', 'PERSON'),
#  ('Alex Salmond', 'PERSON'),
#  ('Gainsborough', 'PERSON'),
#  ('Edward Leigh', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Newport West', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Government', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Roger Mullin', 'PERSON'),
#  ('Kirkcaldy', 'LOCATION'),
#  ('Lewis', 'PERSON'),
#  ('September 1959', 'DATE'),
#  ('Maybole', 'LOCATION'),
#  ('Ayrshire', 'LOCATION'),
#  ('autumn', 'DATE'),
#  ('United States', 'LOCATION'),
#  ('Eisenhower', 'PERSON'),
#  ('Maybole', 'LOCATION'),
#  ('1946', 'DATE'),
#  ('Eisenhower', 'PERSON'),
#  ('Scotland', 'LOCATION'),
#  ('Eisenhower', 'PERSON'),
#  ('Europe', 'LOCATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('1953', 'DATE'),
#  ('1961', 'DATE'),
#  ('White House', 'ORGANIZATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('1959', 'DATE'),
#  ('United Kingdom', 'LOCATION'),
#  ('Parliament', 'ORGANIZATION'),
#  ('France', 'LOCATION'),
#  ('March 1939', 'DATE'),
#  ('Parliament', 'ORGANIZATION'),
#  ('Reagan', 'PERSON'),
#  ('Obama', 'PERSON'),
#  ('Clinton', 'PERSON'),
#  ('George W. Bush', 'PERSON'),
#  ('Parliament', 'ORGANIZATION'),
#  ('20th century', 'DATE'),
#  ('American Presidents', 'ORGANIZATION'),
#  ('Hugh MacDiarmid', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('United Kingdom', 'LOCATION'),
#  ('Mrs Anne Main', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('James Cartlidge', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Government', 'ORGANIZATION'),
#  ('Her Majesty', 'ORGANIZATION'),
#  ('Her Majesty', 'ORGANIZATION'),
#  ('Newport West', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Cardiff South', 'ORGANIZATION'),
#  ('Penarth', 'ORGANIZATION'),
#  ('Stephen Doughty', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Opposition Members', 'ORGANIZATION'),
#  ('United States of America', 'LOCATION'),
#  ('Her Majesty', 'ORGANIZATION'),
#  ('Opposition Members', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Government', 'ORGANIZATION'),
#  ('Her Majesty', 'ORGANIZATION'),
#  ('United States of America', 'LOCATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('Nigel Evans', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('Tony Blair', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Gainsborough', 'PERSON'),
#  ('Edward Leigh', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('Daniel Zeichner', 'PERSON'),
#  ('Cambridge', 'LOCATION'),
#  ('Mr Turner', 'PERSON'),
#  ('Cambridge', 'LOCATION'),
#  ('Cambridge', 'LOCATION'),
#  ('Cambridge', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('Trump', 'ORGANIZATION'),
#  ('White House', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Cambridge', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('US', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Mr Trump', 'PERSON'),
#  ('Carol Monaghan', 'PERSON'),
#  ('Glasgow North West', 'LOCATION'),
#  ('Mr Turner', 'PERSON'),
#  ('Gainsborough', 'PERSON'),
#  ('Edward Leigh', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('Fox News', 'ORGANIZATION'),
#  ('Nicola Sturgeon', 'PERSON'),
#  ('Michelle Thomson', 'PERSON'),
#  ('Edinburgh West', 'LOCATION'),
#  ('Trump', 'ORGANIZATION'),
#  ('Carol Monaghan', 'PERSON'),
#  ('Fox News', 'ORGANIZATION'),
#  ('Germany', 'LOCATION'),
#  ('Randy Krone', 'PERSON'),
#  ('Dallas', 'LOCATION'),
#  ('Carol Monaghan', 'PERSON'),
#  ('Australia', 'LOCATION'),
#  ('Pandora', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('Europe', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Patrick Grady', 'PERSON'),
#  ('Glasgow North', 'ORGANIZATION'),
#  ('this evening', 'TIME'),
#  ('Petitions Committee', 'ORGANIZATION'),
#  ('Procedure Committee', 'ORGANIZATION'),
#  ('Carol Monaghan', 'PERSON'),
#  ('this one this evening', 'TIME'),
#  ('Andrew Turner', 'PERSON'),
#  ('Alistair Carmichael', 'PERSON'),
#  ('Alistair Carmichael', 'PERSON'),
#  ('Orkney', 'ORGANIZATION'),
#  ('Mr Turner', 'PERSON'),
#  ('Petitions Committee', 'ORGANIZATION'),
#  ('this afternoon', 'TIME'),
#  ('House', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Foreign Affairs Committee', 'ORGANIZATION'),
#  ('Reigate', 'LOCATION'),
#  ('Crispin Blunt', 'PERSON'),
#  ('Foreign Affairs Committee', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('NATO', 'ORGANIZATION'),
#  ('Russia', 'LOCATION'),
#  ('Stephen Doughty', 'PERSON'),
#  ('Carmichael', 'PERSON'),
#  ('this weekend', 'DATE'),
#  ('Alex Salmond', 'PERSON'),
#  ('Carmichael', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Nigel Farage', 'PERSON'),
#  ('Trump Tower', 'ORGANIZATION'),
#  ('November', 'DATE'),
#  ('Gordon', 'PERSON'),
#  ('Alex Salmond', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Nigel Evans', 'PERSON'),
#  ('Carmichael', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('United States of America', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Government', 'ORGANIZATION'),
#  ('Administration', 'ORGANIZATION'),
#  ('Gregory Campbell', 'PERSON'),
#  ('East Londonderry', 'LOCATION'),
#  ('Westminster Hall', 'LOCATION'),
#  ('House', 'ORGANIZATION'),
#  ('Candidate Trump', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('United States of America', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Barack Obama', 'PERSON'),
#  ('United States of America', 'LOCATION'),
#  ('21st century', 'DATE'),
#  ('Obama', 'PERSON'),
#  ('United States of America', 'LOCATION'),
#  ('Ribble Valley', 'ORGANIZATION'),
#  ('Evans', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('United Kingdom', 'LOCATION'),
#  ('USA', 'ORGANIZATION'),
#  ('the Netherlands', 'LOCATION'),
#  ('France', 'LOCATION'),
#  ('Germany', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('Europe', 'LOCATION'),
#  ('Westminster', 'LOCATION'),
#  ('Brussels', 'LOCATION'),
#  ('Washington', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Mr Trump', 'PERSON'),
#  ('Mr Trump', 'PERSON'),
#  ('Dawn Butler', 'PERSON'),
#  ('Petitions Committee', 'ORGANIZATION'),
#  ('Europe', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('UK', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('Parliament', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('UK', 'ORGANIZATION'),
#  ('America', 'LOCATION'),
#  ('Parliament', 'LOCATION'),
#  ('Parliament', 'LOCATION'),
#  ('Edmund Burke', 'PERSON'),
#  ('Trump', 'ORGANIZATION'),
#  ('United Kingdom', 'LOCATION'),
#  ('Islamophobia', 'LOCATION'),
#  ('White House', 'ORGANIZATION'),
#  ('today', 'DATE'),
#  ('Martin Luther King', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Nigel Adams', 'PERSON'),
#  ('Selby', 'ORGANIZATION'),
#  ('Andrew Turner', 'PERSON'),
#  ('Liam Byrne', 'PERSON'),
#  ('Birmingham', 'LOCATION'),
#  ('Hodge Hill', 'ORGANIZATION'),
#  ('Liam Byrne', 'PERSON'),
#  ('Parliament', 'LOCATION'),
#  ('Liam Byrne', 'PERSON'),
#  ('Birmingham', 'LOCATION'),
#  ('Mr Turner', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('Washington', 'LOCATION'),
#  ('Washington', 'LOCATION'),
#  ('United Kingdom', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Bradford West', 'ORGANIZATION'),
#  ('Naz Shah', 'PERSON'),
#  ('Birmingham', 'LOCATION'),
#  ('Cambridge', 'LOCATION'),
#  ('Daniel Zeichner', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('Parliament', 'ORGANIZATION'),
#  ('Nigel Adams', 'PERSON'),
#  ('Liam Byrne', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('Donald Trump', 'PERSON'),
#  ('America', 'LOCATION'),
#  ('British Prime Ministers', 'ORGANIZATION'),
#  ('American Presidents', 'ORGANIZATION'),
#  ('Ms Tasmina Ahmed-Sheikh', 'ORGANIZATION'),
#  ('South Perthshire', 'LOCATION'),
#  ('Mr Turner', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('Nigel Adams', 'PERSON'),
#  ('Lewis', 'PERSON'),
#  ('Bradford West', 'ORGANIZATION'),
#  ('Naz Shah', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Government Members', 'ORGANIZATION'),
#  ('Gainsborough', 'PERSON'),
#  ('Edward Leigh', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('USA', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Natalie McGarry', 'PERSON'),
#  ('Glasgow East', 'LOCATION'),
#  ('Parliament', 'ORGANIZATION'),
#  ('Jane Austen', 'PERSON'),
#  ('Nigel Evans', 'PERSON'),
#  ('Selby', 'PERSON'),
#  ('Nigel Adams', 'PERSON'),
#  ('Nigel Adams', 'PERSON'),
#  ('Kuwait', 'LOCATION'),
#  ('Scotland', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('US State Department', 'ORGANIZATION'),
#  ('US Administrations', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('US', 'LOCATION'),
#  ('US', 'LOCATION'),
#  ('Duchess of Cambridge', 'ORGANIZATION'),
#  ('2012', 'DATE'),
#  ('Kate', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('USA', 'ORGANIZATION'),
#  ('Geneva', 'LOCATION'),
#  ('US', 'LOCATION'),
#  ('US', 'LOCATION'),
#  ('US', 'LOCATION'),
#  ('Home Secretary', 'ORGANIZATION'),
#  ('Daesh', 'LOCATION'),
#  ('last week', 'DATE'),
#  ('Putin', 'PERSON'),
#  ('Russia', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('US', 'LOCATION'),
#  ('United States of America', 'LOCATION'),
#  ('Trump', 'LOCATION'),
#  ('Catherine West', 'PERSON'),
#  ('Hornsey', 'ORGANIZATION'),
#  ('Mr Turner', 'PERSON'),
#  ('Opposition', 'ORGANIZATION'),
#  ('Butler', 'PERSON'),
#  ('earlier this month', 'DATE'),
#  ('Newport West', 'ORGANIZATION'),
#  ('Paul Flynn', 'PERSON'),
#  ('Tottenham', 'ORGANIZATION'),
#  ('United States', 'LOCATION'),
#  ('Birmingham', 'LOCATION'),
#  ('Hodge Hill', 'ORGANIZATION'),
#  ('Liam Byrne', 'PERSON'),
#  ('US', 'LOCATION'),
#  ('Hannah Bardell', 'PERSON'),
#  ('US State Department', 'ORGANIZATION'),
#  ('Edinburgh', 'LOCATION'),
#  ('Trump', 'ORGANIZATION'),
#  ('White House', 'ORGANIZATION'),
#  ('Her Majesty', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Iraq', 'LOCATION'),
#  ('Syria', 'LOCATION'),
#  ('Iran', 'LOCATION'),
#  ('Somalia', 'LOCATION'),
#  ('Sudan', 'LOCATION'),
#  ('Yemen', 'LOCATION'),
#  ('White House', 'ORGANIZATION'),
#  ('Angela Merkel', 'PERSON'),
#  ('United Kingdom', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Chris Bryant', 'PERSON'),
#  ('Parliament', 'ORGANIZATION'),
#  ('Hampstead', 'LOCATION'),
#  ('Kilburn', 'PERSON'),
#  ('Tulip Siddiq', 'ORGANIZATION'),
#  ('Bethnal Green', 'ORGANIZATION'),
#  ('Rushanara Ali', 'ORGANIZATION'),
#  ('Dewsbury', 'LOCATION'),
#  ('Paula Sherriff', 'ORGANIZATION'),
#  ('Bradford West', 'ORGANIZATION'),
#  ('Naz Shah', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Houses of Parliament', 'ORGANIZATION'),
#  ('Westminster Hall', 'LOCATION'),
#  ('House of Commons', 'ORGANIZATION'),
#  ('Cardiff South', 'ORGANIZATION'),
#  ('Penarth', 'ORGANIZATION'),
#  ('Stephen Doughty', 'PERSON'),
#  ('Parliament', 'ORGANIZATION'),
#  ('Europe', 'LOCATION'),
#  ('Alan Duncan', 'PERSON'),
#  ('Mr Turner', 'PERSON'),
#  ("Her Majesty 's Government", 'ORGANIZATION'),
#  ('Wood Green', 'ORGANIZATION'),
#  ('Catherine West', 'LOCATION'),
#  ('Government', 'ORGANIZATION'),
#  ('Royal Visits Committee', 'ORGANIZATION'),
#  ('Parliament', 'ORGANIZATION'),
#  ('Cabinet Office', 'ORGANIZATION'),
#  ('Department for International Trade', 'ORGANIZATION'),
#  ('Commonwealth Office', 'ORGANIZATION'),
#  ('Alex Salmond', 'PERSON'),
#  ('Alan Duncan', 'PERSON'),
#  ('United States', 'LOCATION'),
#  ('United Kingdom', 'LOCATION'),
#  ('United Kingdom', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United Kingdom', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('United States', 'LOCATION'),
#  ('America', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Administration', 'ORGANIZATION'),
#  ('Washington', 'LOCATION'),
#  ('US Administration', 'ORGANIZATION'),
#  ('State', 'ORGANIZATION'),
#  ('Defence', 'ORGANIZATION'),
#  ('Friday', 'DATE'),
#  ('US Secretary of Homeland Security', 'ORGANIZATION'),
#  ('John Kelly', 'PERSON'),
#  ('Government', 'ORGANIZATION'),
#  ('Stephen Doughty', 'PERSON'),
#  ('Alan Duncan', 'PERSON'),
#  ('Atlantic', 'LOCATION'),
#  ('Trump', 'PERSON'),
#  ('Washington', 'LOCATION'),
#  ('Administration', 'ORGANIZATION'),
#  ('South Africa', 'LOCATION'),
#  ('France', 'LOCATION'),
#  ('South Korea', 'LOCATION'),
#  ('Finland', 'LOCATION'),
#  ('Poland', 'LOCATION'),
#  ('Seema Malhotra', 'PERSON'),
#  ('Feltham', 'PERSON'),
#  ('Alan Duncan', 'PERSON'),
#  ('Seema Malhotra', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Alan Duncan', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Obama', 'PERSON'),
#  ('George W. Bush', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('today', 'DATE'),
#  ('Houses of Parliament', 'ORGANIZATION'),
#  ('1960', 'DATE'),
#  ...]
