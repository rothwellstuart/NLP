# %% [markdown]
# # Image Classification example
#
# From Stack Exchange
#
# https://datascience.stackexchange.com/questions/10091/image-classification-in-python

# %%
# %matplotlib inline  

import matplotlib
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\rothw\Anaconda3\lib\site-packages\matplotlib\font_manager.py in <module>()
#    1431                 fontManager._version != FontManager.__version__):
# -> 1432                 _rebuild()
#    1433             else:
#
# C:\Users\rothw\Anaconda3\lib\site-packages\matplotlib\font_manager.py in _rebuild()
#    1421             with cbook.Locked(cachedir):
# -> 1422                 pickle_dump(fontManager, _fmcache)
#    1423
#
# C:\Users\rothw\Anaconda3\lib\site-packages\matplotlib\font_manager.py in pickle_dump(data, filename)
#     955     """
# --> 956     with open(filename, 'wb') as fh:
#     957         pickle.dump(data, fh)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\rothw\\.matplotlib\\fontList.py3k.cache'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-8-ec2808e6be20> in <module>()
# ----> 1 get_ipython().magic('matplotlib inline')
#       2
#       3 import matplotlib
#
# C:\Users\rothw\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# C:\Users\rothw\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-105> in matplotlib(self, line)
#
# C:\Users\rothw\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Users\rothw\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# C:\Users\rothw\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    2947                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    2948
# -> 2949         pt.activate_matplotlib(backend)
#    2950         pt.configure_inline_support(self, backend)
#    2951
#
# C:\Users\rothw\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in activate_matplotlib(backend)
#     305     matplotlib.rcParams['backend'] = backend
#     306
# --> 307     import matplotlib.pyplot
#     308     matplotlib.pyplot.switch_backend(backend)
#     309
#
# C:\Users\rothw\Anaconda3\lib\site-packages\matplotlib\pyplot.py in <module>()
#      27 from cycler import cycler
#      28 import matplotlib
# ---> 29 import matplotlib.colorbar
#      30 from matplotlib import style
#      31 from matplotlib import _pylab_helpers, interactive
#
# C:\Users\rothw\Anaconda3\lib\site-packages\matplotlib\colorbar.py in <module>()
#      34 import matplotlib.collections as collections
#      35 import matplotlib.colors as colors
# ---> 36 import matplotlib.contour as contour
#      37 import matplotlib.cm as cm
#      38 import matplotlib.gridspec as gridspec
#
# C:\Users\rothw\Anaconda3\lib\site-packages\matplotlib\contour.py in <module>()
#      20 import matplotlib.colors as colors
#      21 import matplotlib.collections as mcoll
# ---> 22 import matplotlib.font_manager as font_manager
#      23 import matplotlib.text as text
#      24 import matplotlib.cbook as cbook
#
# C:\Users\rothw\Anaconda3\lib\site-packages\matplotlib\font_manager.py in <module>()
#    1437             raise
#    1438         except:
# -> 1439             _rebuild()
#    1440     else:
#    1441         _rebuild()
#
# C:\Users\rothw\Anaconda3\lib\site-packages\matplotlib\font_manager.py in _rebuild()
#    1420         if _fmcache:
#    1421             with cbook.Locked(cachedir):
# -> 1422                 pickle_dump(fontManager, _fmcache)
#    1423
#    1424
#
# C:\Users\rothw\Anaconda3\lib\site-packages\matplotlib\font_manager.py in pickle_dump(data, filename)
#     954     but closes the file to prevent filehandle leakage.
#     955     """
# --> 956     with open(filename, 'wb') as fh:
#     957         pickle.dump(data, fh)
#     958
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\rothw\\.matplotlib\\fontList.py3k.cache'

# %%
# Imports

from PIL import Image
from numpy import array

import numpy as np

# %%
#Import an image

image = Image.open("C:\\Users\\rothw\\Documents\\Python Scripts\\Python NLP\\Stuart_Rothwell_proof_of_ID.JPG")

image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x193683F9EB8>

# %%
# Convert image to gray-scale:

im = image.convert('L')

im
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x1936710CE48>

# %%
array(im)
# Out:
# array([[141, 143, 137, ..., 146, 147, 139],
#        [147, 144, 134, ..., 144, 149, 146],
#        [139, 142, 137, ..., 135, 140, 142],
#        ...,
#        [ 68,  82,  90, ...,  51,  56,  47],
#        [ 74,  80,  87, ...,  50,  58,  54],
#        [ 75,  74,  82, ...,  48,  53,  51]], dtype=uint8)

# %%
# Get size of array

array(im).shape
# Out:
# (480, 640)

# %%
# Get size of flattened array

array(im).flatten().shape
# Out:
# (307200,)
